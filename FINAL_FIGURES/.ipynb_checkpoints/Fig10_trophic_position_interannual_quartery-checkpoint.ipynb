# %% [markdown]
# # Trophic position, in the Arctic Ocean. To create the maps that I want, I think I need to find this remmapped. So I will attempt to do this!

# %%
# %matplotlib inline
import warnings
warnings.simplefilter("ignore") # Silence warnings
#import hvplot.xarray
import xarray as xr
import cartopy.crs as ccrs
import numpy as np
import math
from matplotlib.pyplot import figure

# MatPlotlib
import matplotlib.pyplot as plt
from matplotlib import pylab

# Scientific libraries
from numpy import arange,array,ones
from scipy import stats

import seaborn as sns
import scipy.io as sio

import numpy.ma as ma
from netCDF4 import Dataset as NetCDFFile
import glob
import pylab 
from copy import deepcopy
import pandas as pd
import os
import matplotlib.gridspec as gridspec
import matplotlib
import cartopy
import matplotlib.colors as colors
import cmocean
from cartopy.util import add_cyclic_point

# %%
def discrete_cmap(N, base_cmap=None):
    """Create an N-bin discrete colormap from the specified input map"""

    # Note that if base_cmap is a string or None, you can simply do
    #    return plt.cm.get_cmap(base_cmap, N)
    # The following works for string, None, or a colormap instance:

    base = plt.cm.get_cmap(base_cmap)
    color_list = base(np.linspace(0, 1, N))
    cmap_name = base.name + str(N)
    return base.from_list(cmap_name, color_list, N)

# %%
class MidpointNormalize(colors.Normalize):
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        colors.Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        if clip is None:
            clip = self.clip

        result, is_scalar = self.process_value(value)

        self.autoscale_None(result)
        vmin, vmax, midpoint = self.vmin, self.vmax, self.midpoint

        if not (vmin < midpoint < vmax):
            raise ValueError("midpoint must be between maxvalue and minvalue.")
        elif vmin == vmax:
            result.fill(0) # Or should it be all masked? Or 0.5?
        elif vmin > vmax:
            raise ValueError("maxvalue must be bigger than minvalue")
        else:
            vmin = float(vmin)
            vmax = float(vmax)
            if clip:
                mask = np.ma.getmask(result)
                result = np.ma.array(np.clip(result.filled(vmax), vmin, vmax),
                                  mask=mask)

            # ma division is very slow; we can take a shortcut
            resdat = result.data

            #First scale to -1 to 1 range, than to from 0 to 1.
            resdat -= midpoint
            resdat[resdat>0] /= abs(vmax - midpoint)
            resdat[resdat<0] /= abs(vmin - midpoint)

            resdat /= 2.
            resdat += 0.5
            result = np.ma.array(resdat, mask=result.mask, copy=False)

        if is_scalar:
            result = result[0]
        return result

# %%
def adjust_pop_grid(tlon,tlat,field):
    nj = tlon.shape[0]
    ni = tlon.shape[1]
    xL = int(ni/2 - 1)
    xR = int(xL + ni)

    tlon = np.where(np.greater_equal(tlon,np.min(tlon[:,0])),tlon-360.,tlon)
    lon  = np.concatenate((tlon,tlon+360.),1)
    lon = lon[:,xL:xR]

    if ni == 320:
        lon[367:-3,0] = lon[367:-3,0]+360.
    lon = lon - 360.
    lon = np.hstack((lon,lon[:,0:1]+360.))
    if ni == 320:
        lon[367:,-1] = lon[367:,-1] - 360.

    #-- trick cartopy into doing the right thing:
    #   it gets confused when the cyclic coords are identical
    lon[:,0] = lon[:,0]-1e-8

    #-- periodicity
    lat  = np.concatenate((tlat,tlat),1)
    lat = lat[:,xL:xR]
    lat = np.hstack((lat,lat[:,0:1]))

    field = np.ma.concatenate((field,field),1)
    field = field[:,xL:xR]
    field = np.ma.hstack((field,field[:,0:1]))
    return lon,lat,field

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %% [markdown]
# ## Import the trophic level information quarterly, so that we can create the figure that we wish!

# %%
path = '/glade/campaign/cesm/development/bgcwg/projects/marbl-spectra/GNG595_2ndcycle_1990-2009_clim'
files = sorted(glob.glob(f'{path}/*.nc', recursive=True),key=numericalSort)
ds= xr.open_mfdataset(files,combine='by_coords')

# %% [markdown]
# ## Import the TL for every season

# %%
TL_fall = xr.open_mfdataset('/glade/u/home/gabyn/scratch/SPECTRA/nc_files/zooTL_62yr_fall.nc')
TL_winter = xr.open_mfdataset('/glade/u/home/gabyn/scratch/SPECTRA/nc_files/zooTL_62yr_winter.nc')
TL_summer = xr.open_mfdataset('/glade/u/home/gabyn/scratch/SPECTRA/nc_files/zooTL_62yr_summer.nc')
TL_spring=xr.open_mfdataset('/glade/u/home/gabyn/scratch/SPECTRA/nc_files/zooTL_62yr_spring.nc')
# Out:
# 	NC4_open: path /glade/u/home/gabyn/scratch/SPECTRA/nc_files/zooTL_62yr_fall.nc mode 4096 params 0
# 	HDF5 error messages turned on.
# 			nc4_open_file: path /glade/u/home/gabyn/scratch/SPECTRA/nc_files/zooTL_62yr_fall.nc mode 4096
# 			nc4_grp_list_add: name /
# 			nc4_rec_read_metadata: grp->hdr.name /
# 			found dataset year
# 			found dataset z_t_150m
# 			found dataset nlat
# 			found dataset nlon
# 			found dataset zoo1TL_fall
# 			found dataset zoo2TL_fall
# 			found dataset zoo3TL_fall
# 			found dataset zoo4TL_fall
# 			found dataset zoo5TL_fall
# 			found dataset zoo6TL_fall
# 			found dataset zooTL_fall
# ERROR: Invalid _NCProperties attribute
# 		*** NetCDF-4 Internal Metadata: int_ncid 0xd0000 ext_ncid 0xd0000
# 		FILE - path: /glade/u/home/gabyn/scratch/SPECTRA/nc_files/zooTL_62yr_fall.nc cmode: 0x1008 parallel: 0 redef: 0 fill_mode: 0 no_write: 1 next_nc_grpid: 1
# 		 GROUP - / nc_grpid: 0 nvars: 11 natts: 0
# 		 DIMENSION - dimid: 0 name: year len: 62 unlimited: 0
# 		 DIMENSION - dimid: 1 name: z_t_150m len: 15 unlimited: 0
# 		 DIMENSION - dimid: 2 name: nlat len: 384 unlimited: 0
# 		 DIMENSION - dimid: 3 name: nlon len: 320 unlimited: 0
# 		 VARIABLE - varid: 0 name: year ndims: 1 dimscale: 1 dimids: 0
# 		 VARIABLE - varid: 1 name: z_t_150m ndims: 1 dimscale: 1 dimids: 1
# 		 VARIABLE - varid: 2 name: nlat ndims: 1 dimscale: 1 dimids: 2
# 		 VARIABLE - varid: 3 name: nlon ndims: 1 dimscale: 1 dimids: 3
# 		 VARIABLE - varid: 4 name: zoo1TL_fall ndims: 4 dimscale: 0 dimids: 0 1 2 3
# 		 VARIABLE - varid: 5 name: zoo2TL_fall ndims: 4 dimscale: 0 dimids: 0 1 2 3
# 		 VARIABLE - varid: 6 name: zoo3TL_fall ndims: 4 dimscale: 0 dimids: 0 1 2 3
# 		 VARIABLE - varid: 7 name: zoo4TL_fall ndims: 4 dimscale: 0 dimids: 0 1 2 3
# 		 VARIABLE - varid: 8 name: zoo5TL_fall ndims: 4 dimscale: 0 dimids: 0 1 2 3
# 		 VARIABLE - varid: 9 name: zoo6TL_fall ndims: 4 dimscale: 0 dimids: 0 1 2 3
# 		 VARIABLE - varid: 10 name: zooTL_fall ndims: 4 dimscale: 0 dimids: 0 1 2 3
# 		nc_inq_format: ncid 0xd0000
# 		NC4_inq_format_extended: ncid 0xd0000
# 		nc_inq_typeids: ncid 0xd0000
# 		NC4_inq: ncid 0xd0000
# 		nc_inq_dimids: ncid 0xd0000 include_parents: 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq: ncid 0xd0000
# 		nc_inq_varids: ncid 0xd0000
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 			nc4_att_list_add: name _FillValue
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name units
# 			nc4_att_list_add: name positive
# 			nc4_att_list_add: name valid_min
# 			nc4_att_list_add: name valid_max
# 		nc_inq_attname: ncid 0xd0000 varid 1 attnum 0
# 		nc_inq_attname: ncid 0xd0000 varid 1 attnum 1
# 		nc_inq_attname: ncid 0xd0000 varid 1 attnum 2
# 		nc_inq_attname: ncid 0xd0000 varid 1 attnum 3
# 		nc_inq_attname: ncid 0xd0000 varid 1 attnum 4
# 		nc_inq_attname: ncid 0xd0000 varid 1 attnum 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0xd0000 varid 4 attnum 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0xd0000 varid 5 attnum 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0xd0000 varid 6 attnum 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0xd0000 varid 7 attnum 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0xd0000 varid 8 attnum 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0xd0000 varid 9 attnum 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0xd0000 varid 10 attnum 0
# 		nc_inq_grps: ncid 0xd0000
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		nc_inq_attname: ncid 0xd0000 varid 1 attnum 0
# 		nc_inq_attname: ncid 0xd0000 varid 1 attnum 1
# 		nc_inq_attname: ncid 0xd0000 varid 1 attnum 2
# 		nc_inq_attname: ncid 0xd0000 varid 1 attnum 3
# 		nc_inq_attname: ncid 0xd0000 varid 1 attnum 4
# 		nc_inq_attname: ncid 0xd0000 varid 1 attnum 5
# 		NC4_inq_att: ncid 0xd0000 varid 1 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 1 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 1 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 1 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 1 name _FillValue attnum -1 mem_type 5
# 		NC4_inq_att: ncid 0xd0000 varid 1 name long_name
# 			nc4_get_att: ncid 0xd0000 varid 1 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 1 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xd0000 varid 1 name units
# 			nc4_get_att: ncid 0xd0000 varid 1 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 1 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xd0000 varid 1 name positive
# 			nc4_get_att: ncid 0xd0000 varid 1 name positive attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 1 name positive attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xd0000 varid 1 name valid_min
# 			nc4_get_att: ncid 0xd0000 varid 1 name valid_min attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 1 name valid_min
# 			nc4_get_att: ncid 0xd0000 varid 1 name valid_min attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 1 name valid_min attnum -1 mem_type 5
# 		NC4_inq_att: ncid 0xd0000 varid 1 name valid_max
# 			nc4_get_att: ncid 0xd0000 varid 1 name valid_max attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 1 name valid_max
# 			nc4_get_att: ncid 0xd0000 varid 1 name valid_max attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 1 name valid_max attnum -1 mem_type 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		nc_inq_attname: ncid 0xd0000 varid 4 attnum 0
# 		NC4_inq_att: ncid 0xd0000 varid 4 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 4 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 4 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 4 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 4 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		nc_inq_attname: ncid 0xd0000 varid 5 attnum 0
# 		NC4_inq_att: ncid 0xd0000 varid 5 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 5 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 5 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 5 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 5 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		nc_inq_attname: ncid 0xd0000 varid 6 attnum 0
# 		NC4_inq_att: ncid 0xd0000 varid 6 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 6 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 6 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 6 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 6 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 6
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		nc_inq_attname: ncid 0xd0000 varid 7 attnum 0
# 		NC4_inq_att: ncid 0xd0000 varid 7 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 7 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 7 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 7 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 7 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		NC4_inq_var_all: ncid 0xd0000 varid 7
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		nc_inq_attname: ncid 0xd0000 varid 8 attnum 0
# 		NC4_inq_att: ncid 0xd0000 varid 8 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 8 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 8 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 8 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 8 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		NC4_inq_var_all: ncid 0xd0000 varid 8
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		nc_inq_attname: ncid 0xd0000 varid 9 attnum 0
# 		NC4_inq_att: ncid 0xd0000 varid 9 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 9 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 9 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 9 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 9 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		NC4_inq_var_all: ncid 0xd0000 varid 9
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		nc_inq_attname: ncid 0xd0000 varid 10 attnum 0
# 		NC4_inq_att: ncid 0xd0000 varid 10 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 10 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 10 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 10 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 10 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 			NC4_get_vars: var->hdr.name year mem_nc_type 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_att: ncid 0xd0000 varid 0 name scale_factor
# 			nc4_get_att: ncid 0xd0000 varid 0 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 0 name add_offset
# 			nc4_get_att: ncid 0xd0000 varid 0 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 			NC4_get_vars: var->hdr.name z_t_150m mem_nc_type 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_att: ncid 0xd0000 varid 1 name scale_factor
# 			nc4_get_att: ncid 0xd0000 varid 1 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 1 name add_offset
# 			nc4_get_att: ncid 0xd0000 varid 1 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 			NC4_get_vars: var->hdr.name nlat mem_nc_type 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_att: ncid 0xd0000 varid 2 name scale_factor
# 			nc4_get_att: ncid 0xd0000 varid 2 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 2 name add_offset
# 			nc4_get_att: ncid 0xd0000 varid 2 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 			NC4_get_vars: var->hdr.name nlon mem_nc_type 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_att: ncid 0xd0000 varid 3 name scale_factor
# 			nc4_get_att: ncid 0xd0000 varid 3 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 3 name add_offset
# 			nc4_get_att: ncid 0xd0000 varid 3 name add_offset attnum -1 mem_type 0
# 	NC4_open: path /glade/u/home/gabyn/scratch/SPECTRA/nc_files/zooTL_62yr_winter.nc mode 4096 params 0
# 	HDF5 error messages turned on.
# 			nc4_open_file: path /glade/u/home/gabyn/scratch/SPECTRA/nc_files/zooTL_62yr_winter.nc mode 4096
# 			nc4_grp_list_add: name /
# 			nc4_rec_read_metadata: grp->hdr.name /
# 			found dataset year
# 			found dataset z_t_150m
# 			found dataset nlat
# 			found dataset nlon
# 			found dataset zoo1TL_winter
# 			found dataset zoo2TL_winter
# 			found dataset zoo3TL_winter
# 			found dataset zoo4TL_winter
# 			found dataset zoo5TL_winter
# 			found dataset zoo6TL_winter
# 			found dataset zooTL_winter
# ERROR: Invalid _NCProperties attribute
# 		*** NetCDF-4 Internal Metadata: int_ncid 0xe0000 ext_ncid 0xe0000
# 		FILE - path: /glade/u/home/gabyn/scratch/SPECTRA/nc_files/zooTL_62yr_winter.nc cmode: 0x1008 parallel: 0 redef: 0 fill_mode: 0 no_write: 1 next_nc_grpid: 1
# 		 GROUP - / nc_grpid: 0 nvars: 11 natts: 0
# 		 DIMENSION - dimid: 0 name: year len: 62 unlimited: 0
# 		 DIMENSION - dimid: 1 name: z_t_150m len: 15 unlimited: 0
# 		 DIMENSION - dimid: 2 name: nlat len: 384 unlimited: 0
# 		 DIMENSION - dimid: 3 name: nlon len: 320 unlimited: 0
# 		 VARIABLE - varid: 0 name: year ndims: 1 dimscale: 1 dimids: 0
# 		 VARIABLE - varid: 1 name: z_t_150m ndims: 1 dimscale: 1 dimids: 1
# 		 VARIABLE - varid: 2 name: nlat ndims: 1 dimscale: 1 dimids: 2
# 		 VARIABLE - varid: 3 name: nlon ndims: 1 dimscale: 1 dimids: 3
# 		 VARIABLE - varid: 4 name: zoo1TL_winter ndims: 4 dimscale: 0 dimids: 0 1 2 3
# 		 VARIABLE - varid: 5 name: zoo2TL_winter ndims: 4 dimscale: 0 dimids: 0 1 2 3
# 		 VARIABLE - varid: 6 name: zoo3TL_winter ndims: 4 dimscale: 0 dimids: 0 1 2 3
# 		 VARIABLE - varid: 7 name: zoo4TL_winter ndims: 4 dimscale: 0 dimids: 0 1 2 3
# 		 VARIABLE - varid: 8 name: zoo5TL_winter ndims: 4 dimscale: 0 dimids: 0 1 2 3
# 		 VARIABLE - varid: 9 name: zoo6TL_winter ndims: 4 dimscale: 0 dimids: 0 1 2 3
# 		 VARIABLE - varid: 10 name: zooTL_winter ndims: 4 dimscale: 0 dimids: 0 1 2 3
# 		nc_inq_format: ncid 0xe0000
# 		NC4_inq_format_extended: ncid 0xe0000
# 		nc_inq_typeids: ncid 0xe0000
# 		NC4_inq: ncid 0xe0000
# 		nc_inq_dimids: ncid 0xe0000 include_parents: 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq: ncid 0xe0000
# 		nc_inq_varids: ncid 0xe0000
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 			nc4_att_list_add: name _FillValue
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name units
# 			nc4_att_list_add: name positive
# 			nc4_att_list_add: name valid_min
# 			nc4_att_list_add: name valid_max
# 		nc_inq_attname: ncid 0xe0000 varid 1 attnum 0
# 		nc_inq_attname: ncid 0xe0000 varid 1 attnum 1
# 		nc_inq_attname: ncid 0xe0000 varid 1 attnum 2
# 		nc_inq_attname: ncid 0xe0000 varid 1 attnum 3
# 		nc_inq_attname: ncid 0xe0000 varid 1 attnum 4
# 		nc_inq_attname: ncid 0xe0000 varid 1 attnum 5
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0xe0000 varid 4 attnum 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0xe0000 varid 5 attnum 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0xe0000 varid 6 attnum 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0xe0000 varid 7 attnum 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0xe0000 varid 8 attnum 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0xe0000 varid 9 attnum 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_unlimdims: ncid 0xe0000
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0xe0000 varid 10 attnum 0
# 		nc_inq_grps: ncid 0xe0000
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		nc_inq_attname: ncid 0xe0000 varid 1 attnum 0
# 		nc_inq_attname: ncid 0xe0000 varid 1 attnum 1
# 		nc_inq_attname: ncid 0xe0000 varid 1 attnum 2
# 		nc_inq_attname: ncid 0xe0000 varid 1 attnum 3
# 		nc_inq_attname: ncid 0xe0000 varid 1 attnum 4
# 		nc_inq_attname: ncid 0xe0000 varid 1 attnum 5
# 		NC4_inq_att: ncid 0xe0000 varid 1 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 1 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xe0000 varid 1 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 1 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xe0000 varid 1 name _FillValue attnum -1 mem_type 5
# 		NC4_inq_att: ncid 0xe0000 varid 1 name long_name
# 			nc4_get_att: ncid 0xe0000 varid 1 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xe0000 varid 1 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xe0000 varid 1 name units
# 			nc4_get_att: ncid 0xe0000 varid 1 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xe0000 varid 1 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xe0000 varid 1 name positive
# 			nc4_get_att: ncid 0xe0000 varid 1 name positive attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xe0000 varid 1 name positive attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xe0000 varid 1 name valid_min
# 			nc4_get_att: ncid 0xe0000 varid 1 name valid_min attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xe0000 varid 1 name valid_min
# 			nc4_get_att: ncid 0xe0000 varid 1 name valid_min attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xe0000 varid 1 name valid_min attnum -1 mem_type 5
# 		NC4_inq_att: ncid 0xe0000 varid 1 name valid_max
# 			nc4_get_att: ncid 0xe0000 varid 1 name valid_max attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xe0000 varid 1 name valid_max
# 			nc4_get_att: ncid 0xe0000 varid 1 name valid_max attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xe0000 varid 1 name valid_max attnum -1 mem_type 5
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		NC4_inq_var_all: ncid 0xe0000 varid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		nc_inq_attname: ncid 0xe0000 varid 4 attnum 0
# 		NC4_inq_att: ncid 0xe0000 varid 4 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 4 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xe0000 varid 4 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 4 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xe0000 varid 4 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		NC4_inq_var_all: ncid 0xe0000 varid 4
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		nc_inq_attname: ncid 0xe0000 varid 5 attnum 0
# 		NC4_inq_att: ncid 0xe0000 varid 5 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 5 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xe0000 varid 5 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 5 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xe0000 varid 5 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		NC4_inq_var_all: ncid 0xe0000 varid 5
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		nc_inq_attname: ncid 0xe0000 varid 6 attnum 0
# 		NC4_inq_att: ncid 0xe0000 varid 6 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 6 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xe0000 varid 6 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 6 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xe0000 varid 6 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 6
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		nc_inq_attname: ncid 0xe0000 varid 7 attnum 0
# 		NC4_inq_att: ncid 0xe0000 varid 7 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 7 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xe0000 varid 7 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 7 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xe0000 varid 7 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		NC4_inq_var_all: ncid 0xe0000 varid 7
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		nc_inq_attname: ncid 0xe0000 varid 8 attnum 0
# 		NC4_inq_att: ncid 0xe0000 varid 8 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 8 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xe0000 varid 8 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 8 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xe0000 varid 8 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		NC4_inq_var_all: ncid 0xe0000 varid 8
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		nc_inq_attname: ncid 0xe0000 varid 9 attnum 0
# 		NC4_inq_att: ncid 0xe0000 varid 9 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 9 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xe0000 varid 9 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 9 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xe0000 varid 9 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		NC4_inq_var_all: ncid 0xe0000 varid 9
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		nc_inq_attname: ncid 0xe0000 varid 10 attnum 0
# 		NC4_inq_att: ncid 0xe0000 varid 10 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 10 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xe0000 varid 10 name _FillValue
# 			nc4_get_att: ncid 0xe0000 varid 10 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xe0000 varid 10 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# ...
# 			nc4_att_list_add: name _FillValue
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name units
# 			nc4_att_list_add: name positive
# 			nc4_att_list_add: name valid_min
# 			nc4_att_list_add: name valid_max
# 		nc_inq_attname: ncid 0x100000 varid 1 attnum 0
# 		nc_inq_attname: ncid 0x100000 varid 1 attnum 1
# 		nc_inq_attname: ncid 0x100000 varid 1 attnum 2
# 		nc_inq_attname: ncid 0x100000 varid 1 attnum 3
# 		nc_inq_attname: ncid 0x100000 varid 1 attnum 4
# 		nc_inq_attname: ncid 0x100000 varid 1 attnum 5
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0x100000 varid 4 attnum 0
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0x100000 varid 5 attnum 0
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0x100000 varid 6 attnum 0
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0x100000 varid 7 attnum 0
# 		NC4_inq_var_all: ncid 0x100000 varid 8
# 		NC4_inq_var_all: ncid 0x100000 varid 8
# 		NC4_inq_var_all: ncid 0x100000 varid 8
# 		NC4_inq_var_all: ncid 0x100000 varid 8
# 		NC4_inq_var_all: ncid 0x100000 varid 8
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_var_all: ncid 0x100000 varid 8
# 		NC4_inq_var_all: ncid 0x100000 varid 8
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0x100000 varid 8 attnum 0
# 		NC4_inq_var_all: ncid 0x100000 varid 9
# 		NC4_inq_var_all: ncid 0x100000 varid 9
# 		NC4_inq_var_all: ncid 0x100000 varid 9
# 		NC4_inq_var_all: ncid 0x100000 varid 9
# 		NC4_inq_var_all: ncid 0x100000 varid 9
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_var_all: ncid 0x100000 varid 9
# 		NC4_inq_var_all: ncid 0x100000 varid 9
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0x100000 varid 9 attnum 0
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_unlimdims: ncid 0x100000
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0x100000 varid 10 attnum 0
# 		nc_inq_grps: ncid 0x100000
# 		NC4_inq_var_all: ncid 0x100000 varid 0
# 		NC4_inq_var_all: ncid 0x100000 varid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_var_all: ncid 0x100000 varid 0
# 		NC4_inq_var_all: ncid 0x100000 varid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_var_all: ncid 0x100000 varid 0
# 		NC4_inq_var_all: ncid 0x100000 varid 0
# 		NC4_inq_var_all: ncid 0x100000 varid 0
# 		NC4_inq_var_all: ncid 0x100000 varid 0
# 		NC4_inq_var_all: ncid 0x100000 varid 0
# 		NC4_inq_var_all: ncid 0x100000 varid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_var_all: ncid 0x100000 varid 1
# 		NC4_inq_var_all: ncid 0x100000 varid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_var_all: ncid 0x100000 varid 1
# 		NC4_inq_var_all: ncid 0x100000 varid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_var_all: ncid 0x100000 varid 1
# 		nc_inq_attname: ncid 0x100000 varid 1 attnum 0
# 		nc_inq_attname: ncid 0x100000 varid 1 attnum 1
# 		nc_inq_attname: ncid 0x100000 varid 1 attnum 2
# 		nc_inq_attname: ncid 0x100000 varid 1 attnum 3
# 		nc_inq_attname: ncid 0x100000 varid 1 attnum 4
# 		nc_inq_attname: ncid 0x100000 varid 1 attnum 5
# 		NC4_inq_att: ncid 0x100000 varid 1 name _FillValue
# 			nc4_get_att: ncid 0x100000 varid 1 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x100000 varid 1 name _FillValue
# 			nc4_get_att: ncid 0x100000 varid 1 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x100000 varid 1 name _FillValue attnum -1 mem_type 5
# 		NC4_inq_att: ncid 0x100000 varid 1 name long_name
# 			nc4_get_att: ncid 0x100000 varid 1 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x100000 varid 1 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x100000 varid 1 name units
# 			nc4_get_att: ncid 0x100000 varid 1 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x100000 varid 1 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x100000 varid 1 name positive
# 			nc4_get_att: ncid 0x100000 varid 1 name positive attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x100000 varid 1 name positive attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x100000 varid 1 name valid_min
# 			nc4_get_att: ncid 0x100000 varid 1 name valid_min attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x100000 varid 1 name valid_min
# 			nc4_get_att: ncid 0x100000 varid 1 name valid_min attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x100000 varid 1 name valid_min attnum -1 mem_type 5
# 		NC4_inq_att: ncid 0x100000 varid 1 name valid_max
# 			nc4_get_att: ncid 0x100000 varid 1 name valid_max attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x100000 varid 1 name valid_max
# 			nc4_get_att: ncid 0x100000 varid 1 name valid_max attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x100000 varid 1 name valid_max attnum -1 mem_type 5
# 		NC4_inq_var_all: ncid 0x100000 varid 1
# 		NC4_inq_var_all: ncid 0x100000 varid 1
# 		NC4_inq_var_all: ncid 0x100000 varid 1
# 		NC4_inq_var_all: ncid 0x100000 varid 1
# 		NC4_inq_var_all: ncid 0x100000 varid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		nc_inq_attname: ncid 0x100000 varid 4 attnum 0
# 		NC4_inq_att: ncid 0x100000 varid 4 name _FillValue
# 			nc4_get_att: ncid 0x100000 varid 4 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x100000 varid 4 name _FillValue
# 			nc4_get_att: ncid 0x100000 varid 4 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x100000 varid 4 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		NC4_inq_var_all: ncid 0x100000 varid 4
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		nc_inq_attname: ncid 0x100000 varid 5 attnum 0
# 		NC4_inq_att: ncid 0x100000 varid 5 name _FillValue
# 			nc4_get_att: ncid 0x100000 varid 5 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x100000 varid 5 name _FillValue
# 			nc4_get_att: ncid 0x100000 varid 5 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x100000 varid 5 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		NC4_inq_var_all: ncid 0x100000 varid 5
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		nc_inq_attname: ncid 0x100000 varid 6 attnum 0
# 		NC4_inq_att: ncid 0x100000 varid 6 name _FillValue
# 			nc4_get_att: ncid 0x100000 varid 6 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x100000 varid 6 name _FillValue
# 			nc4_get_att: ncid 0x100000 varid 6 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x100000 varid 6 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		NC4_inq_var_all: ncid 0x100000 varid 6
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		nc_inq_attname: ncid 0x100000 varid 7 attnum 0
# 		NC4_inq_att: ncid 0x100000 varid 7 name _FillValue
# 			nc4_get_att: ncid 0x100000 varid 7 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x100000 varid 7 name _FillValue
# 			nc4_get_att: ncid 0x100000 varid 7 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x100000 varid 7 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		NC4_inq_var_all: ncid 0x100000 varid 7
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 8
# 		NC4_inq_var_all: ncid 0x100000 varid 8
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 8
# 		NC4_inq_var_all: ncid 0x100000 varid 8
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 8
# 		nc_inq_attname: ncid 0x100000 varid 8 attnum 0
# 		NC4_inq_att: ncid 0x100000 varid 8 name _FillValue
# 			nc4_get_att: ncid 0x100000 varid 8 name _FillValue attnum -1 mem_t

# %%
from mpl_toolkits.basemap import Basemap
fig = plt.figure(figsize=(20, 10))
## WINTER 
ax = fig.add_subplot(1, 4, 1)
lon, lat, winter = adjust_pop_grid(ds.TLONG, ds.TLAT, TL_winter.zooTL_winter[:,:,:,:].mean(axis=(0,1)))
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
x,y = m(lon, lat)
cf = m.pcolor(x,y,winter,cmap='Reds', vmin = 2, vmax = 3)
m.drawcoastlines(linewidth=0.5, linestyle='solid', color='gray', antialiased=1, ax=None, zorder=None)
m.fillcontinents(color='0.55', lake_color=None, ax=None, zorder=None, alpha=None)
ax.set_title('Winter', fontsize =30)

## SPRING
ax = fig.add_subplot(1, 4, 2)
lon, lat, spring = adjust_pop_grid(ds.TLONG, ds.TLAT, TL_spring.zooTL_spring[:,:,:,:].mean(axis=(0,1)))
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
x,y = m(lon, lat)
cf = m.pcolor(x,y,spring,cmap='Reds', vmin = 2, vmax = 3)
m.drawcoastlines(linewidth=0.5, linestyle='solid', color='gray', antialiased=1, ax=None, zorder=None)
m.fillcontinents(color='0.55', lake_color=None, ax=None, zorder=None, alpha=None)
ax.set_title('Spring', fontsize =30)

## SUMMER
ax = fig.add_subplot(1, 4, 3)
lon, lat, summer = adjust_pop_grid(ds.TLONG, ds.TLAT, TL_summer.zooTL_summer[:,:,:,:].mean(axis=(0,1)))
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
x,y = m(lon, lat)
cf = m.pcolor(x,y,summer,cmap='Reds', vmin = 2, vmax = 3)
m.drawcoastlines(linewidth=0.5, linestyle='solid', color='gray', antialiased=1, ax=None, zorder=None)
m.fillcontinents(color='0.55', lake_color=None, ax=None, zorder=None, alpha=None)
ax.set_title('Summer', fontsize =30)


##FALL
ax = fig.add_subplot(1, 4, 4)
lon, lat, fall = adjust_pop_grid(ds.TLONG, ds.TLAT, TL_fall.zooTL_fall[:,:,:,:].mean(axis=(0,1)))
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
x,y = m(lon, lat)
cf = m.pcolor(x,y,fall,cmap='Reds', vmin = 2, vmax = 3)
m.drawcoastlines(linewidth=0.5, linestyle='solid', color='gray', antialiased=1, ax=None, zorder=None)
m.fillcontinents(color='0.55', lake_color=None, ax=None, zorder=None, alpha=None)
ax.set_title('Fall', fontsize =30);
cbar_ax = fig.add_axes([0.999, 0.3, 0.01, 0.47])
cb = fig.colorbar(cf, shrink=0.1, extend ='both',orientation='vertical', cax=cbar_ax)
cb.ax.tick_params(labelsize=20)
fig.tight_layout()
#fig.savefig('/glade/work/gabyn/case_notes/analysis_figures/TL_seasonal_AO_20year_clim.png', dpi=600, bbox_inches='tight')
# Out:
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 			NC4_get_vars: var->hdr.name zooTL_winter mem_nc_type 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_att: ncid 0xe0000 varid 10 name scale_factor
# 			nc4_get_att: ncid 0xe0000 varid 10 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xe0000 varid 10 name add_offset
# 			nc4_get_att: ncid 0xe0000 varid 10 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 			NC4_get_vars: var->hdr.name zooTL_winter mem_nc_type 6
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_var_all: ncid 0xe0000 varid 10
# 		NC4_inq_dim: ncid 0xe0000 dimid 0
# 		NC4_inq_dim: ncid 0xe0000 dimid 1
# 		NC4_inq_dim: ncid 0xe0000 dimid 2
# 		NC4_inq_dim: ncid 0xe0000 dimid 3
# 		NC4_inq_att: ncid 0xe0000 varid 10 name scale_factor
# 			nc4_get_att: ncid 0xe0000 varid 10 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xe0000 varid 10 name add_offset
# 			nc4_get_att: ncid 0xe0000 varid 10 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 			NC4_get_vars: var->hdr.name zooTL_spring mem_nc_type 6
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_att: ncid 0x100000 varid 10 name scale_factor
# 			nc4_get_att: ncid 0x100000 varid 10 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x100000 varid 10 name add_offset
# 			nc4_get_att: ncid 0x100000 varid 10 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 			NC4_get_vars: var->hdr.name zooTL_spring mem_nc_type 6
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_var_all: ncid 0x100000 varid 10
# 		NC4_inq_dim: ncid 0x100000 dimid 0
# 		NC4_inq_dim: ncid 0x100000 dimid 1
# 		NC4_inq_dim: ncid 0x100000 dimid 2
# 		NC4_inq_dim: ncid 0x100000 dimid 3
# 		NC4_inq_att: ncid 0x100000 varid 10 name scale_factor
# 			nc4_get_att: ncid 0x100000 varid 10 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x100000 varid 10 name add_offset
# 			nc4_get_att: ncid 0x100000 varid 10 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 			NC4_get_vars: var->hdr.name zooTL_summer mem_nc_type 6
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_att: ncid 0xf0000 varid 10 name scale_factor
# 			nc4_get_att: ncid 0xf0000 varid 10 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xf0000 varid 10 name add_offset
# 			nc4_get_att: ncid 0xf0000 varid 10 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 			NC4_get_vars: var->hdr.name zooTL_summer mem_nc_type 6
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_var_all: ncid 0xf0000 varid 10
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_att: ncid 0xf0000 varid 10 name scale_factor
# 			nc4_get_att: ncid 0xf0000 varid 10 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xf0000 varid 10 name add_offset
# 			nc4_get_att: ncid 0xf0000 varid 10 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 			NC4_get_vars: var->hdr.name zooTL_fall mem_nc_type 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_att: ncid 0xd0000 varid 10 name scale_factor
# 			nc4_get_att: ncid 0xd0000 varid 10 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 10 name add_offset
# 			nc4_get_att: ncid 0xd0000 varid 10 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 			NC4_get_vars: var->hdr.name zooTL_fall mem_nc_type 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 10
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_att: ncid 0xd0000 varid 10 name scale_factor
# 			nc4_get_att: ncid 0xd0000 varid 10 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 10 name add_offset
# 			nc4_get_att: ncid 0xd0000 varid 10 name add_offset attnum -1 mem_type 0

# %% [markdown]
# ## Import High vs Low temp, ice and NO3

# %%
# %%time
temp_ds_inter = xr.open_mfdataset('/glade/u/home/gabyn/scratch/SPECTRA/nc_files/temp_ds_inter_surface.nc');

# %%
## Calculate climatology for each grid cell
temp_ao_clim = np.nanmean(temp_ds_inter.TEMP,axis=0) # Size (384,320)
temp_ds = np.array(temp_ds_inter.TEMP)

# %%
# %%time
# For every grid cell in the Arctic Ocean 
# Create empty arrays filled with NaN's 
temp_arctic_anom = np.empty([62,12,384,320]) ; temp_arctic_anom[:] = np.nan

# Loop through the latitudes and longitudes to calculate anomalies and error values. 
for latitude in np.arange(0,384,1):
    for longitude in np.arange(0,320,1):
        temp_arctic_anom[:,:,latitude,longitude] = temp_ds[:,:,latitude,longitude]-temp_ao_clim[:,latitude,longitude]

# %%
# %%time
temp_arctic_anom_yearly = np.nanmean(temp_arctic_anom,axis=1) # size is now (62,384,320)

# Create empty arrays filled with NaN's 
pcen_90 = np.empty([384,320]) ; pcen_90[:] = np.nan
pcen_10 = np.empty([384,320]) ; pcen_10[:] = np.nan

# Loop through the latitudes and longitudes to calculate anomalies and error values. 
for latitude in np.arange(0,384,1):
    for longitude in np.arange(0,320,1):
    # index of array entry nearest to percentile value
        pcen_90[latitude,longitude]=np.nanpercentile(temp_arctic_anom_yearly[:,latitude,longitude],90,interpolation='nearest')
        pcen_10[latitude,longitude]=np.nanpercentile(temp_arctic_anom_yearly[:,latitude,longitude],10,interpolation='nearest')

# %%
# %%time
# Python3 code to demonstrate working of
# Creating Multidimensional dictionary
# Using defaultdict()
from collections import defaultdict
 
# Utility function to create dictionary
def multi_dict(K, type):
    if K == 1:
        return defaultdict(type)
    else:
        return defaultdict(lambda: multi_dict(K-1, type))
 
# Initialize dictionary
low_temp_years_arctic = {}
high_temp_years_arctic = {}
 
# Using defaultdict()
# Creating Multidimensional dictionary
# calling function
low_temp_years_arctic = multi_dict(2, int)
high_temp_years_arctic = multi_dict(2, int)
for latitude in np.arange(0,384,1):
    for longitude in np.arange(0,320,1):
        low_temp_years_arctic[latitude][longitude] = np.where(temp_arctic_anom_yearly[:,latitude,longitude] < pcen_10[latitude,longitude])
        high_temp_years_arctic[latitude][longitude] = np.where(temp_arctic_anom_yearly[:,latitude,longitude] > pcen_90[latitude,longitude])

# %%
# Loop through the latitudes and longitudes to calculate anomalies and error values. 
low_temp_years_summer = np.empty([384,320]) ; low_temp_years_summer[:] = np.nan
high_temp_years_summer = np.empty([384,320]) ; high_temp_years_summer[:] = np.nan

low_temp_years_spring = np.empty([384,320]) ; low_temp_years_spring[:] = np.nan
high_temp_years_spring = np.empty([384,320]) ; high_temp_years_spring[:] = np.nan

low_temp_years_fall = np.empty([384,320]) ; low_temp_years_fall[:] = np.nan
high_temp_years_fall = np.empty([384,320]) ; high_temp_years_fall[:] = np.nan

low_temp_years_winter = np.empty([384,320]) ; low_temp_years_winter[:] = np.nan
high_temp_years_winter = np.empty([384,320]) ; high_temp_years_winter[:] = np.nan
for latitude in np.arange(0,384,1):
    for longitude in np.arange(0,320,1):
        low_temp_years_summer[latitude,longitude] = np.nanmean(phyto_zoo_frac_summer[low_temp_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1))
        high_temp_years_summer[latitude,longitude] = np.nanmean(phyto_zoo_frac_summer[high_temp_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1)) 

        low_temp_years_spring[latitude,longitude] = np.nanmean(phyto_zoo_frac_spring[low_temp_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1)) 
        high_temp_years_spring[latitude,longitude]= np.nanmean(phyto_zoo_frac_spring[high_temp_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1)) 

        low_temp_years_fall[latitude,longitude] = np.nanmean(phyto_zoo_frac_fall[low_temp_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1)) 
        high_temp_years_fall[latitude,longitude] = np.nanmean(phyto_zoo_frac_fall[high_temp_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1))

        low_temp_years_winter[latitude,longitude]= np.nanmean(phyto_zoo_frac_winter[low_temp_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1)) 
        high_temp_years_winter[latitude,longitude] = np.nanmean(phyto_zoo_frac_winter[high_temp_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1))

# %%
# %%time
ECOSYS_IFRAC_ds_inter = xr.open_mfdataset('/glade/u/home/gabyn/scratch/SPECTRA/nc_files/ECOSYS_IFRAC_ds_inter_surface.nc');

# %%
## Calculate climatology for each grid cell
ice_ao_clim = np.nanmean(ECOSYS_IFRAC_ds_inter.ECOSYS_IFRAC,axis=0) # Size (12,384,320)
ECOSYS_IFRAC_ds = np.array(ECOSYS_IFRAC_ds_inter.ECOSYS_IFRAC)

# %%
# %%time
# For every grid cell in the Arctic Ocean 
# Create empty arrays filled with NaN's 
ice_arctic_anom = np.empty([62,12,384,320]) ; ice_arctic_anom[:] = np.nan

# Loop through the latitudes and longitudes to calculate anomalies and error values. 
for latitude in np.arange(0,384,1):
    for longitude in np.arange(0,320,1):
        ice_arctic_anom[:,:,latitude,longitude] = ECOSYS_IFRAC_ds[:,:,latitude,longitude]-ice_ao_clim[:,latitude,longitude]

# %%
ice_arctic_anom_yearly = np.nanmean(ice_arctic_anom,axis=1) # size is now (62,180,360)

# Create empty arrays filled with NaN's 
pcen_90_ice = np.empty([384,320]) ; pcen_90_ice[:] = np.nan
pcen_10_ice = np.empty([384,320]) ; pcen_10_ice[:] = np.nan

# Loop through the latitudes and longitudes to calculate anomalies and error values. 
for latitude in np.arange(0,384,1):
    for longitude in np.arange(0,320,1):
    # index of array entry nearest to percentile value
        pcen_90_ice[latitude,longitude]=np.nanpercentile(ice_arctic_anom_yearly[:,latitude,longitude],90,interpolation='nearest')
        pcen_10_ice[latitude,longitude]=np.nanpercentile(ice_arctic_anom_yearly[:,latitude,longitude],10,interpolation='nearest')

# %%
# Python3 code to demonstrate working of
# Creating Multidimensional dictionary
# Using defaultdict()
from collections import defaultdict
 
# Utility function to create dictionary
def multi_dict(K, type):
    if K == 1:
        return defaultdict(type)
    else:
        return defaultdict(lambda: multi_dict(K-1, type))
 
# Initialize dictionary
low_ice_years_arctic = {}
high_ice_years_arctic = {}
 
# Using defaultdict()
# Creating Multidimensional dictionary
# calling function
low_ice_years_arctic = multi_dict(2, int)
high_ice_years_arctic = multi_dict(2, int)
for latitude in np.arange(0,384,1):
    for longitude in np.arange(0,320,1):
        low_ice_years_arctic[latitude][longitude] = np.where(ice_arctic_anom_yearly[:,latitude,longitude] < pcen_10_ice[latitude,longitude])
        high_ice_years_arctic[latitude][longitude] = np.where(ice_arctic_anom_yearly[:,latitude,longitude] > pcen_90_ice[latitude,longitude])

# %%
# %%time
# Loop through the latitudes and longitudes to calculate anomalies and error values.
low_ice_years_summer = np.empty([384,320]) ; low_ice_years_summer[:] = np.nan
high_ice_years_summer = np.empty([384,320]) ; high_ice_years_summer[:] = np.nan

low_ice_years_spring = np.empty([384,320]) ; low_ice_years_spring[:] = np.nan
high_ice_years_spring = np.empty([384,320]) ; high_ice_years_spring[:] = np.nan

low_ice_years_fall = np.empty([384,320]) ; low_ice_years_fall[:] = np.nan
high_ice_years_fall = np.empty([384,320]) ; high_ice_years_fall[:] = np.nan

low_ice_years_winter = np.empty([384,320]) ; low_ice_years_winter[:] = np.nan
high_ice_years_winter = np.empty([384,320]) ; high_ice_years_winter[:] = np.nan
for latitude in np.arange(0,384,1):
    for longitude in np.arange(0,320,1):
        low_ice_years_summer[latitude,longitude] = np.nanmean(phyto_zoo_frac_summer[low_ice_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1))
        high_ice_years_summer[latitude,longitude] = np.nanmean(phyto_zoo_frac_summer[high_ice_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1)) 

        low_ice_years_spring[latitude,longitude] = np.nanmean(phyto_zoo_frac_spring[low_ice_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1)) 
        high_ice_years_spring[latitude,longitude]= np.nanmean(phyto_zoo_frac_spring[high_ice_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1)) 

        low_ice_years_fall[latitude,longitude] = np.nanmean(phyto_zoo_frac_fall[low_ice_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1)) 
        high_ice_years_fall[latitude,longitude] = np.nanmean(phyto_zoo_frac_fall[high_ice_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1))

        low_ice_years_winter[latitude,longitude]= np.nanmean(phyto_zoo_frac_winter[low_ice_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1)) 
        high_ice_years_winter[latitude,longitude] = np.nanmean(phyto_zoo_frac_winter[high_ice_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1))

# %%
# %%time
NO3_ds_inter = xr.open_mfdataset('/glade/u/home/gabyn/scratch/SPECTRA/nc_files/NO3_ds_inter_surface.nc');

# %%
# %%time
## Calculate climatology for each grid cell
no3_ao_clim = np.nanmean(NO3_ds_inter.NO3,axis=0) # Size (12,384,320)

# %%
NO3_ds = np.array(NO3_ds_inter.NO3)

# %%
# %%time
# For every grid cell in the Arctic Ocean 
# Create empty arrays filled with NaN's 
no3_arctic_anom = np.empty([62,12,384,320]) ; no3_arctic_anom[:] = np.nan

# Loop through the latitudes and longitudes to calculate anomalies and error values. 
for latitude in np.arange(0,384,1):
    for longitude in np.arange(0,320,1):
        no3_arctic_anom[:,:,latitude,longitude] = NO3_ds[:,:,latitude,longitude]-no3_ao_clim[:,latitude,longitude]

# %%
# %%time
no3_arctic_anom_yearly = np.nanmean(no3_arctic_anom,axis=1) # size is now (62,384,320)

# Create empty arrays filled with NaN's 
pcen_90_no3 = np.empty([384,320]) ; pcen_90_no3[:] = np.nan
pcen_10_no3 = np.empty([384,320]) ; pcen_10_no3[:] = np.nan

# Loop through the latitudes and longitudes to calculate anomalies and error values. 
for latitude in np.arange(0,384,1):
    for longitude in np.arange(0,320,1):
    # index of array entry nearest to percentile value
        pcen_90_no3[latitude,longitude]=np.nanpercentile(no3_arctic_anom_yearly[:,latitude,longitude],90,interpolation='nearest')
        pcen_10_no3[latitude,longitude]=np.nanpercentile(no3_arctic_anom_yearly[:,latitude,longitude],10,interpolation='nearest')

# %%
# Python3 code to demonstrate working of
# Creating Multidimensional dictionary
# Using defaultdict()
from collections import defaultdict
 
# Utility function to create dictionary
def multi_dict(K, type):
    if K == 1:
        return defaultdict(type)
    else:
        return defaultdict(lambda: multi_dict(K-1, type))
 
# Initialize dictionary
low_no3_years_arctic = {}
high_no3_years_arctic = {}
 
# Using defaultdict()
# Creating Multidimensional dictionary
# calling function
low_no3_years_arctic = multi_dict(2, int)
high_no3_years_arctic = multi_dict(2, int)
for latitude in np.arange(0,384,1):
    for longitude in np.arange(0,320,1):
        low_no3_years_arctic[latitude][longitude] = np.where(no3_arctic_anom_yearly[:,latitude,longitude] < pcen_10_no3[latitude,longitude])
        high_no3_years_arctic[latitude][longitude] = np.where(no3_arctic_anom_yearly[:,latitude,longitude] > pcen_90_no3[latitude,longitude])

# %%
# %%time
# Loop through the latitudes and longitudes to calculate anomalies and error values. 
low_no3_years_summer = np.empty([384,320]) ; low_no3_years_summer[:] = np.nan
high_no3_years_summer = np.empty([384,320]) ; high_no3_years_summer[:] = np.nan

low_no3_years_spring = np.empty([384,320]) ; low_no3_years_spring[:] = np.nan
high_no3_years_spring = np.empty([384,320]) ; high_no3_years_spring[:] = np.nan

low_no3_years_fall = np.empty([384,320]) ; low_no3_years_fall[:] = np.nan
high_no3_years_fall = np.empty([384,320]) ; high_no3_years_fall[:] = np.nan

low_no3_years_winter = np.empty([384,320]) ; low_no3_years_winter[:] = np.nan
high_no3_years_winter = np.empty([384,320]) ; high_no3_years_winter[:] = np.nan
for latitude in np.arange(0,384,1):
    for longitude in np.arange(0,320,1):
        low_no3_years_summer[latitude,longitude] = np.nanmean(phyto_zoo_frac_summer[low_no3_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1))
        high_no3_years_summer[latitude,longitude] = np.nanmean(phyto_zoo_frac_summer[high_no3_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1)) 

        low_no3_years_spring[latitude,longitude] = np.nanmean(phyto_zoo_frac_spring[low_no3_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1)) 
        high_no3_years_spring[latitude,longitude]= np.nanmean(phyto_zoo_frac_spring[high_no3_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1)) 

        low_no3_years_fall[latitude,longitude] = np.nanmean(phyto_zoo_frac_fall[low_no3_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1)) 
        high_no3_years_fall[latitude,longitude] = np.nanmean(phyto_zoo_frac_fall[high_no3_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1))

        low_no3_years_winter[latitude,longitude]= np.nanmean(phyto_zoo_frac_winter[low_no3_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1)) 
        high_no3_years_winter[latitude,longitude] = np.nanmean(phyto_zoo_frac_winter[high_no3_years_arctic[latitude][longitude],latitude,longitude],axis=(0,1))

# %%
from mpl_toolkits.basemap import Basemap
lev = np.arange(0, 10, 0.05)
norm = colors.TwoSlopeNorm(vmin=lev[0], vmax=lev[-1], vcenter=1)
fig = plt.figure(figsize=(20, 20))

#### 62 year average!!! 

# Winter TLeq = 3 (62yr average)
ax = fig.add_subplot(4, 4, 1)
lon, lat, winter = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_frac_winter,axis=0))
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, winter, cmap='PiYG', vmin = 0, vmax = 10, norm=norm);
ax.set_title('Winter', fontsize=20)

# Spring TLeq = 3, (62yr average)
ax = fig.add_subplot(4, 4, 2)
lon, lat, spring = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_frac_spring,axis=0))
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
cf = m.pcolor(x, y, spring, cmap='PiYG', vmin = 0, vmax = 10,norm=norm);
ax.set_title('Spring, grazing fraction', fontsize=20)

# Summer TLeq = 3, (62 yr average)
ax = fig.add_subplot(4, 4, 3)
lon, lat, summer = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_frac_summer,axis=0))
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
cf = m.pcolor(x, y, summer, cmap='PiYG', vmin = 0, vmax = 15,norm=norm);
ax.set_title('Summer', fontsize=20)

# Fall TLeq = 3, (62 yr average)
ax = fig.add_subplot(4, 4, 4)
lon, lat, fall = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_frac_fall,axis=0))
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
cf = m.pcolor(x, y, fall, cmap='PiYG',vmin = 0, vmax = 10,norm=norm);
cbar_ax = fig.add_axes([0.999, 0.79, 0.01, 0.15])
cb = fig.colorbar(cf, shrink=0.1, extend ='both',orientation='vertical', cax=cbar_ax)
ax.set_title('Fall', fontsize=20)
cb.ax.tick_params(labelsize=20)

########## Differences!!! 
vminn =-2
vmaxx=2
# Winter, % difference of catch from high and low temperature years. 
ax = fig.add_subplot(4, 4, 5)
winter_temp_diff = high_temp_years_winter-low_temp_years_winter
lon, lat, w_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, winter_temp_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, w_diff, cmap='RdBu_r',vmin=vminn,vmax=vmaxx);

# Spring, % difference of catch from high and low temperature years. 
ax = fig.add_subplot(4, 4, 6)
spring_temp_diff = high_temp_years_spring-low_temp_years_spring
lon, lat, sp_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, spring_temp_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
cf = m.pcolor(x, y, sp_diff, cmap='RdBu_r',vmin=vminn,vmax=vmaxx);

# Summer, % difference of catch from high and low temperature years. 
ax = fig.add_subplot(4, 4, 7)
summer_temp_diff = high_temp_years_summer-low_temp_years_summer
lon, lat, s_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, summer_temp_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
cf = m.pcolor(x, y, s_diff, cmap='RdBu_r',vmin=vminn,vmax=vmaxx);

# Fall, % difference of catch from high and low temperature years. 
ax = fig.add_subplot(4, 4, 8)
fall_temp_diff = high_temp_years_fall-low_temp_years_fall
lon, lat, f_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, fall_temp_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
cf = m.pcolor(x, y, f_diff, cmap='RdBu_r',vmin=vminn,vmax=vmaxx);
cbar_ax = fig.add_axes([0.999, 0.3, 0.01, 0.15])
cb = fig.colorbar(cf, shrink=0.1, extend ='both',orientation='vertical', cax=cbar_ax)
cb.ax.tick_params(labelsize=20)

## Ice Fraction

# Winter, % difference of catch from high and low ice fraction  years. 
ax = fig.add_subplot(4, 4, 9)
winter_ice_diff = high_ice_years_winter-low_ice_years_winter
lon, lat, w_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, winter_ice_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
cf = m.pcolor(x, y, w_diff, cmap='RdBu_r',vmin=vminn,vmax=vmaxx);

# Spring, % difference of catch from high and low ice fraction years. 
ax = fig.add_subplot(4, 4, 10)
spring_ice_diff = high_ice_years_spring-low_ice_years_spring
lon, lat, sp_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, spring_ice_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
cf = m.pcolor(x, y, sp_diff, cmap='RdBu_r',vmin=vminn,vmax=vmaxx);

# Summer, % difference of catch from high and low ice fraction  years. 
ax = fig.add_subplot(4, 4, 11)
summer_ice_diff = high_ice_years_summer-low_ice_years_summer
lon, lat, s_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, summer_ice_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
cf = m.pcolor(x, y, s_diff, cmap='RdBu_r',vmin=vminn,vmax=vmaxx);

# Fall, % difference of catch from high and low ice fraction  years. 
ax = fig.add_subplot(4, 4, 12)
fall_ice_diff = high_ice_years_fall-low_ice_years_fall
lon, lat, f_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, fall_ice_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
cf = m.pcolor(x, y, f_diff, cmap='RdBu_r',vmin=vminn,vmax=vmaxx);
cbar_ax = fig.add_axes([0.999, 0.548, 0.01, 0.15])
cb = fig.colorbar(cf, shrink=0.1, extend ='both',orientation='vertical', cax=cbar_ax)
cb.ax.tick_params(labelsize=20)


# Winter, % difference of catch from high and low NO$_3$  years. 
ax = fig.add_subplot(4, 4, 13)
winter_no3_diff = high_no3_years_winter-low_no3_years_winter
lon, lat, w_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, winter_no3_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
cf = m.pcolor(x, y, w_diff, cmap='RdBu_r',vmin=vminn,vmax=vmaxx);
cb.ax.tick_params(labelsize=20)

# Spring, % difference of catch from high and low NO$_3$ years. 
ax = fig.add_subplot(4, 4, 14)
spring_no3_diff = high_no3_years_spring-low_no3_years_spring
lon, lat, sp_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, spring_no3_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
cf = m.pcolor(x, y, sp_diff, cmap='RdBu_r',vmin=vminn,vmax=vmaxx);

# Summer, % difference of catch from high and low NO$_3$  years. 
ax = fig.add_subplot(4, 4, 15)
summer_no3_diff = high_no3_years_summer-low_no3_years_summer
lon, lat, s_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, summer_no3_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
cf = m.pcolor(x, y, s_diff, cmap='RdBu_r',vmin=vminn,vmax=vmaxx);

# Fall, % difference of catch from high and low NO$_3$  years. 
ax = fig.add_subplot(4, 4, 16)
fall_no3_diff = high_no3_years_fall-low_no3_years_fall
lon, lat, f_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, fall_no3_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
cf = m.pcolor(x, y, f_diff, cmap='RdBu_r',vmin=vminn,vmax=vmaxx);
cbar_ax = fig.add_axes([0.9999, 0.065, 0.01, 0.15])
cb = fig.colorbar(cf, shrink=0.1, extend ='both',orientation='vertical', cax=cbar_ax)
cb.ax.tick_params(labelsize=20)
plt.tight_layout()

fig.savefig('/glade/u/home/gabyn/work/case_notes/analysis_figures/quarterly_grazing_fraction_interannual.png',dpi=200, bbox_inches='tight')
