# %% [markdown]
# # Checking differences in NO$_3$ with the World Ocean Atlas from 1981 to 2010 - so a bit longer than this time series

# %%
import warnings
warnings.simplefilter("ignore") # Silence warnings
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import numpy as np
from matplotlib.pyplot import figure
import numpy.ma as ma
from netCDF4 import Dataset as NetCDFFile
import glob
import cartopy
import cartopy.crs as ccrs
import pylab 
from copy import deepcopy
import pandas as pd
import matplotlib
import matplotlib.colors as colors
from cartopy.util import add_cyclic_point
import matplotlib.gridspec as gridspec
plt.rcParams['mathtext.default']='regular'
from collections import OrderedDict
import cmocean
import matplotlib.cm as cm
import matplotlib as mpl
import seaborn as sns

# %%
class MidpointNormalize(colors.Normalize):
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        colors.Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        if clip is None:
            clip = self.clip

        result, is_scalar = self.process_value(value)

        self.autoscale_None(result)
        vmin, vmax, midpoint = self.vmin, self.vmax, self.midpoint

        if not (vmin < midpoint < vmax):
            raise ValueError("midpoint must be between maxvalue and minvalue.")
        elif vmin == vmax:
            result.fill(0) # Or should it be all masked? Or 0.5?
        elif vmin > vmax:
            raise ValueError("maxvalue must be bigger than minvalue")
        else:
            vmin = float(vmin)
            vmax = float(vmax)
            if clip:
                mask = np.ma.getmask(result)
                result = np.ma.array(np.clip(result.filled(vmax), vmin, vmax),
                                  mask=mask)

            # ma division is very slow; we can take a shortcut
            resdat = result.data

            #First scale to -1 to 1 range, than to from 0 to 1.
            resdat -= midpoint
            resdat[resdat>0] /= abs(vmax - midpoint)
            resdat[resdat<0] /= abs(vmin - midpoint)

            resdat /= 2.
            resdat += 0.5
            result = np.ma.array(resdat, mask=result.mask, copy=False)

        if is_scalar:
            result = result[0]
        return result

# %% [markdown]
# # input file

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %% [markdown]
# ## World Ocean Atlas NO$_3$
#     - n01_01.nc - January
#     - n02_01.nc - February
#     - n03_01.nc - March
#     - n04_01.nc - April
#     - n05_01.nc - May
#     - n06_01.nc - June
#     - n07_01.nc - July
#     - n08_01.nc - August
#     - n09_01.nc - September
#     - n10_01.nc - October
#     - n11_01.nc - November
#     - n12_01.nc - December
#     - woa18_all_n00_01.nc - Annual

# %% [markdown]
# path = '/glade/derecho/scratch/gabyn/obs/NO3/'
# ds_01 = xr.open_mfdataset(f'{path}woa18_all_n01_01.nc',decode_times=False)
# ds_02 = xr.open_mfdataset(f'{path}woa18_all_n02_01.nc',decode_times=False)
# ds_03 = xr.open_mfdataset(f'{path}woa18_all_n03_01.nc',decode_times=False)
# ds_04 = xr.open_mfdataset(f'{path}woa18_all_n04_01.nc',decode_times=False)
# ds_05 = xr.open_mfdataset(f'{path}woa18_all_n05_01.nc',decode_times=False)
# ds_06 = xr.open_mfdataset(f'{path}woa18_all_n06_01.nc',decode_times=False)
# ds_07 = xr.open_mfdataset(f'{path}woa18_all_n07_01.nc',decode_times=False)
# ds_08 = xr.open_mfdataset(f'{path}woa18_all_n08_01.nc',decode_times=False)
# ds_09 = xr.open_mfdataset(f'{path}woa18_all_n09_01.nc',decode_times=False)
# ds_10 = xr.open_mfdataset(f'{path}/woa18_all_n10_01.nc',decode_times=False)
# ds_11 = xr.open_mfdataset(f'{path}woa18_all_n11_01.nc',decode_times=False)
# ds_12 = xr.open_mfdataset(f'{path}woa18_all_n12_01.nc',decode_times=False)

# %%
ds_all = xr.open_mfdataset('/glade/derecho/scratch/gabyn/obs/NO3/woa18_all_n00_01.nc',decode_times=False)
# Out:
# 	NC4_open: path /glade/derecho/scratch/gabyn/obs/NO3/woa18_all_n00_01.nc mode 4096 params 0
# 	HDF5 error messages turned on.
# 			nc4_open_file: path /glade/derecho/scratch/gabyn/obs/NO3/woa18_all_n00_01.nc mode 4096
# 			nc4_grp_list_add: name /
# 			nc4_rec_read_metadata: grp->hdr.name /
# 			found dataset nbounds
# 			found dataset crs
# 			found dataset lat
# 			found dataset lat_bnds
# 			found dataset lon
# 			found dataset lon_bnds
# 			found dataset depth
# 			found dataset depth_bnds
# 			found dataset time
# 			found dataset climatology_bounds
# 			found dataset n_an
# 			found dataset n_mn
# 			found dataset n_dd
# 			found dataset n_sd
# 			found dataset n_se
# 			found dataset n_oa
# 			found dataset n_gp
# ERROR: Invalid _NCProperties attribute
# 		*** NetCDF-4 Internal Metadata: int_ncid 0x10000 ext_ncid 0x10000
# 		FILE - path: /glade/derecho/scratch/gabyn/obs/NO3/woa18_all_n00_01.nc cmode: 0x1108 parallel: 0 redef: 0 fill_mode: 0 no_write: 1 next_nc_grpid: 1
# 		 GROUP - / nc_grpid: 0 nvars: 16 natts: 0
# 		 DIMENSION - dimid: 0 name: nbounds len: 2 unlimited: 0
# 		 DIMENSION - dimid: 1 name: lat len: 180 unlimited: 0
# 		 DIMENSION - dimid: 2 name: lon len: 360 unlimited: 0
# 		 DIMENSION - dimid: 3 name: depth len: 102 unlimited: 0
# 		 DIMENSION - dimid: 4 name: time len: 1 unlimited: 0
# 		 VARIABLE - varid: 0 name: crs ndims: 0 dimscale: 0 dimids: -
# 		 VARIABLE - varid: 1 name: lat ndims: 1 dimscale: 1 dimids: 1
# 		 VARIABLE - varid: 2 name: lat_bnds ndims: 2 dimscale: 0 dimids: 1 0
# 		 VARIABLE - varid: 3 name: lon ndims: 1 dimscale: 1 dimids: 2
# 		 VARIABLE - varid: 4 name: lon_bnds ndims: 2 dimscale: 0 dimids: 2 0
# 		 VARIABLE - varid: 5 name: depth ndims: 1 dimscale: 1 dimids: 3
# 		 VARIABLE - varid: 6 name: depth_bnds ndims: 2 dimscale: 0 dimids: 3 0
# 		 VARIABLE - varid: 7 name: time ndims: 1 dimscale: 1 dimids: 4
# 		 VARIABLE - varid: 8 name: climatology_bounds ndims: 2 dimscale: 0 dimids: 4 0
# 		 VARIABLE - varid: 9 name: n_an ndims: 4 dimscale: 0 dimids: 4 3 1 2
# 		 VARIABLE - varid: 10 name: n_mn ndims: 4 dimscale: 0 dimids: 4 3 1 2
# 		 VARIABLE - varid: 11 name: n_dd ndims: 4 dimscale: 0 dimids: 4 3 1 2
# 		 VARIABLE - varid: 12 name: n_sd ndims: 4 dimscale: 0 dimids: 4 3 1 2
# 		 VARIABLE - varid: 13 name: n_se ndims: 4 dimscale: 0 dimids: 4 3 1 2
# 		 VARIABLE - varid: 14 name: n_oa ndims: 4 dimscale: 0 dimids: 4 3 1 2
# 		 VARIABLE - varid: 15 name: n_gp ndims: 4 dimscale: 0 dimids: 4 3 1 2
# 		nc_inq_format: ncid 0x10000
# 		NC4_inq_format_extended: ncid 0x10000
# 		nc_inq_typeids: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 			nc4_att_list_add: name grid_mapping_name
# 			nc4_att_list_add: name epsg_code
# 			nc4_att_list_add: name longitude_of_prime_meridian
# 			nc4_att_list_add: name semi_major_axis
# 			nc4_att_list_add: name inverse_flattening
# 		nc_inq_attname: ncid 0x10000 varid 0 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 0 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 0 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 0 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 0 attnum 4
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq: ncid 0x10000
# 			nc4_att_list_add: name Conventions
# 			nc4_att_list_add: name title
# 			nc4_att_list_add: name summary
# 			nc4_att_list_add: name references
# 			nc4_att_list_add: name institution
# 			nc4_att_list_add: name comment
# 			nc4_att_list_add: name id
# 			nc4_att_list_add: name naming_authority
# 			nc4_att_list_add: name sea_name
# 			nc4_att_list_add: name time_coverage_start
# 			nc4_att_list_add: name time_coverage_end
# 			nc4_att_list_add: name time_coverage_duration
# 			nc4_att_list_add: name time_coverage_resolution
# 			nc4_att_list_add: name geospatial_lat_min
# 			nc4_att_list_add: name geospatial_lat_max
# 			nc4_att_list_add: name geospatial_lon_min
# 			nc4_att_list_add: name geospatial_lon_max
# 			nc4_att_list_add: name geospatial_vertical_min
# 			nc4_att_list_add: name geospatial_vertical_max
# 			nc4_att_list_add: name geospatial_lat_units
# 			nc4_att_list_add: name geospatial_lat_resolution
# 			nc4_att_list_add: name geospatial_lon_units
# 			nc4_att_list_add: name geospatial_lon_resolution
# 			nc4_att_list_add: name geospatial_vertical_units
# 			nc4_att_list_add: name geospatial_vertical_resolution
# 			nc4_att_list_add: name geospatial_vertical_positive
# 			nc4_att_list_add: name creator_name
# 			nc4_att_list_add: name creator_email
# 			nc4_att_list_add: name creator_url
# 			nc4_att_list_add: name creator_type
# 			nc4_att_list_add: name creator_institution
# 			nc4_att_list_add: name project
# 			nc4_att_list_add: name processing_level
# 			nc4_att_list_add: name keywords
# 			nc4_att_list_add: name keywords_vocabulary
# 			nc4_att_list_add: name standard_name_vocabulary
# 			nc4_att_list_add: name contributor_name
# 			nc4_att_list_add: name contributor_role
# 			nc4_att_list_add: name cdm_data_type
# 			nc4_att_list_add: name publisher_name
# 			nc4_att_list_add: name publisher_institution
# 			nc4_att_list_add: name publisher_type
# 			nc4_att_list_add: name publisher_url
# 			nc4_att_list_add: name publisher_email
# 			nc4_att_list_add: name nodc_template_version
# 			nc4_att_list_add: name license
# 			nc4_att_list_add: name metadata_link
# 			nc4_att_list_add: name date_created
# 			nc4_att_list_add: name date_modified
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 			nc4_att_list_add: name standard_name
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name units
# 			nc4_att_list_add: name axis
# 			nc4_att_list_add: name bounds
# 		nc_inq_attname: ncid 0x10000 varid 1 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 1 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 1 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 1 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 1 attnum 4
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 			nc4_att_list_add: name comment
# 		nc_inq_attname: ncid 0x10000 varid 2 attnum 0
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 			nc4_att_list_add: name standard_name
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name units
# 			nc4_att_list_add: name axis
# 			nc4_att_list_add: name bounds
# 		nc_inq_attname: ncid 0x10000 varid 3 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 3 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 3 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 3 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 3 attnum 4
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 			nc4_att_list_add: name comment
# 		nc_inq_attname: ncid 0x10000 varid 4 attnum 0
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 			nc4_att_list_add: name standard_name
# 			nc4_att_list_add: name bounds
# 			nc4_att_list_add: name positive
# 			nc4_att_list_add: name units
# 			nc4_att_list_add: name axis
# 		nc_inq_attname: ncid 0x10000 varid 5 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 5 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 5 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 5 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 5 attnum 4
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 			nc4_att_list_add: name comment
# 		nc_inq_attname: ncid 0x10000 varid 6 attnum 0
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 			nc4_att_list_add: name standard_name
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name units
# 			nc4_att_list_add: name axis
# 			nc4_att_list_add: name climatology
# 		nc_inq_attname: ncid 0x10000 varid 7 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 7 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 7 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 7 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 7 attnum 4
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 			nc4_att_list_add: name comment
# 		nc_inq_attname: ncid 0x10000 varid 8 attnum 0
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 			nc4_att_list_add: name standard_name
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name coordinates
# 			nc4_att_list_add: name cell_methods
# 			nc4_att_list_add: name grid_mapping
# 			nc4_att_list_add: name units
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0x10000 varid 9 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 9 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 9 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 9 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 9 attnum 4
# 		nc_inq_attname: ncid 0x10000 varid 9 attnum 5
# 		nc_inq_attname: ncid 0x10000 varid 9 attnum 6
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 			nc4_att_list_add: name standard_name
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name coordinates
# 			nc4_att_list_add: name cell_methods
# 			nc4_att_list_add: name grid_mapping
# 			nc4_att_list_add: name units
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0x10000 varid 10 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 10 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 10 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 10 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 10 attnum 4
# 		nc_inq_attname: ncid 0x10000 varid 10 attnum 5
# 		nc_inq_attname: ncid 0x10000 varid 10 attnum 6
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 			nc4_att_list_add: name standard_name
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name coordinates
# 			nc4_att_list_add: name cell_methods
# 			nc4_att_list_add: name grid_mapping
# 			nc4_att_list_add: name units
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0x10000 varid 11 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 11 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 11 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 11 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 11 attnum 4
# 		nc_inq_attname: ncid 0x10000 varid 11 attnum 5
# 		nc_inq_attname: ncid 0x10000 varid 11 attnum 6
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name coordinates
# 			nc4_att_list_add: name cell_methods
# 			nc4_att_list_add: name grid_mapping
# 			nc4_att_list_add: name units
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0x10000 varid 12 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 12 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 12 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 12 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 12 attnum 4
# 		nc_inq_attname: ncid 0x10000 varid 12 attnum 5
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 			nc4_att_list_add: name standard_name
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name coordinates
# 			nc4_att_list_add: name cell_methods
# 			nc4_att_list_add: name grid_mapping
# 			nc4_att_list_add: name units
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0x10000 varid 13 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 13 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 13 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 13 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 13 attnum 4
# 		nc_inq_attname: ncid 0x10000 varid 13 attnum 5
# 		nc_inq_attname: ncid 0x10000 varid 13 attnum 6
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 			nc4_att_list_add: name standard_name
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name coordinates
# 			nc4_att_list_add: name cell_methods
# 			nc4_att_list_add: name grid_mapping
# 			nc4_att_list_add: name units
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0x10000 varid 14 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 14 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 14 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 14 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 14 attnum 4
# 		nc_inq_attname: ncid 0x10000 varid 14 attnum 5
# 		nc_inq_attname: ncid 0x10000 varid 14 attnum 6
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name coordinates
# 			nc4_att_list_add: name cell_methods
# 			nc4_att_list_add: name grid_mapping
# 			nc4_att_list_add: name units
# 			nc4_att_list_add: name _FillValue
# 		nc_inq_attname: ncid 0x10000 varid 15 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 15 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 15 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 15 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 15 attnum 4
# 		nc_inq_attname: ncid 0x10000 varid 15 attnum 5
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		nc_inq_attname: ncid 0x10000 varid 0 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 0 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 0 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 0 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 0 attnum 4
# 		NC4_inq_att: ncid 0x10000 varid 0 name grid_mapping_name
# 			nc4_get_att: ncid 0x10000 varid 0 name grid_mapping_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 0 name grid_mapping_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 0 name epsg_code
# 			nc4_get_att: ncid 0x10000 varid 0 name epsg_code attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 0 name epsg_code attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 0 name longitude_of_prime_meridian
# 			nc4_get_att: ncid 0x10000 varid 0 name longitude_of_prime_meridian attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 0 name longitude_of_prime_meridian
# 			nc4_get_att: ncid 0x10000 varid 0 name longitude_of_prime_meridian attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 0 name longitude_of_prime_meridian attnum -1 mem_type 5
# 		NC4_inq_att: ncid 0x10000 varid 0 name semi_major_axis
# 			nc4_get_att: ncid 0x10000 varid 0 name semi_major_axis attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 0 name semi_major_axis
# 			nc4_get_att: ncid 0x10000 varid 0 name semi_major_axis attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 0 name semi_major_axis attnum -1 mem_type 5
# 		NC4_inq_att: ncid 0x10000 varid 0 name inverse_flattening
# 			nc4_get_att: ncid 0x10000 varid 0 name inverse_flattening attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 0 name inverse_flattening
# 			nc4_get_att: ncid 0x10000 varid 0 name inverse_flattening attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 0 name inverse_flattening attnum -1 mem_type 5
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		nc_inq_attname: ncid 0x10000 varid 1 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 1 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 1 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 1 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 1 attnum 4
# 		NC4_inq_att: ncid 0x10000 varid 1 name standard_name
# 			nc4_get_att: ncid 0x10000 varid 1 name standard_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 1 name standard_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 1 name long_name
# 			nc4_get_att: ncid 0x10000 varid 1 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 1 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 1 name units
# 			nc4_get_att: ncid 0x10000 varid 1 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 1 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 1 name axis
# 			nc4_get_att: ncid 0x10000 varid 1 name axis attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 1 name axis attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 1 name bounds
# 			nc4_get_att: ncid 0x10000 varid 1 name bounds attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 1 name bounds attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		nc_inq_attname: ncid 0x10000 varid 2 attnum 0
# 		NC4_inq_att: ncid 0x10000 varid 2 name comment
# 			nc4_get_att: ncid 0x10000 varid 2 name comment attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 2 name comment attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		nc_inq_attname: ncid 0x10000 varid 3 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 3 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 3 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 3 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 3 attnum 4
# 		NC4_inq_att: ncid 0x10000 varid 3 name standard_name
# 			nc4_get_att: ncid 0x10000 varid 3 name standard_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 3 name standard_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 3 name long_name
# 			nc4_get_att: ncid 0x10000 varid 3 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 3 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 3 name units
# 			nc4_get_att: ncid 0x10000 varid 3 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 3 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 3 name axis
# 			nc4_get_att: ncid 0x10000 varid 3 name axis attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 3 name axis attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 3 name bounds
# 			nc4_get_att: ncid 0x10000 varid 3 name bounds attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 3 name bounds attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		nc_inq_attname: ncid 0x10000 varid 4 attnum 0
# 		NC4_inq_att: ncid 0x10000 varid 4 name comment
# 			nc4_get_att: ncid 0x10000 varid 4 name comment attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 4 name comment attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		nc_inq_attname: ncid 0x10000 varid 5 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 5 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 5 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 5 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 5 attnum 4
# 		NC4_inq_att: ncid 0x10000 varid 5 name standard_name
# 			nc4_get_att: ncid 0x10000 varid 5 name standard_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 5 name standard_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 5 name bounds
# 			nc4_get_att: ncid 0x10000 varid 5 name bounds attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 5 name bounds attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 5 name positive
# 			nc4_get_att: ncid 0x10000 varid 5 name positive attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 5 name positive attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 5 name units
# 			nc4_get_att: ncid 0x10000 varid 5 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 5 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 5 name axis
# 			nc4_get_att: ncid 0x10000 varid 5 name axis attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 5 name axis attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		nc_inq_attname: ncid 0x10000 varid 6 attnum 0
# 		NC4_inq_att: ncid 0x10000 varid 6 name comment
# 			nc4_get_att: ncid 0x10000 varid 6 name comment attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 6 name comment attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		NC4_inq_var_all: ncid 0x10000 varid 6
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		nc_inq_attname: ncid 0x10000 varid 7 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 7 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 7 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 7 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 7 attnum 4
# 		NC4_inq_att: ncid 0x10000 varid 7 name standard_name
# 			nc4_get_att: ncid 0x10000 varid 7 name standard_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 7 name standard_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 7 name long_name
# 			nc4_get_att: ncid 0x10000 varid 7 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 7 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 7 name units
# 			nc4_get_att: ncid 0x10000 varid 7 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 7 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 7 name axis
# 			nc4_get_att: ncid 0x10000 varid 7 name axis attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 7 name axis attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 7 name climatology
# 			nc4_get_att: ncid 0x10000 varid 7 name climatology attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 7 name climatology attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		nc_inq_attname: ncid 0x10000 varid 8 attnum 0
# 		NC4_inq_att: ncid 0x10000 varid 8 name comment
# 			nc4_get_att: ncid 0x10000 varid 8 name comment attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 8 name comment attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		NC4_inq_var_all: ncid 0x10000 varid 8
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 0
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		nc_inq_attname: ncid 0x10000 varid 9 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 9 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 9 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 9 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 9 attnum 4
# 		nc_inq_attname: ncid 0x10000 varid 9 attnum 5
# 		nc_inq_attname: ncid 0x10000 varid 9 attnum 6
# 		NC4_inq_att: ncid 0x10000 varid 9 name standard_name
# 			nc4_get_att: ncid 0x10000 varid 9 name standard_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 9 name standard_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 9 name long_name
# 			nc4_get_att: ncid 0x10000 varid 9 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 9 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 9 name coordinates
# 			nc4_get_att: ncid 0x10000 varid 9 name coordinates attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 9 name coordinates attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 9 name cell_methods
# 			nc4_get_att: ncid 0x10000 varid 9 name cell_methods attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 9 name cell_methods attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 9 name grid_mapping
# 			nc4_get_att: ncid 0x10000 varid 9 name grid_mapping attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 9 name grid_mapping attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 9 name units
# 			nc4_get_att: ncid 0x10000 varid 9 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 9 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 9 name _FillValue
# 			nc4_get_att: ncid 0x10000 varid 9 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 9 name _FillValue
# 			nc4_get_att: ncid 0x10000 varid 9 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 9 name _FillValue attnum -1 mem_type 5
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		nc_inq_attname: ncid 0x10000 varid 10 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 10 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 10 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 10 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 10 attnum 4
# 		nc_inq_attname: ncid 0x10000 varid 10 attnum 5
# 		nc_inq_attname: ncid 0x10000 varid 10 attnum 6
# 		NC4_inq_att: ncid 0x10000 varid 10 name

# %%
### First 20 year climatology GNG595
file = '/glade/derecho/scratch/gabyn/SPECTRA_hindcast/SPECTRA_1990_2009/GNG595_2ndcycle_1990-2009_clim/regrid'
newNCDFfiles1 = sorted(glob.glob(f'{file}/regrid_GNG595_NO3.*.nc', recursive=True),
                      key=numericalSort)

ds = xr.open_mfdataset(newNCDFfiles1,concat_dim='time', combine='nested')
# Out:
# standard_name
# 			nc4_get_att: ncid 0x10000 varid 10 name standard_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 10 name standard_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 10 name long_name
# 			nc4_get_att: ncid 0x10000 varid 10 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 10 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 10 name coordinates
# 			nc4_get_att: ncid 0x10000 varid 10 name coordinates attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 10 name coordinates attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 10 name cell_methods
# 			nc4_get_att: ncid 0x10000 varid 10 name cell_methods attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 10 name cell_methods attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 10 name grid_mapping
# 			nc4_get_att: ncid 0x10000 varid 10 name grid_mapping attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 10 name grid_mapping attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 10 name units
# 			nc4_get_att: ncid 0x10000 varid 10 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 10 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 10 name _FillValue
# 			nc4_get_att: ncid 0x10000 varid 10 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 10 name _FillValue
# 			nc4_get_att: ncid 0x10000 varid 10 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 10 name _FillValue attnum -1 mem_type 5
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		NC4_inq_var_all: ncid 0x10000 varid 10
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		nc_inq_attname: ncid 0x10000 varid 11 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 11 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 11 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 11 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 11 attnum 4
# 		nc_inq_attname: ncid 0x10000 varid 11 attnum 5
# 		nc_inq_attname: ncid 0x10000 varid 11 attnum 6
# 		NC4_inq_att: ncid 0x10000 varid 11 name standard_name
# 			nc4_get_att: ncid 0x10000 varid 11 name standard_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 11 name standard_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 11 name long_name
# 			nc4_get_att: ncid 0x10000 varid 11 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 11 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 11 name coordinates
# 			nc4_get_att: ncid 0x10000 varid 11 name coordinates attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 11 name coordinates attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 11 name cell_methods
# 			nc4_get_att: ncid 0x10000 varid 11 name cell_methods attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 11 name cell_methods attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 11 name grid_mapping
# 			nc4_get_att: ncid 0x10000 varid 11 name grid_mapping attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 11 name grid_mapping attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 11 name units
# 			nc4_get_att: ncid 0x10000 varid 11 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 11 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 11 name _FillValue
# 			nc4_get_att: ncid 0x10000 varid 11 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 11 name _FillValue
# 			nc4_get_att: ncid 0x10000 varid 11 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 11 name _FillValue attnum -1 mem_type 4
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		NC4_inq_var_all: ncid 0x10000 varid 11
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		nc_inq_attname: ncid 0x10000 varid 12 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 12 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 12 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 12 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 12 attnum 4
# 		nc_inq_attname: ncid 0x10000 varid 12 attnum 5
# 		NC4_inq_att: ncid 0x10000 varid 12 name long_name
# 			nc4_get_att: ncid 0x10000 varid 12 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 12 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 12 name coordinates
# 			nc4_get_att: ncid 0x10000 varid 12 name coordinates attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 12 name coordinates attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 12 name cell_methods
# 			nc4_get_att: ncid 0x10000 varid 12 name cell_methods attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 12 name cell_methods attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 12 name grid_mapping
# 			nc4_get_att: ncid 0x10000 varid 12 name grid_mapping attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 12 name grid_mapping attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 12 name units
# 			nc4_get_att: ncid 0x10000 varid 12 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 12 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 12 name _FillValue
# 			nc4_get_att: ncid 0x10000 varid 12 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 12 name _FillValue
# 			nc4_get_att: ncid 0x10000 varid 12 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 12 name _FillValue attnum -1 mem_type 5
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		NC4_inq_var_all: ncid 0x10000 varid 12
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		nc_inq_attname: ncid 0x10000 varid 13 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 13 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 13 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 13 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 13 attnum 4
# 		nc_inq_attname: ncid 0x10000 varid 13 attnum 5
# 		nc_inq_attname: ncid 0x10000 varid 13 attnum 6
# 		NC4_inq_att: ncid 0x10000 varid 13 name standard_name
# 			nc4_get_att: ncid 0x10000 varid 13 name standard_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 13 name standard_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 13 name long_name
# 			nc4_get_att: ncid 0x10000 varid 13 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 13 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 13 name coordinates
# 			nc4_get_att: ncid 0x10000 varid 13 name coordinates attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 13 name coordinates attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 13 name cell_methods
# 			nc4_get_att: ncid 0x10000 varid 13 name cell_methods attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 13 name cell_methods attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 13 name grid_mapping
# 			nc4_get_att: ncid 0x10000 varid 13 name grid_mapping attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 13 name grid_mapping attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 13 name units
# 			nc4_get_att: ncid 0x10000 varid 13 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 13 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 13 name _FillValue
# 			nc4_get_att: ncid 0x10000 varid 13 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 13 name _FillValue
# 			nc4_get_att: ncid 0x10000 varid 13 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 13 name _FillValue attnum -1 mem_type 5
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		NC4_inq_var_all: ncid 0x10000 varid 13
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		nc_inq_attname: ncid 0x10000 varid 14 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 14 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 14 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 14 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 14 attnum 4
# 		nc_inq_attname: ncid 0x10000 varid 14 attnum 5
# 		nc_inq_attname: ncid 0x10000 varid 14 attnum 6
# 		NC4_inq_att: ncid 0x10000 varid 14 name standard_name
# 			nc4_get_att: ncid 0x10000 varid 14 name standard_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 14 name standard_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 14 name long_name
# 			nc4_get_att: ncid 0x10000 varid 14 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 14 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 14 name coordinates
# 			nc4_get_att: ncid 0x10000 varid 14 name coordinates attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 14 name coordinates attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 14 name cell_methods
# 			nc4_get_att: ncid 0x10000 varid 14 name cell_methods attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 14 name cell_methods attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 14 name grid_mapping
# 			nc4_get_att: ncid 0x10000 varid 14 name grid_mapping attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 14 name grid_mapping attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 14 name units
# 			nc4_get_att: ncid 0x10000 varid 14 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 14 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 14 name _FillValue
# 			nc4_get_att: ncid 0x10000 varid 14 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 14 name _FillValue
# 			nc4_get_att: ncid 0x10000 varid 14 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 14 name _FillValue attnum -1 mem_type 5
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		NC4_inq_var_all: ncid 0x10000 varid 14
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		nc_inq_attname: ncid 0x10000 varid 15 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid 15 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid 15 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid 15 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid 15 attnum 4
# 		nc_inq_attname: ncid 0x10000 varid 15 attnum 5
# 		NC4_inq_att: ncid 0x10000 varid 15 name long_name
# 			nc4_get_att: ncid 0x10000 varid 15 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 15 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 15 name coordinates
# 			nc4_get_att: ncid 0x10000 varid 15 name coordinates attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 15 name coordinates attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 15 name cell_methods
# 			nc4_get_att: ncid 0x10000 varid 15 name cell_methods attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 15 name cell_methods attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 15 name grid_mapping
# 			nc4_get_att: ncid 0x10000 varid 15 name grid_mapping attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 15 name grid_mapping attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 15 name units
# 			nc4_get_att: ncid 0x10000 varid 15 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 15 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid 15 name _FillValue
# 			nc4_get_att: ncid 0x10000 varid 15 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 15 name _FillValue
# 			nc4_get_att: ncid 0x10000 varid 15 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid 15 name _FillValue attnum -1 mem_type 4
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		NC4_inq_var_all: ncid 0x10000 varid 15
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq: ncid 0x10000
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 0
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 1
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 2
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 3
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 4
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 5
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 6
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 7
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 8
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 9
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 10
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 11
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 12
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 13
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 14
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 15
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 16
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 17
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 18
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 19
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 20
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 21
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 22
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 23
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 24
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 25
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 26
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 27
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 28
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 29
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 30
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 31
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 32
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 33
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 34
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 35
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 36
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 37
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 38
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 39
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 40
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 41
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 42
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 43
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 44
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 45
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 46
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 47
# 		nc_inq_attname: ncid 0x10000 varid -1 attnum 48
# 		NC4_inq_att: ncid 0x10000 varid -1 name Conventions
# 			nc4_get_att: ncid 0x10000 varid -1 name Conventions attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name Conventions attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name title
# 			nc4_get_att: ncid 0x10000 varid -1 name title attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name title attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name summary
# 			nc4_get_att: ncid 0x10000 varid -1 name summary attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name summary attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name references
# 			nc4_get_att: ncid 0x10000 varid -1 name references attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name references attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name institution
# 			nc4_get_att: ncid 0x10000 varid -1 name institution attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name institution attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name comment
# 			nc4_get_att: ncid 0x10000 varid -1 name comment attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name comment attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name id
# 			nc4_get_att: ncid 0x10000 varid -1 name id attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name id attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name naming_authority
# 			nc4_get_att: ncid 0x10000 varid -1 name naming_authority attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name naming_authority attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name sea_name
# 			nc4_get_att: ncid 0x10000 varid -1 name sea_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name sea_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name time_coverage_start
# 			nc4_get_att: ncid 0x10000 varid -1 name time_coverage_start attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name time_coverage_start attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name time_coverage_end
# 			nc4_get_att: ncid 0x10000 varid -1 name time_coverage_end attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name time_coverage_end attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name time_coverage_duration
# 			nc4_get_att: ncid 0x10000 varid -1 name time_coverage_duration attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name time_coverage_duration attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name time_coverage_resolution
# 			nc4_get_att: ncid 0x10000 varid -1 name time_coverage_resolution attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name time_coverage_resolution attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_lat_min
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lat_min attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_lat_min
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lat_min attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lat_min attnum -1 mem_type 5
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_lat_max
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lat_max attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_lat_max
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lat_max attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lat_max attnum -1 mem_type 5
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_lon_min
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lon_min attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_lon_min
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lon_min attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lon_min attnum -1 mem_type 5
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_lon_max
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lon_max attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_lon_max
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lon_max attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lon_max attnum -1 mem_type 5
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_vertical_min
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_vertical_min attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_vertical_min
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_vertical_min attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_vertical_min attnum -1 mem_type 5
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_vertical_max
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_vertical_max attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_vertical_max
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_vertical_max attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_vertical_max attnum -1 mem_type 5
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_lat_units
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lat_units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lat_units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_lat_resolution
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lat_resolution attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lat_resolution attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_lon_units
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lon_units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lon_units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_lon_resolution
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lon_resolution attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_lon_resolution attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_vertical_units
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_vertical_units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_vertical_units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_vertical_resolution
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_vertical_resolution attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_vertical_resolution attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name geospatial_vertical_positive
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_vertical_positive attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name geospatial_vertical_positive attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name creator_name
# 			nc4_get_att: ncid 0x10000 varid -1 name creator_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name creator_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name creator_email
# 			nc4_get_att: ncid 0x10000 varid -1 name creator_email attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name creator_email attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name creator_url
# 			nc4_get_att: ncid 0x10000 varid -1 name creator_url attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name creator_url attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name creator_type
# 			nc4_get_att: ncid 0x10000 varid -1 name creator_type attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name creator_type attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name creator_institution
# 			nc4_get_att: ncid 0x10000 varid -1 name creator_institution attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name creator_institution attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name project
# 			nc4_get_att: ncid 0x10000 varid -1 name project attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name project attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name processing_level
# 			nc4_get_att: ncid 0x10000 varid -1 name processing_level attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name processing_level attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name keywords
# 			nc4_get_att: ncid 0x10000 varid -1 name keywords attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name keywords attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name keywords_vocabulary
# 			nc4_get_att: ncid 0x10000 varid -1 name keywords_vocabulary attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name keywords_vocabulary attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name standard_name_vocabulary
# 			nc4_get_att: ncid 0x10000 varid -1 name standard_name_vocabulary attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name standard_name_vocabulary attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name contributor_name
# 			nc4_get_att: ncid 0x10000 varid -1 name contributor_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name contributor_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name contributor_role
# 			nc4_get_att: ncid 0x10000 varid -1 name contributor_role attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name contributor_role attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name cdm_data_type
# 			nc4_get_att: ncid 0x10000 varid -1 name cdm_data_type attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name cdm_data_type attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name publisher_name
# 			nc4_get_att: ncid 0x10000 varid -1 name publisher_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name publisher_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name publisher_institution
# 			nc4_get_att: ncid 0x10000 varid -1 name publisher_institution attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name publisher_institution attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name publisher_type
# 			nc4_get_att: ncid 0x10000 varid -1 name publisher_type attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name publisher_type attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name publisher_url
# 			nc4_get_att: ncid 0x10000 varid -1 name publisher_url attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name publisher_url attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name publisher_email
# 			nc4_get_att: ncid 0x10000 varid -1 name publisher_email attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name publisher_email attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name nodc_template_version
# 			nc4_get_att: ncid 0x10000 varid -1 name nodc_template_version attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name nodc_template_version attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name license
# 			nc4_get_att: ncid 0x10000 varid -1 name license attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name license attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name metadata_link
# 			nc4_get_att: ncid 0x10000 varid -1 name metadata_link attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name metadata_link attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name date_created
# 			nc4_get_att: ncid 0x10000 varid -1 name date_created attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name date_created attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0x10000 varid -1 name date_modified
# 			nc4_get_att: ncid 0x10000 varid -1 name date_modified attnum -1 mem_type 0
# 			nc4_get_att: ncid 0x10000 varid -1 name date_modified attnum -1 mem_type 2
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq: ncid 0x10000
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 			NC4_get_vars: var->hdr.name lat mem_nc_type 5
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_var_all: ncid 0x10000 varid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_att: ncid 0x10000 varid 1 name scale_factor
# 			nc4_get_att: ncid 0x10000 varid 1 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 1 name add_offset
# 			nc4_get_att: ncid 0x10000 varid 1 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 			NC4_get_vars: var->hdr.name lon mem_nc_type 5
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_att: ncid 0x10000 varid 3 name scale_factor
# 			nc4_get_att: ncid 0x10000 varid 3 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 3 name add_offset
# 			nc4_get_att: ncid 0x10000 varid 3 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 			NC4_get_vars: var->hdr.name depth mem_nc_type 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_var_all: ncid 0x10000 varid 5
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_att: ncid 0x10000 varid 5 name scale_factor
# 			nc4_get_att: ncid 0x10000 varid 5 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 5 name add_offset
# 			nc4_get_att: ncid 0x10000 varid 5 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 			NC4_get_vars: var->hdr.name time mem_nc_type 5
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_var_all: ncid 0x10000 varid 7
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_att: ncid 0x10000 varid 7 name scale_factor
# 			nc4_get_att: ncid 0x10000 varid 7 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 7 name add_offset
# 			nc4_get_att: ncid 0x10000 varid 7 name add_offset attnum -1 mem_type 0

# %% [markdown]
# # To convert $\frac{umol}{kg}$ to $\frac{mmol}{m^3}$
# $\frac{umol}{kg} * \frac{1 mmol}{1000 umol} * \frac{1026 kg}{1 m^3} = 0.97465 \frac{mmol}{m^3} $

# %%
NO3_woa_10m = np.nansum(ds_all.n_an[:,0:3,:,:],axis=(0,1)) *0.97465 # Sum through the top 10m, which is the surface layer in spectra. (umol/kg ---> mmol/m3)
# Out:
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 			NC4_get_vars: var->hdr.name n_an mem_nc_type 5
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_att: ncid 0x10000 varid 9 name scale_factor
# 			nc4_get_att: ncid 0x10000 varid 9 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 9 name add_offset
# 			nc4_get_att: ncid 0x10000 varid 9 name add_offset attnum -1 mem_type 0

# %%
surface_NO3_woa = ds_all.n_an[0,0,:,:] *0.97465 # Sum through the top 10m, which is the surface layer in spectra. (umol/kg ---> mmol/m3)

# %%
surface_NO3_woa.shape
# Out:
# (180, 360)

# %%
surface_NO3_SPECTRA = np.nanmean(ds.NO3[:,0,:,:],axis=0) # mmol/m^3

# %%
surface_NO3_SPECTRA.shape
# Out:
# (180, 360)

# %%
ds_all.lon
# Out:
# <xarray.DataArray 'lon' (lon: 360)>
# array([-179.5, -178.5, -177.5, ...,  177.5,  178.5,  179.5], dtype=float32)
# Coordinates:
#   * lon      (lon) float32 -179.5 -178.5 -177.5 -176.5 ... 177.5 178.5 179.5
# Attributes:
#     standard_name:  longitude
#     long_name:      longitude
#     units:          degrees_east
#     axis:           X
#     bounds:         lon_bnds

# %%
from mpl_toolkits.basemap import Basemap
fig = plt.figure(figsize=(18, 8))
lat = ds.lat
vminn=0
vmaxx=20
ax = fig.add_subplot(1, 3, 1)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
model, lon = add_cyclic_point(surface_NO3_SPECTRA, coord=ds.lon, axis=1)
x, y = m(*np.meshgrid(lon,ds.lat))
cf = m.pcolor(x,y,model,cmap='Spectral_r', vmin=vminn, vmax=vmaxx)
cb = plt.colorbar(cf, shrink=0.75, orientation='horizontal',extend = 'both')
cb.ax.set_title('mmol m$^{-3}$', fontsize = 22)
cb.ax.tick_params(labelsize=20)
ax.set_title('', fontsize =20)

m.drawmeridians((180,205), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((205,235), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((235,290), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((290,315), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((145,180), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((90,145), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((53,90), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((20,53), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawparallels((60,90), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])

ax = fig.add_subplot(1, 3, 2)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
obs, lon = add_cyclic_point(surface_NO3_woa, coord=ds.lon, axis=1)
x, y = m(*np.meshgrid(lon,ds.lat))
cf = m.pcolor(x,y,obs,cmap='Spectral_r', vmin=vminn, vmax=vmaxx)
cb = plt.colorbar(cf, shrink=0.75, orientation='horizontal',extend = 'both')
cb.ax.set_title('mmol m$^{-3}$', fontsize = 22)
cb.ax.tick_params(labelsize=20)
ax.set_title('', fontsize =20)

m.drawmeridians((180,205), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((205,235), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((235,290), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((290,315), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((145,180), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((90,145), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((53,90), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((20,53), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawparallels((60,90), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])

ax = fig.add_subplot(1, 3, 3)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
cf = m.pcolor(x,y,model-obs,cmap='RdBu_r', vmin = -3, vmax = 3)
cb = plt.colorbar(cf, shrink=0.75, orientation='horizontal',extend = 'both')
cb.ax.set_title('mmol m$^{-3}$', fontsize = 22)
cb.ax.tick_params(labelsize=20)
ax.set_title('', fontsize =20)

m.drawmeridians((180,205), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((205,235), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((235,290), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((290,315), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((145,180), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((90,145), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((53,90), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawmeridians((20,53), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
m.drawparallels((60,90), color='k', linewidth=1.0, zorder=None, dashes=[1, 1])
fig.tight_layout()
fig.savefig('/glade/work/gabyn/case_notes/analysis_figures/Surface_NO3_annual_comparison_20years.png',dpi=600, bbox_inches='tight')
# Out:
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 			NC4_get_vars: var->hdr.name n_an mem_nc_type 5
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_att: ncid 0x10000 varid 9 name scale_factor
# 			nc4_get_att: ncid 0x10000 varid 9 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 9 name add_offset
# 			nc4_get_att: ncid 0x10000 varid 9 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 			NC4_get_vars: var->hdr.name n_an mem_nc_type 5
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_var_all: ncid 0x10000 varid 9
# 		NC4_inq_dim: ncid 0x10000 dimid 4
# 		NC4_inq_dim: ncid 0x10000 dimid 3
# 		NC4_inq_dim: ncid 0x10000 dimid 1
# 		NC4_inq_dim: ncid 0x10000 dimid 2
# 		NC4_inq_att: ncid 0x10000 varid 9 name scale_factor
# 			nc4_get_att: ncid 0x10000 varid 9 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0x10000 varid 9 name add_offset
# 			nc4_get_att: ncid 0x10000 varid 9 name add_offset attnum -1 mem_type 0

# %% [markdown]
# #---------------------------------------------------------------------
# fig = plt.figure(figsize=(20, 8))
# #---------------------------------------------------------------------
# vminn=0
# vmaxx=20
# font=26
#
# #-------------------- Cartopy Settings -------------------------------
# import cartopy.crs as ccrs
# import matplotlib.path as mpath
# theta = np.linspace(0, 2*np.pi, 100)
# map_circle = mpath.Path(np.vstack([np.sin(theta), np.cos(theta)]).T * 0.5 + [0.5, 0.5])
# r_limit = 3214068.5
# r_extent = r_limit*1.0001
# lonlatproj = ccrs.PlateCarree()
# my_projn = ccrs.Orthographic(central_longitude=180+(-100+-30)/2, central_latitude=90)
# # Prep circular boundary
# circle_path = mpath.Path.unit_circle()
# circle_path = mpath.Path(circle_path.vertices.copy() * r_limit,circle_path.codes.copy())
#
# # -------------  MARBL-SPECTRA  ---------------------------------------
# ax = fig.add_subplot(1, 3, 1,projection=my_projn)
#
# model, lon = add_cyclic_point(surface_NO3_SPECTRA, coord=ds.lon, axis=1)
# x, y = np.meshgrid(lon,ds.lat)
# cf = ax.pcolor(x,y,model,cmap='Spectral_r', vmin=vminn, vmax=vmaxx,transform=lonlatproj)
# cb = plt.colorbar(cf, shrink=0.75, orientation='horizontal',extend = 'both')
# cb.ax.set_title('mmol m$^{-3}$', fontsize = 22)
# cb.ax.tick_params(labelsize=20)
# ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'));
# ax.set_xlim(-r_extent, r_extent); ax.set_ylim(-r_extent, r_extent)
# ax.set_boundary(circle_path); ax.set_frame_on(False)  #hide the rectangle frame
#
# # -------------  World Ocean Atlas   ---------------------------------------
# ax = fig.add_subplot(1, 3, 2,projection=my_projn)
# obs, lon = add_cyclic_point(surface_NO3_woa, coord=ds.lon, axis=1)
# cf = ax.pcolor(x,y,obs,cmap='Spectral_r', vmin=vminn, vmax=vmaxx,transform=lonlatproj)
# cb = plt.colorbar(cf, shrink=0.75, orientation='horizontal',extend = 'both')
# cb.ax.set_title('mmol m$^{-3}$', fontsize = 22)
# cb.ax.tick_params(labelsize=20)
# ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'));
# ax.set_xlim(-r_extent, r_extent); ax.set_ylim(-r_extent, r_extent)
# ax.set_boundary(circle_path); ax.set_frame_on(False)  #hide the rectangle frame
#
# # -------------  Model - Observations   ---------------------------------------
#
# ax = fig.add_subplot(1, 3, 3,projection=my_projn)
# cf = ax.pcolor(x,y,model-obs,cmap='RdBu_r', vmin = -0.5, vmax = 0.5,transform=lonlatproj)
# cb = plt.colorbar(cf, shrink=0.75, orientation='horizontal',extend = 'both')
# cb.ax.set_title('mmol m$^{-3}$', fontsize = 22)
# cb.ax.tick_params(labelsize=20)
# ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'));
# ax.set_xlim(-r_extent, r_extent); ax.set_ylim(-r_extent, r_extent)
# ax.set_boundary(circle_path); ax.set_frame_on(False)  #hide the rectangle frame

# %% [markdown]
# ## Calculate Bias and RMSE

# %%
#NO3
no3_predicted = surface_NO3_SPECTRA 
no3_observed  = surface_NO3_woa 
no3_bias = np.nanmean(no3_predicted - no3_observed)
no3_rmse = (np.nanmean((no3_predicted-no3_observed)**2))**0.5

# %%
print(f'bias= {no3_bias}, RMSE = {no3_rmse} mmol m^{-3}')
