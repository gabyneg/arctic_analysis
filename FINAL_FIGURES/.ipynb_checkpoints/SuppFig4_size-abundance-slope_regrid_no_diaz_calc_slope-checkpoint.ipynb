# %% [markdown]
# ## Compare the size abundance slope throughout the Arctic Ocean between these time periods:
#     Goal:
#     - Plot the size abundance slope for the last 30 years of the SSP1-2.6, SSP2-4.5 and SSP5-8.5 runs (2070-2100 climatological mean), the last 30 years of the 20th century historical (1970-2000 climatological mean), and the difference between the two?

# %%
import warnings
warnings.simplefilter("ignore") # Silence warnings
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import numpy as np
from matplotlib.pyplot import figure
import numpy.ma as ma
from netCDF4 import Dataset as NetCDFFile
import glob
import cartopy
import cartopy.crs as ccrs
import pylab 
from copy import deepcopy
import pandas as pd
import matplotlib
import matplotlib.colors as colors
from cartopy.util import add_cyclic_point
import matplotlib.gridspec as gridspec
plt.rcParams['mathtext.default']='regular'
from collections import OrderedDict
import cmocean
import matplotlib.cm as cm
import matplotlib as mpl
import seaborn as sns
from numpy import arange,array,ones
from scipy import stats
import re 
import os

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
def adjust_pop_grid(tlon,tlat,field):
    nj = tlon.shape[0]
    ni = tlon.shape[1]
    xL = int(ni/2 - 1)
    xR = int(xL + ni)

    tlon = np.where(np.greater_equal(tlon,np.min(tlon[:,0])),tlon-360.,tlon)
    lon  = np.concatenate((tlon,tlon+360.),1)
    lon = lon[:,xL:xR]

    if ni == 320:
        lon[367:-3,0] = lon[367:-3,0]+360.
    lon = lon - 360.
    lon = np.hstack((lon,lon[:,0:1]+360.))
    if ni == 320:
        lon[367:,-1] = lon[367:,-1] - 360.

    #-- trick cartopy into doing the right thing:
    #   it gets confused when the cyclic coords are identical
    lon[:,0] = lon[:,0]-1e-8

    #-- periodicity
    lat  = np.concatenate((tlat,tlat),1)
    lat = lat[:,xL:xR]
    lat = np.hstack((lat,lat[:,0:1]))

    field = np.ma.concatenate((field,field),1)
    field = field[:,xL:xR]
    field = np.ma.hstack((field,field[:,0:1]))
    return lon,lat,field

# %% [markdown]
# ## Import general Grid

# %%
### 20 year climatology GNG513b from 43 to 62 representing Jan 1990 - Dec 2009.
path = '/glade/campaign/cesm/development/bgcwg/projects/marbl-spectra/GNG595_2ndcycle_1990-2009_clim'
files = sorted(glob.glob(f'{path}/*.nc', recursive=True),key=numericalSort)
ds= xr.open_mfdataset(files,combine='by_coords')

# %% [markdown]
# ## Import the Biomass so that you can calculate the abundance directly
# `Regional_analysis_biomass_ssps_hist.ipynb` and the units should be in `mmol C m-2`, however, to convert to `ugC m-3` all I have to do is divide by `150m` and multiply by * `12.011` *`1000`

# %%
path = '/glade/derecho/scratch/gabyn/save/regrid/'
zbm_ssp1 =  xr.open_mfdataset(f'{path}regrid_zbmss_ssp1.nc',combine='by_coords')
zbm_ssp2 =  xr.open_mfdataset(f'{path}regrid_zbmss_ssp2.nc',combine='by_coords')
zbm_ssp5 =  xr.open_mfdataset(f'{path}regrid_zbmss_ssp5.nc',combine='by_coords')
zbm_hist =  xr.open_mfdataset(f'{path}regrid_zbmss_hist.nc',combine='by_coords')

bm_ssp1 =  xr.open_mfdataset(f'{path}regrid_bmss_ssp1.nc',combine='by_coords')
bm_ssp2 =  xr.open_mfdataset(f'{path}regrid_bmss_ssp2.nc',combine='by_coords')
bm_ssp5 =  xr.open_mfdataset(f'{path}regrid_bmss_ssp5.nc',combine='by_coords')
bm_hist =  xr.open_mfdataset(f'{path}regrid_bmss_hist.nc',combine='by_coords')

# %%
pb_ssp1 = np.array(bm_ssp1.pbmss_ssp1)
pb_ssp2 = np.array(bm_ssp2.pbmss_ssp2)
pb_ssp5 = np.array(bm_ssp5.pbmss_ssp5)
pb_hist = np.array(bm_hist.pbmss_hist)
zb_ssp1 = np.array(zbm_ssp1.zbmss_ssp1)
zb_ssp2 = np.array(zbm_ssp2.zbmss_ssp2)
zb_ssp5 = np.array(zbm_ssp5.zbmss_ssp5)
zb_hist = np.array(zbm_hist.zbmss_hist)

# %% [markdown]
# ## Import the already calculated and regrided slope and intercept

# %%
path = '/glade/derecho/scratch/gabyn/save/regrid/'
sa_ssp1 =  xr.open_mfdataset(f'{path}regrid_sa_ssp1.nc',combine='by_coords')
sa_ssp2 =  xr.open_mfdataset(f'{path}regrid_sa_ssp2.nc',combine='by_coords')
sa_ssp5 =  xr.open_mfdataset(f'{path}regrid_sa_ssp5.nc',combine='by_coords')
sa_hist =  xr.open_mfdataset(f'{path}regrid_sa_hist.nc',combine='by_coords')

path = '/glade/derecho/scratch/gabyn/save/regrid/'
in_ssp1 =  xr.open_mfdataset(f'{path}regrid_intercept_ssp1.nc',combine='by_coords')
in_ssp2 =  xr.open_mfdataset(f'{path}regrid_intercept_ssp2.nc',combine='by_coords')
in_ssp5 =  xr.open_mfdataset(f'{path}regrid_intercept_ssp5.nc',combine='by_coords')
in_hist =  xr.open_mfdataset(f'{path}regrid_intercept_hist.nc',combine='by_coords')

# %%
# slope
sa_ssp1_slope = np.array(sa_ssp1.sa_ssp1)
sa_ssp2_slope = np.array(sa_ssp2.sa_ssp2)
sa_ssp5_slope = np.array(sa_ssp5.sa_ssp5)
sa_hist_slope = np.array(sa_hist.sa_hist)

# Intercept 
in_ssp1_slope = np.array(in_ssp1.sa_ssp1)
in_ssp2_slope = np.array(in_ssp2.sa_ssp2)
in_ssp5_slope = np.array(in_ssp5.sa_ssp5)
in_hist_slope = np.array(in_hist.sa_hist)

# %% [markdown]
# ### Create lines of the slope at the central Arctic compared to the Nordic Sea
# `y = mx+b`
#
# where:
#
#     `m` = np.nanmean(sa_hist_slope[149:170,155:205])
#     `b` = np.nanmean(in_hist_slope[149:170,155:205])
#     `y` is phytoplankton abundance
#     `x` is phytoplankton volumes.

# %%
## Gaby's Path 
gabyn_path = '/glade/work/gabyn/case_notes/spectral_cases/g.e21.G1850ECOIAF.t62_g17.marbl0_33.GNG595_updated/spectra-config'
nl_config = os.path.join(f'{gabyn_path}/data/')
sizes = pd.read_csv(nl_config+'plankton_sizes.csv')
sizes = sizes.sort_values('mass_ugC') # sorting sizes by mass in ugC 
sizes
# Out:
#      type  sname      mass_ugC       vol_um3     ESD_mm  Qp_fixed  \
# 1   phyto     pp  9.266989e-08  3.706795e-01   0.000891  0.004651
# 2   phyto    mp1  8.241979e-06  1.805089e+01   0.003255  0.006824
# 0   phyto   diaz  5.499929e-05  1.227865e+02   0.006167  0.003333
# 3   phyto    mp2  8.888712e-05  8.790197e+02   0.011885  0.008656
# 6   phyto  diat1  5.004513e-04  1.327390e+04   0.029376  0.010289
# 9     zoo   zoo1  2.803686e-03  2.355042e+04   0.035563  0.008547
# 7   phyto  diat2  3.803133e-03  1.326626e+05   0.063278  0.012602
# 4   phyto    mp3  4.830334e-03  4.280541e+04   0.043401  0.012907
# 8   phyto  diat3  2.890156e-02  1.325863e+06   0.136301  0.015435
# 10    zoo   zoo2  8.933984e-02  7.447577e+05   0.112462  0.008547
# 5   phyto    mp4  1.855836e-01  2.084484e+06   0.158489  0.018590
# 11    zoo   zoo3  2.825280e+00  2.355219e+07   0.355640  0.008547
# 12    zoo   zoo4  8.934658e+01  7.448139e+08   1.124647  0.008547
# ...

# %%
# Sorting mass and names of only the phytoplankton by mass. 
phyto_mass = array([sizes.mass_ugC[1],sizes.mass_ugC[2],sizes.mass_ugC[3],
                   sizes.mass_ugC[6],sizes.mass_ugC[7],sizes.mass_ugC[4],sizes.mass_ugC[8],
                   sizes.mass_ugC[5]]) # ugC 

phyto_vol = array([sizes.vol_um3[1],sizes.vol_um3[2],sizes.vol_um3[3],
                   sizes.vol_um3[6],sizes.vol_um3[7],sizes.vol_um3[4],sizes.vol_um3[8],
                   sizes.vol_um3[5]]) # units of um^3 (this is good). 

phyto_names = array([sizes.sname[1],sizes.sname[2],sizes.sname[3],
                   sizes.sname[6],sizes.sname[7],sizes.sname[4],sizes.sname[8],
                   sizes.sname[5]])

# %% [markdown]
# ## Calculate the abundance from the biomass ( $\mu$g C m$^{-3}$)

# %%
pbmss_ssp2 = np.nanmean(np.delete(pb_ssp2,1,1),axis=0)/150*(12.011*1000) # converting from mmolC -2 to ug C m-3
pbmss_hist = np.nanmean(np.delete(pb_hist,1,1),axis=0)/150*(12.011*1000) # converting from mmolC -2 to ug C m-3

# %%
# This deletes the dizotrophs from the array - np.delete(pb_ssp2,1,1)
phyto_mass.shape
# Out:
# (8,)

# %%
# calcualte the abundance of each phytoplankton with biomass and mass in the same order. 
phyto_abu_ssp2 = np.zeros((8,180,360))
phyto_abu_hist = np.zeros((8,180,360))
for i in range(8):
    phyto_abu_ssp2[i,:,:] = pbmss_ssp2[i,:,:]/phyto_mass[i] # ug C cm^{-3} / ug C -->  cell/ m^3 
    phyto_abu_hist[i,:,:] = pbmss_hist[i,:,:]/phyto_mass[i] # ug C cm^{-3} / ug C -->  cell/ m^3

# %%
fig = plt.figure(figsize=(10, 7))
sfont=13
font=16

#subplot 1
ax1 = fig.add_subplot(2, 2, 1)
lnsp1 = ax1.plot(np.log10(phyto_vol),np.log10(phyto_abu_hist[:,155,178]), 'o', color='k',linewidth=3,label='Historical');
lns1 = ax1.plot(np.log10(phyto_vol),np.log10(phyto_abu_ssp2[:,155,178]), '*', color='k',linewidth=1,label='SSP2-4.5');
ax1.tick_params(axis='both',labelsize=sfont);
ax1.legend(['Historical','SSP2-4.5'],fontsize=sfont)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax1.set_title('2$^o$W, 65.5$^o$N',fontsize=font)

ax1 = fig.add_subplot(2, 2, 2)
lnsp2 = ax1.plot(np.log10(phyto_vol),np.log10(phyto_abu_hist[:,160,3]), 'o', color='k',linewidth=3,label='Historical');
lns2 = ax1.plot(np.log10(phyto_vol),np.log10(phyto_abu_ssp2[:,160,3]), '*', color='k',linewidth=1,label='SSP2-4.5');
ax1.tick_params(axis='both',labelsize=sfont);
#ax1.legend(['Historical','SSP2-4.5'],fontsize=sfont)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax1.set_title('167$^o$W, 70.5$^o$N',fontsize=font)

ax1 = fig.add_subplot(2, 2, 3)
lnsp3 = ax1.plot(np.log10(phyto_vol),np.log10(phyto_abu_hist[:,179,200]), 'o', color='k',linewidth=3,label='Historical');
lns3 = ax1.plot(np.log10(phyto_vol),np.log10(phyto_abu_ssp2[:,179,200]), '*', color='k',linewidth=1,label='SSP2-4.5');
ax1.tick_params(axis='both',labelsize=sfont);
#ax1.legend(['Historical','SSP2-4.5'],fontsize=sfont)
ax1.set_title('20$^o$E, 89.5$^o$N',fontsize=font)

ax1 = fig.add_subplot(2, 2, 4)
lnsp4 = ax1.plot(np.log10(phyto_vol),np.log10(phyto_abu_hist[:,164,250]), 'o', color='k',linewidth=3,label='Historical');
lns4 = ax1.plot(np.log10(phyto_vol),np.log10(phyto_abu_ssp2[:,164,250]), '*', color='k',linewidth=1,label='SSP2-4.5');
ax1.tick_params(axis='both',labelsize=sfont);
#ax1.legend(['Historical','SSP2-4.5'],fontsize=sfont)
ax1.set_title('70$^o$E, 74.5$^o$N',fontsize=font)

fig.text(0.5, 0.001, 'Phytoplankton log volume ($\mu$m$^3$)', ha='center',fontsize=font)
fig.text(0.03, 0.5, 'Phytoplankton log abundance (cells m$^{-3}$)', va='center', rotation='vertical',fontsize=font)
#file = '/glade/u/home/gabyn/work/case_notes/analysis_figures/'
#fig.savefig(f'{file}sa_hist_ssp2_regional.png',dpi=600, bbox_inches='tight')
# Out:
# Text(0.03, 0.5, 'Phytoplankton log abundance (cells m$^{-3}$)')

# %% [markdown]
# ## Comparing between these different areas of the Arctic Ocean

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import matplotlib.path as mpath
import numpy as np

r_limit = 3214068.5 #from: ax.get_ylim() of above plot
vminn=-0.1
vmaxx=0.1
# some settings  
lonlatproj = ccrs.PlateCarree()
my_projn = ccrs.Orthographic(central_longitude=0, central_latitude=90)
fig = plt.figure(figsize=[8, 8])
ax = plt.subplot(1, 1, 1, projection=my_projn)

data, lon = add_cyclic_point(sa_ssp2_slope-sa_hist_slope, coord=sa_hist.lon, axis=1)
x, y = np.meshgrid(lon,sa_hist.lat)
cf = ax.pcolormesh(x,y,data,cmap='RdBu_r',transform=lonlatproj,vmin=vminn, vmax=vmaxx)

# -2^oE, 65.5^oN
x1, y1 = np.meshgrid(sa_hist.lon[178],sa_hist.lat[155])
ax.plot(x1,y1,'X',color='gold',ms=10,fillstyle='full',transform=lonlatproj)

# -167^oE, 70.5^oN
x2, y2 = np.meshgrid(sa_hist.lon[13],sa_hist.lat[160])
ax.plot(x2,y2,'o',color='gold',ms=10,fillstyle='full',transform=lonlatproj)

# 20^oE, 89.5^oN
x3, y3 = np.meshgrid(sa_hist.lon[200],sa_hist.lat[179])
ax.plot(x3,y3,'*',color='gold',ms=13,fillstyle='full',transform=lonlatproj)

# 70^oE, 74.5^oN
x4, y4 = np.meshgrid(sa_hist.lon[250],sa_hist.lat[164])
ax.plot(x4,y4,'^',color='gold',ms=13,fillstyle='full',transform=lonlatproj)

# add bluemarble image
# add coastlines
ax.coastlines(lw=0.5, color="black", zorder=20)


# draw graticule (of meridian and parallel lines)
gls = ax.gridlines(draw_labels=True, crs=ccrs.PlateCarree(), lw=1, color="gray",
        y_inline=True, xlocs=range(-180,180,30), ylocs=range(-80,91,10))


# add extra padding to the plot extents
r_extent = r_limit*1.0001
ax.set_xlim(-r_extent, r_extent)
ax.set_ylim(-r_extent, r_extent)

ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'));
# Prep circular boundary
circle_path = mpath.Path.unit_circle()
circle_path = mpath.Path(circle_path.vertices.copy() * r_limit,
                           circle_path.codes.copy())

#set circle boundary
ax.set_boundary(circle_path)
#hide frame
ax.set_frame_on(False)  #hide the rectangle frame
cbar_ax = fig.add_axes([0.258, 0.01, 0.5, 0.02])
cb = fig.colorbar(cf, shrink=1, extend ='both',orientation='horizontal', cax=cbar_ax)
cb.ax.tick_params(labelsize=14)
cb.ax.set_title('Size abundance slope (SSP2 - Historical)', fontsize=16)
plt.show()
#file = '/glade/u/home/gabyn/work/case_notes/analysis_figures/'
#fig.savefig(f'{file}sa_hist_ssp2_map_wregions.png',dpi=600, bbox_inches='tight')

# %%
Y_hist_k = (sa_hist_slope[155,178]*np.log10(phyto_vol))+in_hist_slope[155,178]
Y_hist_r = (sa_hist_slope[160,13]*np.log10(phyto_vol))+in_hist_slope[160,3]
Y_hist_b = (sa_hist_slope[179,200]*np.log10(phyto_vol))+in_hist_slope[179,200]
Y_hist_g = (sa_hist_slope[164,250]*np.log10(phyto_vol))+in_hist_slope[164,250]

Y_ssp2_k = (sa_ssp2_slope[155,178]*np.log10(phyto_vol))+in_ssp2_slope[155,178]
Y_ssp2_r = (sa_ssp2_slope[160,13]*np.log10(phyto_vol))+in_ssp2_slope[160,3]
Y_ssp2_b = (sa_ssp2_slope[179,200]*np.log10(phyto_vol))+in_ssp2_slope[179,200]
Y_ssp2_g = (sa_ssp2_slope[164,250]*np.log10(phyto_vol))+in_ssp2_slope[164,250]

# %%
fig = plt.figure(figsize=(10, 7))
sfont=13
font=16

#subplot 1
ax1 = fig.add_subplot(2, 2, 1)
lnsp1 = ax1.plot(np.log10(phyto_vol),Y_hist_k, '-o', color='k',linewidth=3,label='Historical');
lns1 = ax1.plot(np.log10(phyto_vol),Y_ssp2_k, '--o', color='k',linewidth=1,label='SSP2-4.5');
ax1.tick_params(axis='both',labelsize=sfont);
ax1.legend(['Historical','SSP2-4.5'],fontsize=sfont)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax1.set_title('2$^o$W, 65.5$^o$N',fontsize=font)

ax1 = fig.add_subplot(2, 2, 2)
lnsp2 = ax1.plot(np.log10(phyto_vol),Y_hist_r, '-o', color='k',linewidth=3,label='Historical');
lns2 = ax1.plot(np.log10(phyto_vol),Y_ssp2_r, '--o', color='k',linewidth=1,label='SSP2-4.5');
ax1.tick_params(axis='both',labelsize=sfont);
#ax1.legend(['Historical','SSP2-4.5'],fontsize=sfont)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax1.set_title('167$^o$W, 70.5$^o$N',fontsize=font)

ax1 = fig.add_subplot(2, 2, 3)
lnsp3 = ax1.plot(np.log10(phyto_vol),Y_hist_b, '-o', color='k',linewidth=3,label='Historical');
lns3 = ax1.plot(np.log10(phyto_vol),Y_ssp2_b, '--o', color='k',linewidth=1,label='SSP2-4.5');
ax1.tick_params(axis='both',labelsize=sfont);
#ax1.legend(['Historical','SSP2-4.5'],fontsize=sfont)
ax1.set_title('20$^o$E, 89.5$^o$N',fontsize=font)

ax1 = fig.add_subplot(2, 2, 4)
lnsp4 = ax1.plot(np.log10(phyto_vol),Y_hist_g, '-o', color='k',linewidth=3,label='Historical');
lns4 = ax1.plot(np.log10(phyto_vol),Y_ssp2_g, '--o', color='k',linewidth=1,label='SSP2-4.5');
ax1.tick_params(axis='both',labelsize=sfont);
#ax1.legend(['Historical','SSP2-4.5'],fontsize=sfont)
ax1.set_title('70$^o$E, 74.5$^o$N',fontsize=font)

fig.text(0.5, 0.001, 'Phytoplankton log volume ($\mu$m$^3$)', ha='center',fontsize=font)
fig.text(0.03, 0.5, 'Phytoplankton log abundance (cells m$^{-3}$)', va='center', rotation='vertical',fontsize=font)
#file = '/glade/u/home/gabyn/work/case_notes/analysis_figures/'
#fig.savefig(f'{file}sa_hist_ssp2_regional.png',dpi=600, bbox_inches='tight')
# Out:
# Text(0.03, 0.5, 'Phytoplankton log abundance (cells m$^{-3}$)')

# %% [markdown]
# ## Recalcualte the slope for these regions:
# 1. Calculate the abudance at each grid cell, for every phtyoplankton and every month

# %%
pbmss_ssp2 = np.delete(pb_ssp2,1,1)/150*(12.011*1000) # converting from mmolC -2 to ug C m-3
pbmss_ssp1 = np.delete(pb_ssp1,1,1)/150*(12.011*1000) # converting from mmolC -2 to ug C m-3
pbmss_ssp5 = np.delete(pb_ssp5,1,1)/150*(12.011*1000) # converting from mmolC -2 to ug C m-3
pbmss_hist = np.delete(pb_hist,1,1)/150*(12.011*1000) # converting from mmolC -2 to ug C m-3

# %%
# calcualte the abundance of each phytoplankton with biomass and mass in the same order. 
phyto_abu_ssp2 = np.zeros((12,8,180,360))
phyto_abu_ssp1 = np.zeros((12,8,180,360))
phyto_abu_ssp5 = np.zeros((12,8,180,360))
phyto_abu_hist = np.zeros((12,8,180,360))
for i in range(8):
    phyto_abu_ssp2[:,i,:,:] = pbmss_ssp2[:,i,:,:]/phyto_mass[i] # ug C cm^{-3} / ug C -->  cell/ m^3 
    phyto_abu_hist[:,i,:,:] = pbmss_hist[:,i,:,:]/phyto_mass[i] # ug C cm^{-3} / ug C -->  cell/ m^3
    phyto_abu_ssp1[:,i,:,:] = pbmss_ssp1[:,i,:,:]/phyto_mass[i]
    phyto_abu_ssp5[:,i,:,:] = pbmss_ssp5[:,i,:,:]/phyto_mass[i]

# %% [markdown]
# ### Calculate the slope and intercept directly at one location to see how it compares when you calculate as a loop

# %%
stats.linregress(np.log10(phyto_vol+1),np.log10(np.nanmean(phyto_abu_hist[:,:,155,178],axis=0)))
# Out:
# LinregressResult(slope=-1.061798028521097, intercept=10.004462241978803, rvalue=-0.9519624560805378, pvalue=0.00026724073527225093, stderr=0.13943525523866745, intercept_stderr=0.6086523733483008)

# %%
xp = np.log10(phyto_vol+1)
yp_results_155_178 = np.empty((12,5))
for i in range(12):
    yp_results_155_178[i] = stats.linregress(xp, np.log10(phyto_abu_hist[i,:,155,178]))

# %%
np.nanmean(yp_results_155_178,axis=0)
# Out:
# array([-1.03630062e+00,  9.69878791e+00, -9.58322237e-01,  2.62920844e-04,
#         1.25502505e-01])

# %% [markdown]
# ## The comparison is a few decimals off, but very similar.

# %% [markdown]
# ### Now calculate for each grid cell, and see how that comaprd

# %%
# %%time
m=12
xp = np.log10(phyto_vol+1)
phyto_abu_hist[phyto_abu_hist<0] = 0
phyto_abu_hist_log = np.log10(phyto_abu_hist[:,:,:,:]+1)
yp_hist = np.empty((12,180,360, 5))
for i in range(12):
    for lat in range(180):
        for lon in range(360):
            yp_hist[i,lat,lon,:] = stats.linregress(xp, phyto_abu_hist_log[i,:,lat,lon])
# Out:
# CPU times: user 1min 26s, sys: 239 ms, total: 1min 26s
# Wall time: 1min 29s

# %%
# %%time
m=12
xp = np.log10(phyto_vol+1)
phyto_abu_ssp2[phyto_abu_ssp2<0] = 0
phyto_abu_ssp2_log = np.log10(phyto_abu_ssp2[:,:,:,:]+1)
yp_ssp2 = np.empty((12,180,360, 5))
for i in range(12):
    for lat in range(180):
        for lon in range(360):
            yp_ssp2[i,lat,lon,:] = stats.linregress(xp, phyto_abu_ssp2_log[i,:,lat,lon])
# Out:
# CPU times: user 1min 24s, sys: 251 ms, total: 1min 25s
# Wall time: 1min 28s

# %%
# %%time
m=12
xp = np.log10(phyto_vol+1)
phyto_abu_ssp1[phyto_abu_ssp1<0] = 0
phyto_abu_ssp1_log = np.log10(phyto_abu_ssp1[:,:,:,:]+1)
yp_ssp1 = np.empty((12,180,360, 5))
for i in range(12):
    for lat in range(180):
        for lon in range(360):
            yp_ssp1[i,lat,lon,:] = stats.linregress(xp, phyto_abu_ssp1_log[i,:,lat,lon])
# Out:
# CPU times: user 1min 28s, sys: 272 ms, total: 1min 28s
# Wall time: 1min 32s

# %%
# %%time
m=12
xp = np.log10(phyto_vol+1)
phyto_abu_ssp5[phyto_abu_ssp5<0] = 0
phyto_abu_ssp5_log = np.log10(phyto_abu_ssp5[:,:,:,:]+1)
yp_ssp5 = np.empty((12,180,360, 5))
for i in range(12):
    for lat in range(180):
        for lon in range(360):
            yp_ssp5[i,lat,lon,:] = stats.linregress(xp, phyto_abu_ssp5_log[i,:,lat,lon])
# Out:
# CPU times: user 1min 26s, sys: 250 ms, total: 1min 26s
# Wall time: 1min 30s

# %% [markdown]
# ### There are now a few more differences in errors, but not huge, and it migth be worth it since it compares a lot more than the already calcualted in a pop grid and then regrided, which provided quite a difference in both slope and intercept

# %%
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import matplotlib.path as mpath
import numpy as np

r_limit = 3214068.5 #from: ax.get_ylim() of above plot
vminn=-0.08
vmaxx=0.08
# some settings  
lonlatproj = ccrs.PlateCarree()
my_projn = ccrs.Orthographic(central_longitude=0, central_latitude=90)
fig = plt.figure(figsize=[8, 8])
ax = plt.subplot(1, 1, 1, projection=my_projn)

data, lon = add_cyclic_point(np.nanmean(yp_ssp2[:,:,:,0],axis=0)-np.nanmean(yp_hist[:,:,:,0],axis=0), coord=sa_hist.lon, axis=1)
x, y = np.meshgrid(lon,sa_hist.lat)
cf = ax.pcolormesh(x,y,data,cmap='RdBu_r',transform=lonlatproj,vmin=vminn, vmax=vmaxx)

# 7$^o$W, 64.5$^o$N
x1, y1 = np.meshgrid(sa_hist.lon[173],sa_hist.lat[154])
ax.plot(x1,y1,'X',color='k',ms=10,fillstyle='full',transform=lonlatproj)

# 167$^o$W, 75.5$^o$N
x2, y2 = np.meshgrid(sa_hist.lon[13],sa_hist.lat[165])
ax.plot(x2,y2,'h',color='k',ms=10,fillstyle='full',transform=lonlatproj)

# 20$^o$E, 89.5$^o$N
x3, y3 = np.meshgrid(sa_hist.lon[200],sa_hist.lat[179])
ax.plot(x3,y3,'*',color='k',ms=13,fillstyle='full',transform=lonlatproj)

# 150$^o$E, 72.5$^o$N
x4, y4 = np.meshgrid(sa_hist.lon[330],sa_hist.lat[162])
ax.plot(x4,y4,'^',color='k',ms=13,fillstyle='full',transform=lonlatproj)

# add bluemarble image
# add coastlines
ax.coastlines(lw=0.5, color="black", zorder=20)


# draw graticule (of meridian and parallel lines)
gls = ax.gridlines(draw_labels=True, crs=ccrs.PlateCarree(), lw=1, color="gray",
        y_inline=True, xlocs=range(-180,180,30), ylocs=range(-80,91,10))


# add extra padding to the plot extents
r_extent = r_limit*1.0001
ax.set_xlim(-r_extent, r_extent)
ax.set_ylim(-r_extent, r_extent)

ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'));
# Prep circular boundary
circle_path = mpath.Path.unit_circle()
circle_path = mpath.Path(circle_path.vertices.copy() * r_limit,
                           circle_path.codes.copy())

#set circle boundary
ax.set_boundary(circle_path)
#hide frame
ax.set_frame_on(False)  #hide the rectangle frame
cbar_ax = fig.add_axes([0.258, -0.01, 0.5, 0.02])
cb = fig.colorbar(cf, shrink=1, extend ='both',orientation='horizontal', cax=cbar_ax)
cb.ax.tick_params(labelsize=20)
cb.ax.set_title('SSP2-4.5 - Historical', fontsize=20)
plt.show()
file = '/glade/u/home/gabyn/work/case_notes/analysis_figures/'
fig.savefig(f'{file}sa_hist_ssp2_map_wregions.png',dpi=600, bbox_inches='tight')

# %%
r_limit = 3214068.5 #from: ax.get_ylim() of above plot
vminn=-0.1
vmaxx=0.1
# some settings  
lonlatproj = ccrs.PlateCarree()
my_projn = ccrs.Orthographic(central_longitude=0, central_latitude=90)
fig = plt.figure(figsize=[8, 8])
ax = plt.subplot(1, 1, 1, projection=my_projn)

data, lon = add_cyclic_point(np.nanmean(yp_ssp1[:,:,:,0],axis=0)-np.nanmean(yp_hist[:,:,:,0],axis=0), coord=sa_hist.lon, axis=1)
x, y = np.meshgrid(lon,sa_hist.lat)
cf = ax.pcolormesh(x,y,data,cmap='RdBu_r',transform=lonlatproj,vmin=vminn, vmax=vmaxx)

# -2^oE, 65.5^oN
x1, y1 = np.meshgrid(sa_hist.lon[173],sa_hist.lat[154])
ax.plot(x1,y1,'X',color='k',ms=10,fillstyle='full',transform=lonlatproj)

# -167^oE, 70.5^oN
x2, y2 = np.meshgrid(sa_hist.lon[13],sa_hist.lat[165])
ax.plot(x2,y2,'h',color='k',ms=10,fillstyle='full',transform=lonlatproj)

# 20^oE, 89.5^oN
x3, y3 = np.meshgrid(sa_hist.lon[200],sa_hist.lat[179])
ax.plot(x3,y3,'*',color='k',ms=13,fillstyle='full',transform=lonlatproj)

# 70^oE, 74.5^oN
x4, y4 = np.meshgrid(sa_hist.lon[330],sa_hist.lat[162])
ax.plot(x4,y4,'^',color='k',ms=13,fillstyle='full',transform=lonlatproj)

# add bluemarble image
# add coastlines
ax.coastlines(lw=0.5, color="black", zorder=20)


# draw graticule (of meridian and parallel lines)
gls = ax.gridlines(draw_labels=True, crs=ccrs.PlateCarree(), lw=1, color="gray",
        y_inline=True, xlocs=range(-180,180,30), ylocs=range(-80,91,10))


# add extra padding to the plot extents
r_extent = r_limit*1.0001
ax.set_xlim(-r_extent, r_extent)
ax.set_ylim(-r_extent, r_extent)

ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'));
# Prep circular boundary
circle_path = mpath.Path.unit_circle()
circle_path = mpath.Path(circle_path.vertices.copy() * r_limit,
                           circle_path.codes.copy())

#set circle boundary
ax.set_boundary(circle_path)
#hide frame
ax.set_frame_on(False)  #hide the rectangle frame
cbar_ax = fig.add_axes([0.258, -0.01, 0.5, 0.02])
cb = fig.colorbar(cf, shrink=1, extend ='both',orientation='horizontal', cax=cbar_ax)
cb.ax.tick_params(labelsize=14)
cb.ax.set_title('Slope of size abundance relationship \n (SSP1-2.6 - Historical)', fontsize=16)
plt.show()
file = '/glade/u/home/gabyn/work/case_notes/analysis_figures/'
fig.savefig(f'{file}sa_hist_ssp1_map_wregions.png',dpi=600, bbox_inches='tight')

# %%
r_limit = 3214068.5 #from: ax.get_ylim() of above plot
vminn=-0.1
vmaxx=0.1
# some settings  
lonlatproj = ccrs.PlateCarree()
my_projn = ccrs.Orthographic(central_longitude=0, central_latitude=90)
fig = plt.figure(figsize=[8, 8])
ax = plt.subplot(1, 1, 1, projection=my_projn)

data, lon = add_cyclic_point(np.nanmean(yp_ssp5[:,:,:,0],axis=0)-np.nanmean(yp_hist[:,:,:,0],axis=0), coord=sa_hist.lon, axis=1)
x, y = np.meshgrid(lon,sa_hist.lat)
cf = ax.pcolormesh(x,y,data,cmap='RdBu_r',transform=lonlatproj,vmin=vminn, vmax=vmaxx)

# -2^oE, 65.5^oN
x1, y1 = np.meshgrid(sa_hist.lon[173],sa_hist.lat[154])
ax.plot(x1,y1,'X',color='k',ms=10,fillstyle='full',transform=lonlatproj)

# -167^oE, 70.5^oN
x2, y2 = np.meshgrid(sa_hist.lon[13],sa_hist.lat[165])
ax.plot(x2,y2,'h',color='k',ms=10,fillstyle='full',transform=lonlatproj)

# 20^oE, 89.5^oN
x3, y3 = np.meshgrid(sa_hist.lon[200],sa_hist.lat[179])
ax.plot(x3,y3,'*',color='k',ms=13,fillstyle='full',transform=lonlatproj)

# 70^oE, 74.5^oN
x4, y4 = np.meshgrid(sa_hist.lon[330],sa_hist.lat[162])
ax.plot(x4,y4,'^',color='k',ms=13,fillstyle='full',transform=lonlatproj)

# add bluemarble image
# add coastlines
ax.coastlines(lw=0.5, color="black", zorder=20)


# draw graticule (of meridian and parallel lines)
gls = ax.gridlines(draw_labels=True, crs=ccrs.PlateCarree(), lw=1, color="gray",
        y_inline=True, xlocs=range(-180,180,30), ylocs=range(-80,91,10))


# add extra padding to the plot extents
r_extent = r_limit*1.0001
ax.set_xlim(-r_extent, r_extent)
ax.set_ylim(-r_extent, r_extent)

ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'));
# Prep circular boundary
circle_path = mpath.Path.unit_circle()
circle_path = mpath.Path(circle_path.vertices.copy() * r_limit,
                           circle_path.codes.copy())

#set circle boundary
ax.set_boundary(circle_path)
#hide frame
ax.set_frame_on(False)  #hide the rectangle frame
cbar_ax = fig.add_axes([0.258, -0.01, 0.5, 0.02])
cb = fig.colorbar(cf, shrink=1, extend ='both',orientation='horizontal', cax=cbar_ax)
cb.ax.tick_params(labelsize=14)
cb.ax.set_title('Slope of size abundance relationship \n (SSP5-8.5 - Historical)', fontsize=16)
plt.show()
file = '/glade/u/home/gabyn/work/case_notes/analysis_figures/'
fig.savefig(f'{file}sa_hist_ssp5_map_wregions.png',dpi=600, bbox_inches='tight')

# %%
r_limit = 3214068.5 #from: ax.get_ylim() of above plot
vminn=-1.1
vmaxx=-0.8
# some settings  
lonlatproj = ccrs.PlateCarree()
my_projn = ccrs.Orthographic(central_longitude=0, central_latitude=90)
fig = plt.figure(figsize=[8, 8])
ax = plt.subplot(1, 1, 1, projection=my_projn)

data, lon = add_cyclic_point(np.nanmean(yp_hist[:,:,:,0],axis=0), coord=sa_hist.lon, axis=1)
x, y = np.meshgrid(lon,sa_hist.lat)
cf = ax.pcolormesh(x,y,data,cmap='Spectral_r',transform=lonlatproj,vmin=vminn, vmax=vmaxx)

# -2^oE, 65.5^oN
x1, y1 = np.meshgrid(sa_hist.lon[173],sa_hist.lat[154])
ax.plot(x1,y1,'X',color='k',ms=10,fillstyle='full',transform=lonlatproj)

# -167^oE, 70.5^oN
x2, y2 = np.meshgrid(sa_hist.lon[13],sa_hist.lat[165])
ax.plot(x2,y2,'h',color='k',ms=10,fillstyle='full',transform=lonlatproj)

# 20^oE, 89.5^oN
x3, y3 = np.meshgrid(sa_hist.lon[200],sa_hist.lat[179])
ax.plot(x3,y3,'*',color='k',ms=13,fillstyle='full',transform=lonlatproj)

# 70^oE, 74.5^oN
x4, y4 = np.meshgrid(sa_hist.lon[330],sa_hist.lat[162])
ax.plot(x4,y4,'^',color='k',ms=13,fillstyle='full',transform=lonlatproj)

# add bluemarble image
# add coastlines
ax.coastlines(lw=0.5, color="black", zorder=20)


# draw graticule (of meridian and parallel lines)
gls = ax.gridlines(draw_labels=True, crs=ccrs.PlateCarree(), lw=1, color="gray",
        y_inline=True, xlocs=range(-180,180,30), ylocs=range(-80,91,10))


# add extra padding to the plot extents
r_extent = r_limit*1.0001
ax.set_xlim(-r_extent, r_extent)
ax.set_ylim(-r_extent, r_extent)

ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'));
# Prep circular boundary
circle_path = mpath.Path.unit_circle()
circle_path = mpath.Path(circle_path.vertices.copy() * r_limit,
                           circle_path.codes.copy())

#set circle boundary
ax.set_boundary(circle_path)
#hide frame
ax.set_frame_on(False)  #hide the rectangle frame
cbar_ax = fig.add_axes([0.258, -0.01, 0.5, 0.02])
cb = fig.colorbar(cf, shrink=1, extend ='both',orientation='horizontal', cax=cbar_ax)
cb.ax.tick_params(labelsize=20)
cb.ax.set_title('Historical', fontsize=20)
plt.show()
file = '/glade/u/home/gabyn/work/case_notes/analysis_figures/'
fig.savefig(f'{file}sa_hist_map_wregions_no_diaz.png',dpi=600, bbox_inches='tight')

# %%
abu_hist = np.nanmean(phyto_abu_hist_log,axis=0)
abu_ssp2 = np.nanmean(phyto_abu_ssp2_log,axis=0)
abu_ssp1 = np.nanmean(phyto_abu_ssp1_log,axis=0)
abu_ssp5 = np.nanmean(phyto_abu_ssp5_log,axis=0)

sa_ssp1 = np.nanmean(yp_ssp1,axis=0)
sa_ssp2 = np.nanmean(yp_ssp2,axis=0)
sa_ssp5 = np.nanmean(yp_ssp5,axis=0)
sa_hist = np.nanmean(yp_hist,axis=0)

Y_hist_k = (sa_hist[154,173,0]*np.log10(phyto_vol))+sa_hist[154,173,1]
Y_hist_r = (sa_hist[165,13,0]*np.log10(phyto_vol))+sa_hist[165,3,1]
Y_hist_b = (sa_hist[179,200,0]*np.log10(phyto_vol))+sa_hist[179,200,1]
Y_hist_g = (sa_hist[162,330,0]*np.log10(phyto_vol))+sa_hist[164,250,1]

Y_ssp2_k = (sa_ssp2[154,173,0]*np.log10(phyto_vol))+sa_ssp2[154,173,1]
Y_ssp2_r = (sa_ssp2[165,13,0]*np.log10(phyto_vol))+sa_ssp2[165,3,1]
Y_ssp2_b = (sa_ssp2[179,200,0]*np.log10(phyto_vol))+sa_ssp2[179,200,1]
Y_ssp2_g = (sa_ssp2[162,330,0]*np.log10(phyto_vol))+sa_ssp2[162,330,1]

Y_ssp1_k = (sa_ssp1[154,173,0]*np.log10(phyto_vol))+sa_ssp1[154,173,1]
Y_ssp1_r = (sa_ssp1[165,13,0]*np.log10(phyto_vol))+sa_ssp1[165,3,1]
Y_ssp1_b = (sa_ssp1[179,200,0]*np.log10(phyto_vol))+sa_ssp1[179,200,1]
Y_ssp1_g = (sa_ssp1[162,330,0]*np.log10(phyto_vol))+sa_ssp1[162,330,1]

Y_ssp5_k = (sa_ssp5[154,173,0]*np.log10(phyto_vol))+sa_ssp5[154,173,1]
Y_ssp5_r = (sa_ssp5[165,13,0]*np.log10(phyto_vol))+sa_ssp5[165,3,1]
Y_ssp5_b = (sa_ssp5[179,200,0]*np.log10(phyto_vol))+sa_ssp5[179,200,1]
Y_ssp5_g = (sa_ssp5[162,330,0]*np.log10(phyto_vol))+sa_ssp5[162,330,1]

# %%
fig = plt.figure(figsize=(10, 7))
sfont=13
font=16

#subplot 1
ax1 = fig.add_subplot(2, 2, 1)
lnsp1 = ax1.plot(np.log10(phyto_vol),abu_hist[:,154,173], 'o', color='k',linewidth=3,label='Historical');
lnsp = ax1.plot(np.log10(phyto_vol),Y_hist_k, '-', color='k',linewidth=3,label='Historical');
ax1.tick_params(axis='both',labelsize=sfont);
ax1.legend(lnsp,['Historical'],fontsize=sfont)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax1.set_title('7$^o$W, 64.5$^o$N',fontsize=font)

ax1 = fig.add_subplot(2, 2, 2)
lnsp2 = ax1.plot(np.log10(phyto_vol),abu_hist[:,165,13], 'o', color='k',linewidth=3,label='Historical');
lnsp2 = ax1.plot(np.log10(phyto_vol),Y_hist_r, '-', color='k',linewidth=3,label='Historical');
ax1.tick_params(axis='both',labelsize=sfont);
#ax1.legend(['Historical','SSP2-4.5'],fontsize=sfont)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax1.set_title('167$^o$W, 75.5$^o$N',fontsize=font)

ax1 = fig.add_subplot(2, 2, 3)
lnsp3 = ax1.plot(np.log10(phyto_vol),abu_hist[:,179,200], 'o', color='k',linewidth=3,label='Historical');
lnsp3 = ax1.plot(np.log10(phyto_vol),Y_hist_b, '-', color='k',linewidth=3,label='Historical');
ax1.tick_params(axis='both',labelsize=sfont);
#ax1.legend(['Historical','SSP2-4.5'],fontsize=sfont)
ax1.set_title('20$^o$E, 89.5$^o$N',fontsize=font)

ax1 = fig.add_subplot(2, 2, 4)
lnsp4 = ax1.plot(np.log10(phyto_vol),abu_hist[:,162,330], 'o', color='k',linewidth=3,label='Historical');
lnsp4 = ax1.plot(np.log10(phyto_vol),Y_hist_g, '-', color='k',linewidth=3,label='Historical');
ax1.tick_params(axis='both',labelsize=sfont);
#ax1.legend(['Historical','SSP2-4.5'],fontsize=sfont)
ax1.set_title('150$^o$E, 72.5$^o$N',fontsize=font)

fig.text(0.5, 0.001, 'Phytoplankton log volume ($\mu$m$^3$)', ha='center',fontsize=font)
fig.text(0.03, 0.5, 'Phytoplankton log abundance (cells m$^{-3}$)', va='center', rotation='vertical',fontsize=font)
file = '/glade/u/home/gabyn/work/case_notes/analysis_figures/'
fig.savefig(f'{file}sa_hist_regional.png',dpi=600, bbox_inches='tight')

# %%
fig = plt.figure(figsize=(10, 7))
sfont=13
font=16

#subplot 1
ax1 = fig.add_subplot(2, 2, 1)
lnsp1 = ax1.plot(np.log10(phyto_vol),abu_hist[:,154,173], 'o', color='k',linewidth=3,label='Historical');
lnsp = ax1.plot(np.log10(phyto_vol),Y_hist_k, '-', color='k',linewidth=1,label='Historical');
lns = ax1.plot(np.log10(phyto_vol),Y_ssp2_k, '--', color='royalblue',linewidth=1,label='SSP2-4.5');
lns1 = ax1.plot(np.log10(phyto_vol),abu_ssp2[:,152,173], 'o', color='royalblue',linewidth=1,label='SSP2-4.5');
ax1.tick_params(axis='both',labelsize=sfont);
ax1.legend(lnsp+lns,['Historical','SSP2-4.5'],fontsize=sfont)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax1.set_title('7$^o$W, 64.5$^o$N',fontsize=font)

ax1 = fig.add_subplot(2, 2, 2)
lnsp2 = ax1.plot(np.log10(phyto_vol),abu_hist[:,165,13], 'o', color='k',linewidth=3,label='Historical');
lnsp2 = ax1.plot(np.log10(phyto_vol),Y_hist_r, '-', color='k',linewidth=1,label='Historical');
lns2 = ax1.plot(np.log10(phyto_vol),abu_ssp2[:,165,13], 'o', color='royalblue',linewidth=1,label='SSP2-4.5');
lns2 = ax1.plot(np.log10(phyto_vol),Y_ssp2_r, '--', color='royalblue',linewidth=1,label='SSP2-4.5');
ax1.tick_params(axis='both',labelsize=sfont);
#ax1.legend(['Historical','SSP2-4.5'],fontsize=sfont)
plt.tick_params(
    axis='x',          # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom=False,      # ticks along the bottom edge are off
    top=False,         # ticks along the top edge are off
    labelbottom=False) # labels along the bottom edge are off
ax1.set_title('167$^o$W, 75.5$^o$N',fontsize=font)

ax1 = fig.add_subplot(2, 2, 3)
lnsp3 = ax1.plot(np.log10(phyto_vol),abu_hist[:,179,200], 'o', color='k',linewidth=3,label='Historical');
lnsp3 = ax1.plot(np.log10(phyto_vol),Y_hist_b, '-', color='k',linewidth=1,label='Historical');
lns3 = ax1.plot(np.log10(phyto_vol),abu_ssp2[:,179,200], 'o', color='royalblue',linewidth=1,label='SSP2-4.5');
lns3 = ax1.plot(np.log10(phyto_vol),Y_ssp2_b, '--', color='royalblue',linewidth=1,label='SSP2-4.5');
ax1.tick_params(axis='both',labelsize=sfont);
#ax1.legend(['Historical','SSP2-4.5'],fontsize=sfont)
ax1.set_title('20$^o$E, 89.5$^o$N',fontsize=font)

ax1 = fig.add_subplot(2, 2, 4)
lnsp4 = ax1.plot(np.log10(phyto_vol),abu_hist[:,162,330], 'o', color='k',linewidth=3,label='Historical');
lnsp4 = ax1.plot(np.log10(phyto_vol),Y_hist_g, '-', color='k',linewidth=1,label='Historical');
lns4 = ax1.plot(np.log10(phyto_vol),abu_ssp2[:,162,330], 'o', color='royalblue',linewidth=1,label='SSP2-4.5');
lns4 = ax1.plot(np.log10(phyto_vol),Y_ssp2_g, '--', color='royalblue',linewidth=1,label='SSP2-4.5');
ax1.tick_params(axis='both',labelsize=sfont);
#ax1.legend(['Historical','SSP2-4.5'],fontsize=sfont)
ax1.set_title('150$^o$E, 72.5$^o$N',fontsize=font)

fig.text(0.5, 0.001, 'Phytoplankton log volume ($\mu$m$^3$)', ha='center',fontsize=font)
fig.text(0.03, 0.5, 'Phytoplankton log abundance (cells m$^{-3}$)', va='center', rotation='vertical',fontsize=font)
file = '/glade/u/home/gabyn/work/case_notes/analysis_figures/'
fig.savefig(f'{file}sa_hist_ssp2_regional.png',dpi=600, bbox_inches='tight')
