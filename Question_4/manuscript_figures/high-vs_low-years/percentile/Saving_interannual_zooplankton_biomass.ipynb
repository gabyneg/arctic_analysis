# %% [markdown]
# # Saving Interannual zooplankton biomass to increase the speed of making these interannual plots in the future.

# %%
import warnings
warnings.simplefilter("ignore") # Silence warnings
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import numpy as np
from matplotlib.pyplot import figure

import numpy.ma as ma
from netCDF4 import Dataset as NetCDFFile
import cartopy
import cartopy.crs as ccrs
import pylab 
from copy import deepcopy
import pandas as pd
import matplotlib
import matplotlib.colors as colors
from cartopy.util import add_cyclic_point
plt.rcParams['mathtext.default']='regular'
from collections import OrderedDict
import cmocean
import matplotlib.cm as cm
import matplotlib as mpl
import seaborn as sns
from matplotlib.gridspec import GridSpec
import matplotlib
# Scientific libraries
from numpy import arange,array,ones
from scipy import stats
import os

# %matplotlib inline
from glob import glob
import dask
import esmlab
import pop_tools 
import statistics as stats
from statistics import mean

# %%
class MidpointNormalize(colors.Normalize):
    def __init__(self, vmin=None, vmax=None, midpoint=None, clip=False):
        self.midpoint = midpoint
        colors.Normalize.__init__(self, vmin, vmax, clip)

    def __call__(self, value, clip=None):
        if clip is None:
            clip = self.clip

        result, is_scalar = self.process_value(value)

        self.autoscale_None(result)
        vmin, vmax, midpoint = self.vmin, self.vmax, self.midpoint

        if not (vmin < midpoint < vmax):
            raise ValueError("midpoint must be between maxvalue and minvalue.")
        elif vmin == vmax:
            result.fill(0) # Or should it be all masked? Or 0.5?
        elif vmin > vmax:
            raise ValueError("maxvalue must be bigger than minvalue")
        else:
            vmin = float(vmin)
            vmax = float(vmax)
            if clip:
                mask = np.ma.getmask(result)
                result = np.ma.array(np.clip(result.filled(vmax), vmin, vmax),
                                  mask=mask)

            # ma division is very slow; we can take a shortcut
            resdat = result.data

            #First scale to -1 to 1 range, than to from 0 to 1.
            resdat -= midpoint
            resdat[resdat>0] /= abs(vmax - midpoint)
            resdat[resdat<0] /= abs(vmin - midpoint)

            resdat /= 2.
            resdat += 0.5
            result = np.ma.array(resdat, mask=result.mask, copy=False)

        if is_scalar:
            result = result[0]
        return result

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
def adjust_pop_grid(tlon,tlat,field):
    nj = tlon.shape[0]
    ni = tlon.shape[1]
    xL = int(ni/2 - 1)
    xR = int(xL + ni)

    tlon = np.where(np.greater_equal(tlon,np.min(tlon[:,0])),tlon-360.,tlon)
    lon  = np.concatenate((tlon,tlon+360.),1)
    lon = lon[:,xL:xR]

    if ni == 320:
        lon[367:-3,0] = lon[367:-3,0]+360.
    lon = lon - 360.
    lon = np.hstack((lon,lon[:,0:1]+360.))
    if ni == 320:
        lon[367:,-1] = lon[367:,-1] - 360.

    #-- trick cartopy into doing the right thing:
    #   it gets confused when the cyclic coords are identical
    lon[:,0] = lon[:,0]-1e-8

    #-- periodicity
    lat  = np.concatenate((tlat,tlat),1)
    lat = lat[:,xL:xR]
    lat = np.hstack((lat,lat[:,0:1]))

    field = np.ma.concatenate((field,field),1)
    field = field[:,xL:xR]
    field = np.ma.hstack((field,field[:,0:1]))
    return lon,lat,field

# %% [markdown]
# ## Import the phytoplankton biomass...

# %%
case = 'g.e21.G1850ECOIAF.t62_g17.marbl0_33.GNG595'
path = f'/glade/campaign/cesm/development/bgcwg/projects/marbl-spectra/{case}/ocn/hist'

# %%
variables = [f'{var}' for var in ['zoo1C','zoo2C','zoo3C','zoo4C', 'zoo5C', 'zoo6C','ECOSYS_IFRAC']]
coords = {'x':'TLONG','y':'TLAT'}
keep_vars = variables + list(coords.values())+['dz','KMT','time']

# %%
# %%time

ds_summer_avg = xr.Dataset()
ds_spring_avg = xr.Dataset()
ds_fall_avg = xr.Dataset()
ds_winter_avg =xr.Dataset()

for year in np.arange(63,125,1):
    yr4="0{:02d}".format(year).zfill(4)
    print(year)
    
    ds_summer = xr.Dataset()
    ds_spring = xr.Dataset()
    ds_winter = xr.Dataset()
    ds_fall = xr.Dataset()

    file = sorted(glob(f'{path}/{case}.pop.h.{yr4}-*.nc'))
    
    winter_indexes = [0,1,-1]
    winter_files = [file[ind] for ind in winter_indexes]
    dsv_winter=xr.open_mfdataset(winter_files, decode_times=True,drop_variables=["transport_components", "transport_regions"], 
                            parallel=True, compat="override", combine='nested', concat_dim="time",data_vars="minimal",coords='minimal' )
        
    dsv_summer=xr.open_mfdataset(file[5:8], decode_times=True,drop_variables=["transport_components", "transport_regions"], 
                            parallel=True, compat="override", combine='nested', concat_dim="time",data_vars="minimal",coords='minimal' )
    dsv_spring=xr.open_mfdataset(file[2:5], decode_times=True,drop_variables=["transport_components", "transport_regions"], 
                            parallel=True, compat="override", combine='nested', concat_dim="time",data_vars="minimal",coords='minimal' )
    dsv_fall=xr.open_mfdataset(file[8:11], decode_times=True,drop_variables=["transport_components", "transport_regions"], 
                            parallel=True, compat="override", combine='nested', concat_dim="time",data_vars="minimal",coords='minimal' )
    
    for vv in variables: 
        ds_summer = xr.merge((ds_summer, dsv_summer[vv]))
        ds_spring = xr.merge((ds_spring, dsv_spring[vv]))
        ds_winter = xr.merge((ds_winter, dsv_winter[vv]))
        ds_fall = xr.merge((ds_fall, dsv_fall[vv]))
        

    ds_summer = ds_summer.drop([v for v in ds_summer.variables if v not in keep_vars]).squeeze()
    ds_summer = ds_summer.mean(dim='time')
    ds_summer_avg = xr.concat([ds_summer_avg, ds_summer],dim='year')
    
    ds_spring = ds_spring.drop([v for v in ds_spring.variables if v not in keep_vars]).squeeze()
    ds_spring = ds_spring.mean(dim='time')
    ds_spring_avg = xr.concat([ds_spring_avg, ds_spring],dim='year')
    
    ds_winter = ds_winter.drop([v for v in ds_winter.variables if v not in keep_vars]).squeeze()
    ds_winter = ds_winter.mean(dim='time')
    ds_winter_avg = xr.concat([ds_winter_avg, ds_winter],dim='year')
    
    ds_fall = ds_fall.drop([v for v in ds_fall.variables if v not in keep_vars]).squeeze()
    ds_fall = ds_fall.mean(dim='time')
    ds_fall_avg = xr.concat([ds_fall_avg, ds_fall],dim='year')
# Out:
# 63
# 64
# 65
# 66
# 67
# 68
# 69
# 70
# 71
# 72
# 73
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/magics/execution.py", line 1335, in time
#     exec(code, glob, local_ns)
#   File "<timed exec>", line 25, in <module>
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/backends/api.py", line 931, in open_mfdataset
#     combine_attrs=combine_attrs,
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/combine.py", line 368, in _nested_combine
#     combine_attrs=combine_attrs,
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/combine.py", line 242, in _combine_nd
#     combine_attrs=combine_attrs,
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/combine.py", line 271, in _combine_all_along_first_dim
#     datasets, dim, compat, data_vars, coords, fill_value, join, combine_attrs
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/combine.py", line 301, in _combine_1d
#     combine_attrs=combine_attrs,
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/concat.py", line 243, in concat
#     objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/concat.py", line 518, in _dataset_concat
#     vars = ensure_common_dims([ds[k].variable for ds in datasets])
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/concat.py", line 518, in <listcomp>
#     vars = ensure_common_dims([ds[k].variable for ds in datasets])
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/dataset.py", line 1499, in __getitem__
#     return self._construct_dataarray(key)
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/dataset.py", line 1405, in _construct_dataarray
#     for k in self._variables:
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/interactiveshell.py", line 2098, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/inspect.py", line 1502, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/inspect.py", line 1460, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/inspect.py", line 696, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/inspect.py", line 739, in getmodule
#     f = getabsfile(module)
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/inspect.py", line 708, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/inspect.py", line 693, in getsourcefile
#     if os.path.exists(filename):
#   File "/glade/u/home/gabyn/miniconda3/envs/python-tutorial/lib/python3.7/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1334             try:
# -> 1335                 exec(code, glob, local_ns)
#    1336                 out=None
#
# <timed exec> in <module>
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/backends/api.py in open_mfdataset(paths, chunks, concat_dim, compat, preprocess, engine, data_vars, coords, combine, parallel, join, attrs_file, combine_attrs, **kwargs)
#     930                 join=join,
# --> 931                 combine_attrs=combine_attrs,
#     932             )
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/combine.py in _nested_combine(datasets, concat_dims, compat, data_vars, coords, ids, fill_value, join, combine_attrs)
#     367         join=join,
# --> 368         combine_attrs=combine_attrs,
#     369     )
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/combine.py in _combine_nd(combined_ids, concat_dims, data_vars, coords, compat, fill_value, join, combine_attrs)
#     241             join=join,
# --> 242             combine_attrs=combine_attrs,
#     243         )
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/combine.py in _combine_all_along_first_dim(combined_ids, dim, data_vars, coords, compat, fill_value, join, combine_attrs)
#     270         new_combined_ids[new_id] = _combine_1d(
# --> 271             datasets, dim, compat, data_vars, coords, fill_value, join, combine_attrs
#     272         )
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/combine.py in _combine_1d(datasets, concat_dim, compat, data_vars, coords, fill_value, join, combine_attrs)
#     300                 join=join,
# --> 301                 combine_attrs=combine_attrs,
#     302             )
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/concat.py in concat(objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     242     return f(
# --> 243         objs, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs
#     244     )
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/concat.py in _dataset_concat(datasets, dim, data_vars, coords, compat, positions, fill_value, join, combine_attrs)
#     517             try:
# --> 518                 vars = ensure_common_dims([ds[k].variable for ds in datasets])
#     519             except KeyError:
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/concat.py in <listcomp>(.0)
#     517             try:
# --> 518                 vars = ensure_common_dims([ds[k].variable for ds in datasets])
#     519             except KeyError:
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/dataset.py in __getitem__(self, key)
#    1498         if hashable(key):
# -> 1499             return self._construct_dataarray(key)
#    1500         else:
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/xarray/core/dataset.py in _construct_dataarray(self, name)
#    1404         # preserve ordering
# -> 1405         for k in self._variables:
#    1406             if k in self._coord_names and set(self.variables[k].dims) <= needed_dims:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2097                         # in the engines. This should return a list of strings.
# -> 2098                         stb = value._render_traceback_()
#    2099                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# /glade/scratch/gabyn/ipykernel_240104/4000397346.py in <module>
# ----> 1 get_ipython().run_cell_magic('time', '', '\nds_summer_avg = xr.Dataset()\nds_spring_avg = xr.Dataset()\nds_fall_avg = xr.Dataset()\nds_winter_avg =xr.Dataset()\n\nfor year in np.arange(63,125,1):\n    yr4="0{:02d}".format(year).zfill(4)\n    print(year)\n    \n    ds_summer = xr.Dataset()\n    ds_spring = xr.Dataset()\n    ds_winter = xr.Dataset()\n    ds_fall = xr.Dataset()\n\n    file = sorted(glob(f\'{path}/{case}.pop.h.{yr4}-*.nc\'))\n    \n    winter_indexes = [0,1,-1]\n    winter_files = [file[ind] for ind in winter_indexes]\n    dsv_winter=xr.open_mfdataset(winter_files, decode_times=True,drop_variables=["transport_components", "transport_regions"], \n                            parallel=True, compat="override", combine=\'nested\', concat_dim="time",data_vars="minimal",coords=\'minimal\' )\n        \n    dsv_summer=xr.open_mfdataset(file[5:8], decode_times=True,drop_variables=["transport_components", "transport_regions"], \n                            parallel=True, compat="override", combine=\'nested\', concat_dim="time",data_vars="minimal",coords=\'minimal\' )\n    dsv_spring=xr.open_mfdataset(file[2:5], decode_times=True,drop_variables=["transport_components", "transport_regions"], \n                            parallel=True, compat="override", combine=\'nested\', concat_dim="time",data_vars="minimal",coords=\'minimal\' )\n    dsv_fall=xr.open_mfdataset(file[8:11], decode_times=True,drop_variables=["transport_components", "transport_regions"], \n                            parallel=True, compat="override", combine=\'nested\', concat_dim="time",data_vars="minimal",coords=\'minimal\' )\n    \n    for vv in variables: \n        ds_summer = xr.merge((ds_summer, dsv_summer[vv]))\n        ds_spring = xr.merge((ds_spring, dsv_spring[vv]))\n        ds_winter = xr.merge((ds_winter, dsv_winter[vv]))\n        ds_fall = xr.merge((ds_fall, dsv_fall[vv]))\n        \n\n    ds_summer = ds_summer.drop([v for v in ds_summer.variables if v not in keep_vars]).squeeze()\n    ds_summer = ds_summer.mean(dim=\'time\')\n    ds_summer_avg = xr.concat([ds_summer_avg, ds_summer],dim=\'year\')\n    \n    ds_spring = ds_spring.drop([v for v in ds_spring.variables if v not in keep_vars]).squeeze()\n    ds_spring = ds_spring.mean(dim=\'time\')\n    ds_spring_avg = xr.concat([ds_spring_avg, ds_spring],dim=\'year\')\n    \n    ds_winter = ds_winter.drop([v for v in ds_winter.variables if v not in keep_vars]).squeeze()\n    ds_winter = ds_winter.mean(dim=\'time\')\n    ds_winter_avg = xr.concat([ds_winter_avg, ds_winter],dim=\'year\')\n    \n    ds_fall = ds_fall.drop([v for v in ds_fall.variables if v not in keep_vars]).squeeze()\n    ds_fall = ds_fall.mean(dim=\'time\')\n    ds_fall_avg = xr.concat([ds_fall_avg, ds_fall],dim=\'year\')\n')
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2470             with self.builtin_trap:
#    2471                 args = (magic_arg_s, cell)
# -> 2472                 result = fn(*args, **kwargs)
#    2473             return result
#    2474
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1340                     out = eval(code_2, glob, local_ns)
#    1341             except:
# -> 1342                 self.shell.showtraceback()
#    1343                 return
#    1344             end = clock2()
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2099                     except Exception:
#    2100                         stb = self.InteractiveTB.structured_traceback(etype,
# -> 2101                                             value, tb, tb_offset=tb_offset)
#    2102
#    2103                     self._showtraceback(etype, value, stb)
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
#    1367         return FormattedTB.structured_traceback(
# -> 1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#    1370
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
#    1267             return VerboseTB.structured_traceback(
# -> 1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#    1270         elif mode == 'Minimal':
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
#    1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
# -> 1125                                                                tb_offset)
#    1126
#    1127         colors = self.Colors  # just a shorthand + quicker name lookup
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
# %%time
phytoC_summer = np.stack([ds_summer_avg.zoo1C, ds_summer_avg.zoo2C, ds_summer_avg.zoo3C, 
                   ds_summer_avg.zoo4C, ds_summer_avg.zoo5C, ds_summer_avg.zoo6C])

# %%
# %%time
phytoC_spring = np.stack([ds_spring_avg.zoo1C, ds_spring_avg.zoo2C, ds_spring_avg.zoo3C, 
                   ds_spring_avg.zoo4C, ds_spring_avg.zoo5C, ds_spring_avg.zoo6C])

# %%
# %%time
phytoC_winter = np.stack([ds_winter_avg.zoo1C, ds_winter_avg.zoo2C, ds_winter_avg.zoo3C, 
                   ds_winter_avg.zoo4C, ds_winter_avg.zoo5C, ds_winter_avg.zoo6C])

# %%
# %%time
phytoC_fall = np.stack([ds_fall_avg.zoo1C, ds_fall_avg.zoo2C, ds_fall_avg.zoo3C, 
                   ds_fall_avg.zoo4C, ds_fall_avg.zoo5C, ds_fall_avg.zoo6C])

# %%
# %%time
phytoC_summer_bm = np.nansum(phytoC_summer, axis=(0,2)) * 10/150 #integrate over depth #mmol m-3
phytoC_summer_bm = phytoC_summer_bm * 12.011 *1000 # ug C m-3 --> ugC m^{-3}

phytoC_spring_bm = np.nansum(phytoC_spring, axis=(0,2)) * 10/150 #integrate over depth #mmol m-3
phytoC_spring_bm = phytoC_spring_bm * 12.011 *1000 # ug C m-3 --> ugC m^{-3}

phytoC_fall_bm = np.nansum(phytoC_fall, axis=(0,2)) * 10/150 #integrate over depth #mmol m-3
phytoC_fall_bm = phytoC_fall_bm * 12.011 *1000 # ug C m-3 --> ugC m^{-3}

phytoC_winter_bm = np.nansum(phytoC_winter, axis=(0,2)) * 10/150 #integrate over depth #mmol m-3
phytoC_winter_bm = phytoC_winter_bm * 12.011 *1000 # ug C m-3 --> ugC m^{-3}

# %%
phytoC_summer_bm[phytoC_summer_bm<0] ==np.nan
phytoC_spring_bm[phytoC_spring_bm<0] ==np.nan
phytoC_fall_bm[phytoC_fall_bm<0] ==np.nan
phytoC_winter_bm[phytoC_winter_bm<0] ==np.nan

# %%
phytoC_summer_bm

# %%
zoo_bmss = xr.DataArray(phytoC_summer_bm, coords={'year':ds_fall_avg.year, 'TLAT':ds_fall_avg.TLAT, 'TLONG':ds_fall_avg.TLONG},
                      dims=['year', 'nlat', 'nlon'])
zoo_bmss = zoo_bmss.to_dataset(name='zooC_summer_bm')

zoo_bmss['zooC_spring_bm'] = xr.DataArray(phytoC_spring_bm, coords={'year':ds_fall_avg.year, 'TLAT':ds_fall_avg.TLAT, 'TLONG':ds_fall_avg.TLONG},
                      dims=['year', 'nlat', 'nlon'])

zoo_bmss['zooC_fall_bm'] = xr.DataArray(phytoC_fall_bm, coords={'year':ds_fall_avg.year, 'TLAT':ds_fall_avg.TLAT, 'TLONG':ds_fall_avg.TLONG},
                      dims=['year', 'nlat', 'nlon'])

zoo_bmss['zooC_winter_bm'] = xr.DataArray(phytoC_winter_bm, coords={'year':ds_fall_avg.year, 'TLAT':ds_fall_avg.TLAT, 'TLONG':ds_fall_avg.TLONG},
                      dims=['year', 'nlat', 'nlon'])

# %%
zoo_bmss.to_netcdf('/glade/u/home/gabyn/scratch/SPECTRA/nc_files/zoo_bmss_62yr.nc');
# Out:
# 	NC4_create: path /glade/u/home/gabyn/scratch/SPECTRA/nc_files/phytoC_summer_bm.nc cmode 0x1000 parameters (nil)
# 	HDF5 error messages turned on.
# 			nc4_create_file: path /glade/u/home/gabyn/scratch/SPECTRA/nc_files/phytoC_summer_bm.nc mode 0x1000
# 			nc4_grp_list_add: name /
# 		nc_inq_format: ncid 0x520000
# 		NC4_inq_format_extended: ncid 0x520000
# 		nc_inq_typeids: ncid 0x520000
# 		NC4_inq: ncid 0x520000
# 		NC4_inq: ncid 0x520000
# 		nc_inq_grps: ncid 0x520000
# 		NC4_def_dim: ncid 0x520000 name time len 62
# 		NC4_def_dim: ncid 0x520000 name nlat len 384
# 		NC4_def_dim: ncid 0x520000 name nlon len 320
# 		NC4_def_var: name time type 10 ndims 1
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_var_all: ncid 0x520000 varid 0
# 		NC4_inq_var_all: ncid 0x520000 varid 0
# 		NC4_inq_var_all: ncid 0x520000 varid 0
# 		NC4_inq_var_all: ncid 0x520000 varid 0
# 		NC4_inq_dim: ncid 0x520000 dimid 0
# 		NC4_inq_dim: ncid 0x520000 dimid 0
# 		NC4_inq_var_all: ncid 0x520000 varid 0
# 		NC4_inq_var_all: ncid 0x520000 varid 0
# 		NC4_inq_dim: ncid 0x520000 dimid 0
# 		NC4_inq_dim: ncid 0x520000 dimid 0
# 		NC4_inq_var_all: ncid 0x520000 varid 0
# 		NC4_inq_var_all: ncid 0x520000 varid 0
# 		NC4_inq_dim: ncid 0x520000 dimid 0
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_var_all: ncid 0x520000 varid 0
# 		NC4_inq_var_all: ncid 0x520000 varid 0
# 		NC4_inq_dim: ncid 0x520000 dimid 0
# 		NC4_inq_var_all: ncid 0x520000 varid 0
# 			NC4_put_vars: var->hdr.name time mem_nc_type 10
# 			nc4_enddef_netcdf4_file
# 			sync_netcdf4_file
# 		*** NetCDF-4 Internal Metadata: int_ncid 0x520000 ext_ncid 0x520000
# 		FILE - path: /glade/u/home/gabyn/scratch/SPECTRA/nc_files/phytoC_summer_bm.nc cmode: 0x1009 parallel: 0 redef: 0 fill_mode: 0 no_write: 0 next_nc_grpid: 1
# 		 GROUP - / nc_grpid: 0 nvars: 1 natts: 0
# 		 DIMENSION - dimid: 0 name: time len: 62 unlimited: 0
# 		 DIMENSION - dimid: 1 name: nlat len: 384 unlimited: 0
# 		 DIMENSION - dimid: 2 name: nlon len: 320 unlimited: 0
# 		 VARIABLE - varid: 0 name: time ndims: 1 dimscale: 1 dimids: 0
# 			nc4_rec_write_groups_types: grp->hdr.name /
# 			nc4_rec_write_metadata: grp->hdr.name /, bad_coord_order 1
# 			var_create_dataset:: name time
# 	NC4_redef: ncid 0x520000
# 		NC4_def_var: name TLAT type 6 ndims 2
# 		nc_inq_format: ncid 0x520000
# 	nc4_put_att: ncid 0x520000 varid 1 name _FillValue file_type 6 mem_type 6 len 1
# 	nc4_put_att: ncid 0x520000 varid 1 name _FillValue file_type 6 mem_type 6 len 1
# 			adding attribute _FillValue to the list...
# 			nc4_att_list_add: name _FillValue
# 			nc4_convert_type: len 1 src_type 6 dest_type 6
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_var_all: ncid 0x520000 varid 1
# 		NC4_inq_var_all: ncid 0x520000 varid 1
# 		nc_inq_attname: ncid 0x520000 varid 1 attnum 0
# 		nc_inq_format: ncid 0x520000
# 	nc4_put_att: ncid 0x520000 varid 1 name long_name file_type 2 mem_type 2 len 25
# 	nc4_put_att: ncid 0x520000 varid 1 name long_name file_type 2 mem_type 2 len 25
# 			adding attribute long_name to the list...
# 			nc4_att_list_add: name long_name
# 			nc4_convert_type: len 25 src_type 2 dest_type 2
# 		nc_inq_format: ncid 0x520000
# 	nc4_put_att: ncid 0x520000 varid 1 name units file_type 2 mem_type 2 len 13
# 	nc4_put_att: ncid 0x520000 varid 1 name units file_type 2 mem_type 2 len 13
# 			adding attribute units to the list...
# 			nc4_att_list_add: name units
# 			nc4_convert_type: len 13 src_type 2 dest_type 2
# 		NC4_inq_var_all: ncid 0x520000 varid 1
# 		NC4_inq_var_all: ncid 0x520000 varid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_var_all: ncid 0x520000 varid 1
# 		NC4_inq_var_all: ncid 0x520000 varid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_var_all: ncid 0x520000 varid 1
# 		NC4_inq_var_all: ncid 0x520000 varid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_var_all: ncid 0x520000 varid 1
# 		NC4_inq_var_all: ncid 0x520000 varid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_var_all: ncid 0x520000 varid 1
# 			NC4_put_vars: var->hdr.name TLAT mem_nc_type 6
# 			nc4_enddef_netcdf4_file
# 			sync_netcdf4_file
# 		*** NetCDF-4 Internal Metadata: int_ncid 0x520000 ext_ncid 0x520000
# 		FILE - path: /glade/u/home/gabyn/scratch/SPECTRA/nc_files/phytoC_summer_bm.nc cmode: 0x1009 parallel: 0 redef: 0 fill_mode: 0 no_write: 0 next_nc_grpid: 1
# 		 GROUP - / nc_grpid: 0 nvars: 2 natts: 0
# 		 DIMENSION - dimid: 0 name: time len: 62 unlimited: 0
# 		 DIMENSION - dimid: 1 name: nlat len: 384 unlimited: 0
# 		 DIMENSION - dimid: 2 name: nlon len: 320 unlimited: 0
# 		 VARIABLE - varid: 0 name: time ndims: 1 dimscale: 1 dimids: 0
# 		 VARIABLE - varid: 1 name: TLAT ndims: 2 dimscale: 0 dimids: 1 2
# 		 VAR ATTRIBUTE - attnum: 0 name: _FillValue type: 6 len: 1
# 		 VAR ATTRIBUTE - attnum: 1 name: long_name type: 2 len: 25
# 		 VAR ATTRIBUTE - attnum: 2 name: units type: 2 len: 13
# 			nc4_rec_write_groups_types: grp->hdr.name /
# 			nc4_rec_write_metadata: grp->hdr.name /, bad_coord_order 0
# 			var_create_dataset:: name TLAT
# 			put_att_grpa: varid 1 att->hdr.id 0 att->hdr.name _FillValue att->nc_typeid 6 att->len 1
# 			put_att_grpa: varid 1 att->hdr.id 1 att->hdr.name long_name att->nc_typeid 2 att->len 25
# 			put_att_grpa: varid 1 att->hdr.id 2 att->hdr.name units att->nc_typeid 2 att->len 13
# 		attach_dimscales: attaching scale for dimid 1 to var TLAT
# 		attach_dimscales: attaching scale for dimid 2 to var TLAT
# 	NC4_redef: ncid 0x520000
# 		NC4_def_var: name TLONG type 6 ndims 2
# 		nc_inq_format: ncid 0x520000
# 	nc4_put_att: ncid 0x520000 varid 2 name _FillValue file_type 6 mem_type 6 len 1
# 	nc4_put_att: ncid 0x520000 varid 2 name _FillValue file_type 6 mem_type 6 len 1
# 			adding attribute _FillValue to the list...
# 			nc4_att_list_add: name _FillValue
# 			nc4_convert_type: len 1 src_type 6 dest_type 6
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_var_all: ncid 0x520000 varid 2
# 		NC4_inq_var_all: ncid 0x520000 varid 2
# 		nc_inq_attname: ncid 0x520000 varid 2 attnum 0
# 		nc_inq_format: ncid 0x520000
# 	nc4_put_att: ncid 0x520000 varid 2 name long_name file_type 2 mem_type 2 len 26
# 	nc4_put_att: ncid 0x520000 varid 2 name long_name file_type 2 mem_type 2 len 26
# 			adding attribute long_name to the list...
# 			nc4_att_list_add: name long_name
# 			nc4_convert_type: len 26 src_type 2 dest_type 2
# 		nc_inq_format: ncid 0x520000
# 	nc4_put_att: ncid 0x520000 varid 2 name units file_type 2 mem_type 2 len 12
# 	nc4_put_att: ncid 0x520000 varid 2 name units file_type 2 mem_type 2 len 12
# 			adding attribute units to the list...
# 			nc4_att_list_add: name units
# 			nc4_convert_type: len 12 src_type 2 dest_type 2
# 		NC4_inq_var_all: ncid 0x520000 varid 2
# 		NC4_inq_var_all: ncid 0x520000 varid 2
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_var_all: ncid 0x520000 varid 2
# 		NC4_inq_var_all: ncid 0x520000 varid 2
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_var_all: ncid 0x520000 varid 2
# 		NC4_inq_var_all: ncid 0x520000 varid 2
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_var_all: ncid 0x520000 varid 2
# 		NC4_inq_var_all: ncid 0x520000 varid 2
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_var_all: ncid 0x520000 varid 2
# 			NC4_put_vars: var->hdr.name TLONG mem_nc_type 6
# 			nc4_enddef_netcdf4_file
# 			sync_netcdf4_file
# 		*** NetCDF-4 Internal Metadata: int_ncid 0x520000 ext_ncid 0x520000
# 		FILE - path: /glade/u/home/gabyn/scratch/SPECTRA/nc_files/phytoC_summer_bm.nc cmode: 0x1009 parallel: 0 redef: 0 fill_mode: 0 no_write: 0 next_nc_grpid: 1
# 		 GROUP - / nc_grpid: 0 nvars: 3 natts: 0
# 		 DIMENSION - dimid: 0 name: time len: 62 unlimited: 0
# 		 DIMENSION - dimid: 1 name: nlat len: 384 unlimited: 0
# 		 DIMENSION - dimid: 2 name: nlon len: 320 unlimited: 0
# 		 VARIABLE - varid: 0 name: time ndims: 1 dimscale: 1 dimids: 0
# 		 VARIABLE - varid: 1 name: TLAT ndims: 2 dimscale: 0 dimids: 1 2
# 		 VAR ATTRIBUTE - attnum: 0 name: _FillValue type: 6 len: 1
# 		 VAR ATTRIBUTE - attnum: 1 name: long_name type: 2 len: 25
# 		 VAR ATTRIBUTE - attnum: 2 name: units type: 2 len: 13
# 		 VARIABLE - varid: 2 name: TLONG ndims: 2 dimscale: 0 dimids: 1 2
# 		 VAR ATTRIBUTE - attnum: 0 name: _FillValue type: 6 len: 1
# 		 VAR ATTRIBUTE - attnum: 1 name: long_name type: 2 len: 26
# 		 VAR ATTRIBUTE - attnum: 2 name: units type: 2 len: 12
# 			nc4_rec_write_groups_types: grp->hdr.name /
# 			nc4_rec_write_metadata: grp->hdr.name /, bad_coord_order 0
# 			var_create_dataset:: name TLONG
# 			put_att_grpa: varid 2 att->hdr.id 0 att->hdr.name _FillValue att->nc_typeid 6 att->len 1
# 			put_att_grpa: varid 2 att->hdr.id 1 att->hdr.name long_name att->nc_typeid 2 att->len 26
# 			put_att_grpa: varid 2 att->hdr.id 2 att->hdr.name units att->nc_typeid 2 att->len 12
# 		attach_dimscales: attaching scale for dimid 1 to var TLONG
# 		attach_dimscales: attaching scale for dimid 2 to var TLONG
# 	NC4_redef: ncid 0x520000
# 		NC4_def_var: name phytoC_150m type 5 ndims 3
# 		nc_inq_format: ncid 0x520000
# 	nc4_put_att: ncid 0x520000 varid 3 name _FillValue file_type 5 mem_type 5 len 1
# 	nc4_put_att: ncid 0x520000 varid 3 name _FillValue file_type 5 mem_type 5 len 1
# 			adding attribute _FillValue to the list...
# 			nc4_att_list_add: name _FillValue
# 			nc4_convert_type: len 1 src_type 5 dest_type 5
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_var_all: ncid 0x520000 varid 3
# 		NC4_inq_var_all: ncid 0x520000 varid 3
# 		nc_inq_attname: ncid 0x520000 varid 3 attnum 0
# 		nc_inq_format: ncid 0x520000
# 	nc4_put_att: ncid 0x520000 varid 3 name description file_type 2 mem_type 2 len 57
# 	nc4_put_att: ncid 0x520000 varid 3 name description file_type 2 mem_type 2 len 57
# 			adding attribute description to the list...
# 			nc4_att_list_add: name description
# 			nc4_convert_type: len 57 src_type 2 dest_type 2
# 		nc_inq_format: ncid 0x520000
# 	nc4_put_att: ncid 0x520000 varid 3 name units file_type 2 mem_type 2 len 10
# 	nc4_put_att: ncid 0x520000 varid 3 name units file_type 2 mem_type 2 len 10
# 			adding attribute units to the list...
# 			nc4_att_list_add: name units
# 			nc4_convert_type: len 10 src_type 2 dest_type 2
# 		nc_inq_format: ncid 0x520000
# 	nc4_put_att: ncid 0x520000 varid 3 name coordinates file_type 2 mem_type 2 len 10
# 	nc4_put_att: ncid 0x520000 varid 3 name coordinates file_type 2 mem_type 2 len 10
# 			adding attribute coordinates to the list...
# 			nc4_att_list_add: name coordinates
# 			nc4_convert_type: len 10 src_type 2 dest_type 2
# 		NC4_inq_var_all: ncid 0x520000 varid 3
# 		NC4_inq_var_all: ncid 0x520000 varid 3
# 		NC4_inq_dim: ncid 0x520000 dimid 0
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_dim: ncid 0x520000 dimid 0
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_var_all: ncid 0x520000 varid 3
# 		NC4_inq_var_all: ncid 0x520000 varid 3
# 		NC4_inq_dim: ncid 0x520000 dimid 0
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_dim: ncid 0x520000 dimid 0
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_var_all: ncid 0x520000 varid 3
# 		NC4_inq_var_all: ncid 0x520000 varid 3
# 		NC4_inq_dim: ncid 0x520000 dimid 0
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_unlimdims: ncid 0x520000
# 		NC4_inq_var_all: ncid 0x520000 varid 3
# 		NC4_inq_var_all: ncid 0x520000 varid 3
# 		NC4_inq_dim: ncid 0x520000 dimid 0
# 		NC4_inq_dim: ncid 0x520000 dimid 1
# 		NC4_inq_dim: ncid 0x520000 dimid 2
# 		NC4_inq_var_all: ncid 0x520000 varid 3
# 			NC4_put_vars: var->hdr.name phytoC_150m mem_nc_type 5
# 			nc4_enddef_netcdf4_file
# 			sync_netcdf4_file
# 		*** NetCDF-4 Internal Metadata: int_ncid 0x520000 ext_ncid 0x520000
# 		FILE - path: /glade/u/home/gabyn/scratch/SPECTRA/nc_files/phytoC_summer_bm.nc cmode: 0x1009 parallel: 0 redef: 0 fill_mode: 0 no_write: 0 next_nc_grpid: 1
# 		 GROUP - / nc_grpid: 0 nvars: 4 natts: 0
# 		 DIMENSION - dimid: 0 name: time len: 62 unlimited: 0
# 		 DIMENSION - dimid: 1 name: nlat len: 384 unlimited: 0
# 		 DIMENSION - dimid: 2 name: nlon len: 320 unlimited: 0
# 		 VARIABLE - varid: 0 name: time ndims: 1 dimscale: 1 dimids: 0
# 		 VARIABLE - varid: 1 name: TLAT ndims: 2 dimscale: 0 dimids: 1 2
# 		 VAR ATTRIBUTE - attnum: 0 name: _FillValue type: 6 len: 1
# 		 VAR ATTRIBUTE - attnum: 1 name: long_name type: 2 len: 25
# 		 VAR ATTRIBUTE - attnum: 2 name: units type: 2 len: 13
# 		 VARIABLE - varid: 2 name: TLONG ndims: 2 dimscale: 0 dimids: 1 2
# 		 VAR ATTRIBUTE - attnum: 0 name: _FillValue type: 6 len: 1
# 		 VAR ATTRIBUTE - attnum: 1 name: long_name type: 2 len: 26
# 		 VAR ATTRIBUTE - attnum: 2 name: units type: 2 len: 12
# 		 VARIABLE - varid: 3 name: phytoC_150m ndims: 3 dimscale: 0 dimids: 0 1 2
# 		 VAR ATTRIBUTE - attnum: 0 name: _FillValue type: 5 len: 1
# 		 VAR ATTRIBUTE - attnum: 1 name: description type: 2 len: 57
# 		 VAR ATTRIBUTE - attnum: 2 name: units type: 2 len: 10
# 		 VAR ATTRIBUTE - attnum: 3 name: coordinates type: 2 len: 10
# 			nc4_rec_write_groups_types: grp->hdr.name /
# 			nc4_rec_write_metadata: grp->hdr.name /, bad_coord_order 0
# 			var_create_dataset:: name phytoC_150m
# 			put_att_grpa: varid 3 att->hdr.id 0 att->hdr.name _FillValue att->nc_typeid 5 att->len 1
# 			put_att_grpa: varid 3 att->hdr.id 1 att->hdr.name description att->nc_typeid 2 att->len 57
# 			put_att_grpa: varid 3 att->hdr.id 2 att->hdr.name units att->nc_typeid 2 att->len 10
# 			put_att_grpa: varid 3 att->hdr.id 3 att->hdr.name coordinates att->nc_typeid 2 att->len 10
# 		attach_dimscales: attaching scale for dimid 0 to var phytoC_150m
# 		attach_dimscales: attaching scale for dimid 1 to var phytoC_150m
# 		attach_dimscales: attaching scale for dimid 2 to var phytoC_150m
# 	NC4_close: ncid 0x520000
# 			nc4_close_hdf5_file: h5->path /glade/u/home/gabyn/scratch/SPECTRA/nc_files/phytoC_summer_bm.nc abort 0
# 			sync_netcdf4_file
# 		*** NetCDF-4 Internal Metadata: int_ncid 0x520000 ext_ncid 0x520000
# 		FILE - path: /glade/u/home/gabyn/scratch/SPECTRA/nc_files/phytoC_summer_bm.nc cmode: 0x1009 parallel: 0 redef: 0 fill_mode: 0 no_write: 0 next_nc_grpid: 1
# 		 GROUP - / nc_grpid: 0 nvars: 4 natts: 0
# 		 DIMENSION - dimid: 0 name: time len: 62 unlimited: 0
# 		 DIMENSION - dimid: 1 name: nlat len: 384 unlimited: 0
# 		 DIMENSION - dimid: 2 name: nlon len: 320 unlimited: 0
# 		 VARIABLE - varid: 0 name: time ndims: 1 dimscale: 1 dimids: 0
# 		 VARIABLE - varid: 1 name: TLAT ndims: 2 dimscale: 0 dimids: 1 2
# 		 VAR ATTRIBUTE - attnum: 0 name: _FillValue type: 6 len: 1
# 		 VAR ATTRIBUTE - attnum: 1 name: long_name type: 2 len: 25
# 		 VAR ATTRIBUTE - attnum: 2 name: units type: 2 len: 13
# 		 VARIABLE - varid: 2 name: TLONG ndims: 2 dimscale: 0 dimids: 1 2
# 		 VAR ATTRIBUTE - attnum: 0 name: _FillValue type: 6 len: 1
# 		 VAR ATTRIBUTE - attnum: 1 name: long_name type: 2 len: 26
# 		 VAR ATTRIBUTE - attnum: 2 name: units type: 2 len: 12
# 		 VARIABLE - varid: 3 name: phytoC_150m ndims: 3 dimscale: 0 dimids: 0 1 2
# 		 VAR ATTRIBUTE - attnum: 0 name: _FillValue type: 5 len: 1
# 		 VAR ATTRIBUTE - attnum: 1 name: description type: 2 len: 57
# 		 VAR ATTRIBUTE - attnum: 2 name: units type: 2 len: 10
# 		 VAR ATTRIBUTE - attnum: 3 name: coordinates type: 2 len: 10
# 			nc4_rec_write_groups_types: grp->hdr.name /
# 			nc4_rec_write_metadata: grp->hdr.name /, bad_coord_order 0
# 			nc4_rec_grp_HDF5_del: grp->name /
# 			closing HDF5 dataset 360287970189639680
# 			closing HDF5 dataset 360287970189639683
# 			closing HDF5 dataset 360287970189639684
# 			closing HDF5 dataset 360287970189639685
# 			nc4_close_netcdf4_file: h5->path /glade/u/home/gabyn/scratch/SPECTRA/nc_files/phytoC_summer_bm.nc abort 0
# 			nc4_rec_grp_del: grp->name /
# 			att_free: name _FillValue
# 			att_free: name long_name
# 			att_free: name units
# 			att_free: name _FillValue
# 			att_free: name long_name
# 			att_free: name units
# 			att_free: name _FillValue
# 			att_free: name description
# 			att_free: name units
# 			att_free: name coordinates
