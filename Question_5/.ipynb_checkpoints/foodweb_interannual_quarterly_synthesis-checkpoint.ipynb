# %% [markdown]
# # Plankton food web grazing fluxes between cold and warm periods
# ### Here, I will plot the fraction between net autotrophic and net heterotrophic grazing fluxes by adding the grazing fluxes from phytoplankton to zooplankton in the nominator and the grazing fluxes between zooplankton and other zooplankton in the denominator.
#     - values less than 1 = Net heterotrophic fluxes dominate
#     - values equal to 1 = net heterorophy equals net autotrophy
#     - values less than 1 = net autotophy domaintes.

# %%
import warnings
warnings.simplefilter("ignore") # Silence warnings
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import numpy as np
import xarray as xr
import numpy as np
from matplotlib.pyplot import figure
import numpy.ma as ma
from netCDF4 import Dataset as NetCDFFile
import glob
import cartopy
import cartopy.crs as ccrs
import pylab
from copy import deepcopy
import pandas as pd
import matplotlib
import matplotlib.colors as colors
from cartopy.util import add_cyclic_point
import matplotlib.gridspec as gridspec
plt.rcParams['mathtext.default']='regular'
from collections import OrderedDict
import cmocean
import matplotlib.cm as cm
import matplotlib as mpl
import seaborn as sns

# Scientific libraries
from numpy import arange,array,ones
from scipy import stats
import os
import matplotlib.gridspec as gridspec

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
def adjust_pop_grid(tlon,tlat,field):
    nj = tlon.shape[0]
    ni = tlon.shape[1]
    xL = int(ni/2 - 1)
    xR = int(xL + ni)

    tlon = np.where(np.greater_equal(tlon,np.min(tlon[:,0])),tlon-360.,tlon)
    lon  = np.concatenate((tlon,tlon+360.),1)
    lon = lon[:,xL:xR]

    if ni == 320:
        lon[367:-3,0] = lon[367:-3,0]+360.
    lon = lon - 360.
    lon = np.hstack((lon,lon[:,0:1]+360.))
    if ni == 320:
        lon[367:,-1] = lon[367:,-1] - 360.

    #-- trick cartopy into doing the right thing:
    #   it gets confused when the cyclic coords are identical
    lon[:,0] = lon[:,0]-1e-8

    #-- periodicity
    lat  = np.concatenate((tlat,tlat),1)
    lat = lat[:,xL:xR]
    lat = np.hstack((lat,lat[:,0:1]))

    field = np.ma.concatenate((field,field),1)
    field = field[:,xL:xR]
    field = np.ma.hstack((field,field[:,0:1]))
    return lon,lat,field

# %% [markdown]
# ## Load size abundance slope for the 62 yr period

# %%
### All 63 years of the 2nd cycle 
newNCDFfiles1 = sorted(glob.glob('/glade/scratch/gabyn/SPECTRA/GNG595_monthly_yearly_1948_2009/SPECTRA_*.nc', recursive=True),
                      key=numericalSort)

ds = xr.open_mfdataset(newNCDFfiles1,combine='by_coords')

# %% [markdown]
# ## We want grazing from zooplankton to zooplankton & phytoplankton to zooplankton

# %%
## Gaby's Path 
jluo_path = '/glade/u/home/jluo/cesm_scripts/size_structured/nl_input/cases/g.e21.G1850ECOIAF.t62_g17.marbl0_33.'
gabyn_path = '/glade/u/home/gabyn/case_notes/spectral_cases/g.e21.G1850ECOIAF.t62_g17.marbl0_33.'
nl_config = os.path.join(''+gabyn_path+'GNG595/data/')
sizes = pd.read_csv(nl_config+'plankton_sizes.csv')
sizes = sizes.sort_values('mmolC')
sizes
# Out:
#      type  sname      mass_ugC       vol_um3     ESD_mm  Qp_fixed  \
# 1   phyto     pp  9.266989e-08  3.706795e-01   0.000891  0.004651
# 2   phyto    mp1  8.241979e-06  1.805089e+01   0.003255  0.006824
# 0   phyto   diaz  5.499929e-05  1.227865e+02   0.006167  0.003333
# 3   phyto    mp2  8.888712e-05  8.790197e+02   0.011885  0.008656
# 6   phyto  diat1  5.004513e-04  1.327390e+04   0.029376  0.010289
# 9     zoo   zoo1  2.803686e-03  2.355042e+04   0.035563  0.008547
# 7   phyto  diat2  3.803133e-03  1.326626e+05   0.063278  0.012602
# 4   phyto    mp3  4.830334e-03  4.280541e+04   0.043401  0.012907
# 8   phyto  diat3  2.890156e-02  1.325863e+06   0.136301  0.015435
# 10    zoo   zoo2  8.933984e-02  7.447577e+05   0.112462  0.008547
# 5   phyto    mp4  1.855836e-01  2.084484e+06   0.158489  0.018590
# 11    zoo   zoo3  2.825280e+00  2.355219e+07   0.355640  0.008547
# 12    zoo   zoo4  8.934658e+01  7.448139e+08   1.124647  0.008547
# ...

# %%
prey_varnames = {}
for i,v in enumerate(sizes.sname):
    prey_varnames[v]=i

# %%
grazing_vars = [v for v in ds if 'graze' in v and 'zint' not in v]

# %%
phyto_grazing = grazing_vars[0:27] # only the zooplankton and phytoplankton grazing. 
zoo_grazing = grazing_vars[27:36] # only the zooplankton and zooplankton grazing.

# %%
phyto_zoo_grazing = xr.concat([ds[w] for w in phyto_grazing], dim='new_dim') # units are mmol/m^3/s
zoo_zoo_grazing = xr.concat([ds[z] for z in zoo_grazing], dim='new_dim') # units are mmol/m^3/s

# %% [markdown]
# ## Import sum of phytoplankton to zooplankton grazing

# %%
phyto_zoo_ds_inter = np.load("/glade/scratch/gabyn/SPECTRA/phyto_zoo_ds_inter.npy")

# %%
### [THIS IS THE CODE THAT PROVIDED -- phyto_zoo_ds_inter.npy]
phyto_zoo_150m_grazing = np.sum(phyto_zoo_grazing, axis=2) * 10/150 *(60*60*24*365) #integrate over depth #mmol m-3 y-1

#### had to separate it to be able to run faster without crashing! 
phyto_zoo_ds_inter = np.empty([27,63,12,384,320])
phyto_zoo_ds_inter[:] = np.nan
x = np.array(range(0,756,12)) ## this loops from 0 to 2016, and selects every 12th number. 
for i in range(0,10):
    phyto_zoo_ds_inter[:,i,:,:,:] = phyto_zoo_150m_grazing[:,x[i]:x[i]+12,:,:]
    
x = np.array(range(0,756,12)) ## this loops from 0 to 2016, and selects every 12th number. 
for i in range(10,20):
    phyto_zoo_ds_inter[:,i,:,:,:] = phyto_zoo_150m_grazing[:,x[i]:x[i]+12,:,:]
    
x = np.array(range(0,756,12)) ## this loops from 0 to 2016, and selects every 12th number. 
for i in range(20,30):
    phyto_zoo_ds_inter[:,i,:,:,:] = phyto_zoo_150m_grazing[:,x[i]:x[i]+12,:,:]
    
x = np.array(range(0,756,12)) ## this loops from 0 to 2016, and selects every 12th number. 
for i in range(30,40):
    phyto_zoo_ds_inter[:,i,:,:,:] = phyto_zoo_150m_grazing[:,x[i]:x[i]+12,:,:]

x = np.array(range(0,756,12)) ## this loops from 0 to 2016, and selects every 12th number. 
for i in range(40,50):
    phyto_zoo_ds_inter[:,i,:,:,:] = phyto_zoo_150m_grazing[:,x[i]:x[i]+12,:,:]
    
x = np.array(range(0,756,12)) ## this loops from 0 to 2016, and selects every 12th number. 
for i in range(50,63):
    phyto_zoo_ds_inter[:,i,:,:,:] = phyto_zoo_150m_grazing[:,x[i]:x[i]+12,:,:]
    
np.save("/glade/scratch/gabyn/SPECTRA/phyto_zoo_ds_inter.npy",phyto_zoo_ds_inter)

# %% [markdown]
# ## Code that separated by quarters, added all fluxes and was saved!
# #### Separate Quarterly
# * Winter: December, January and February
# * Spring : March, April, May
# * Summer : June, July, August
# * Fall : September, October, November

# %% [markdown]
# phyto_zoo_ds_inter_sum_winter = np.nanmean(phyto_zoo_ds_inter[:,:,list(range(2)) + [-1],:,:],axis=(2)) # sum through the years and the
# phyto_zoo_ds_inter_spring = np.nanmean(phyto_zoo_ds_inter[:,:,2:5,:,:],axis=(2)) # sum through the years and the
# phyto_zoo_ds_inter_summer = np.nanmean(phyto_zoo_ds_inter[:,:,5:8,:,:],axis=(2)) # sum through the years and the
# phyto_zoo_ds_inter_fall = np.nanmean(phyto_zoo_ds_inter[:,:,8:11,:,:],axis=(2)) # sum through the years and the
#
# phyto_zoo_sum_winter = np.nansum(phyto_zoo_ds_inter_sum_winter,axis=0)
# phyto_zoo_sum_spring = np.nansum(phyto_zoo_ds_inter_spring,axis=0)
# phyto_zoo_sum_summer = np.nansum(phyto_zoo_ds_inter_summer,axis=0)
# phyto_zoo_sum_fall = np.nansum(phyto_zoo_ds_inter_fall,axis=0)
#
# np.save("/glade/scratch/gabyn/SPECTRA/phyto_zoo_sum_winter.npy",phyto_zoo_sum_winter)
# np.save("/glade/scratch/gabyn/SPECTRA/phyto_zoo_sum_spring.npy",phyto_zoo_sum_spring)
# np.save("/glade/scratch/gabyn/SPECTRA/phyto_zoo_sum_summer.npy",phyto_zoo_sum_summer)
# np.save("/glade/scratch/gabyn/SPECTRA/phyto_zoo_sum_fall.npy",phyto_zoo_sum_fall)

# %%
phyto_zoo_sum_winter = np.load("/glade/scratch/gabyn/SPECTRA/phyto_zoo_sum_winter.npy")
phyto_zoo_sum_spring = np.load("/glade/scratch/gabyn/SPECTRA/phyto_zoo_sum_spring.npy")
phyto_zoo_sum_summer = np.load("/glade/scratch/gabyn/SPECTRA/phyto_zoo_sum_summer.npy")
phyto_zoo_sum_fall = np.load("/glade/scratch/gabyn/SPECTRA/phyto_zoo_sum_fall.npy")

# %%
fig = plt.figure(figsize=(15, 10))
lat = ds.TLAT
lev = np.arange(0, 10, 0.1)
norm = colors.DivergingNorm(vmin=lev[0], vmax=lev[-1], vcenter=5)

## WINTER 
ax = fig.add_subplot(2, 2, 1, projection=ccrs.Robinson(central_longitude=305.0))
tlon, tlat, phyto = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_sum_winter,axis=0))
cf = ax.contourf(tlon, tlat, phyto, extend='both',cmap='Spectral_r',transform=ccrs.PlateCarree());
land = ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'))
cb = plt.colorbar(cf,shrink=0.5,orientation='horizontal')
cb.ax.tick_params(labelsize=20)
ax.set_title('Winter', fontsize =16)


## SPRING
ax = fig.add_subplot(2, 2, 2, projection=ccrs.Robinson(central_longitude=305.0))
tlon, tlat, phyto = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_sum_spring,axis=0))
cf = ax.contourf(tlon, tlat, phyto, extend='both',cmap='Spectral_r',transform=ccrs.PlateCarree());
land = ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'))
cb = plt.colorbar(cf,shrink=0.5,orientation='horizontal')
cb.ax.tick_params(labelsize=20)
ax.set_title('Spring', fontsize =16)

## SUMMER
ax = fig.add_subplot(2, 2, 3, projection=ccrs.Robinson(central_longitude=305.0))
tlon, tlat, phyto = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_sum_summer,axis=0))
cf = ax.contourf(tlon, tlat, phyto,  extend='both',cmap='Spectral_r',transform=ccrs.PlateCarree());
land = ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'))
cb = plt.colorbar(cf,shrink=0.5,orientation='horizontal')
cb.ax.tick_params(labelsize=20)
ax.set_title('Summer', fontsize =16)


##FALL
ax = fig.add_subplot(2, 2, 4, projection=ccrs.Robinson(central_longitude=305.0))
tlon, tlat, phyto = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_sum_fall,axis=0))
cf = ax.contourf(tlon, tlat, phyto, extend='both',cmap='Spectral_r',transform=ccrs.PlateCarree());
land = ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'))
cb = plt.colorbar(cf,shrink=0.5,orientation='horizontal')
cb.ax.tick_params(labelsize=20)
ax.set_title('Fall', fontsize =16);
fig.tight_layout()
fig.savefig('/glade/u/home/gabyn/case_notes/analysis_figures/GNG595/global_phyto_zoo_grazing_fluxes_quarterly_150m.png',dpi=200, bbox_inches='tight')

# %% [markdown]
# ## Now do the same for all zooplankton!

# %%
zoo_zoo_grazing_150m =  np.sum(zoo_zoo_grazing, axis=2) * 10/150 *(60*60*24*365) #integrate over depth #mmol m-3 y-1

# %%
zoo_zoo_grazing_150m.shape
# Out:
# (9, 756, 384, 320)

# %%
zoo_zoo_ds_inter = np.empty([9,63,12,384,320])
zoo_zoo_ds_inter[:] = np.nan
x = np.array(range(0,756,12)) ## this loops from 0 to 2016, and selects every 12th number. 
for i in range(0,20):
    zoo_zoo_ds_inter[:,i,:,:,:] = zoo_zoo_grazing_150m[:,x[i]:x[i]+12,:,:]

# %%
x = np.array(range(0,756,12)) ## this loops from 0 to 2016, and selects every 12th number. 
for i in range(20,40):
    zoo_zoo_ds_inter[:,i,:,:,:] = zoo_zoo_grazing_150m[:,x[i]:x[i]+12,:,:]

# %%
x = np.array(range(0,756,12)) ## this loops from 0 to 2016, and selects every 12th number. 
for i in range(40,63):
    zoo_zoo_ds_inter[:,i,:,:,:] = zoo_zoo_grazing_150m[:,x[i]:x[i]+12,:,:]

# %%
np.save("/glade/scratch/gabyn/SPECTRA/zoo_zoo_ds_inter.npy", zoo_zoo_ds_inter)

# %%
zoo_zoo_ds_inter_winter = np.nanmean(zoo_zoo_ds_inter[:,:,list(range(2)) + [-1],:,:],axis=(2)) # sum through the years and the 
zoo_zoo_ds_inter_spring = np.nanmean(zoo_zoo_ds_inter[:,:,2:5,:,:],axis=(2)) # sum through the years and the 
zoo_zoo_ds_inter_summer = np.nanmean(zoo_zoo_ds_inter[:,:,5:8,:,:],axis=(2)) # sum through the years and the 
zoo_zoo_ds_inter_fall = np.nanmean(zoo_zoo_ds_inter[:,:,8:11,:,:],axis=(2)) # sum through the years and the 

zoo_zoo_sum_winter = np.nansum(zoo_zoo_ds_inter_sum_winter,axis=0)
zoo_zoo_sum_spring = np.nansum(zoo_zoo_ds_inter_spring,axis=0)
zoo_zoo_sum_summer = np.nansum(zoo_zoo_ds_inter_summer,axis=0)
zoo_zoo_sum_fall = np.nansum(zoo_zoo_ds_inter_fall,axis=0)

np.save("/glade/scratch/gabyn/SPECTRA/zoo_zoo_sum_winter.npy",zoo_zoo_sum_winter)
np.save("/glade/scratch/gabyn/SPECTRA/zoo_zoo_sum_spring.npy",zoo_zoo_sum_spring)
np.save("/glade/scratch/gabyn/SPECTRA/zoo_zoo_sum_summer.npy",zoo_zoo_sum_summer)
np.save("/glade/scratch/gabyn/SPECTRA/zoo_zoo_sum_fall.npy",zoo_zoo_sum_fall)

# %%
zoo_zoo_ds_inter_winter = np.nanmean(zoo_zoo_ds_inter[:,:,list(range(2)) + [-1],:,:],axis=(2)) # sum through the years and the 
zoo_zoo_ds_inter_spring = np.nanmean(zoo_zoo_ds_inter[:,:,2:5,:,:],axis=(2)) # sum through the years and the 
zoo_zoo_ds_inter_summer = np.nanmean(zoo_zoo_ds_inter[:,:,5:8,:,:],axis=(2)) # sum through the years and the 
zoo_zoo_ds_inter_fall = np.nanmean(zoo_zoo_ds_inter[:,:,8:11,:,:],axis=(2)) # sum through the years and the

# %%
zoo_zoo_sum_winter = np.nansum(zoo_zoo_ds_inter_winter,axis=0)
zoo_zoo_sum_spring = np.nansum(zoo_zoo_ds_inter_spring,axis=0)
zoo_zoo_sum_summer = np.nansum(zoo_zoo_ds_inter_summer,axis=0)
zoo_zoo_sum_fall = np.nansum(zoo_zoo_ds_inter_fall,axis=0)

# %%
np.save("/glade/scratch/gabyn/SPECTRA/zoo_zoo_sum_winter.npy",zoo_zoo_sum_winter)
np.save("/glade/scratch/gabyn/SPECTRA/zoo_zoo_sum_spring.npy",zoo_zoo_sum_spring)
np.save("/glade/scratch/gabyn/SPECTRA/zoo_zoo_sum_summer.npy",zoo_zoo_sum_summer)
np.save("/glade/scratch/gabyn/SPECTRA/zoo_zoo_sum_fall.npy",zoo_zoo_sum_fall)

# %%
zoo_zoo_sum_winter= np.load("/glade/scratch/gabyn/SPECTRA/zoo_zoo_sum_winter.npy")
zoo_zoo_sum_spring = np.load("/glade/scratch/gabyn/SPECTRA/zoo_zoo_sum_spring.npy")
zoo_zoo_sum_summer = np.load("/glade/scratch/gabyn/SPECTRA/zoo_zoo_sum_summer.npy")
zoo_zoo_sum_fall = np.load("/glade/scratch/gabyn/SPECTRA/zoo_zoo_sum_fall.npy")

# %%
fig = plt.figure(figsize=(15, 10))
lat = ds.TLAT
lev = np.arange(0, 10, 0.1)
norm = colors.DivergingNorm(vmin=lev[0], vmax=lev[-1], vcenter=5)

## WINTER 
ax = fig.add_subplot(2, 2, 1, projection=ccrs.Robinson(central_longitude=305.0))
tlon, tlat, phyto = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(zoo_zoo_sum_winter,axis=0))
cf = ax.contourf(tlon, tlat, phyto, extend='both',cmap='Spectral_r',transform=ccrs.PlateCarree());
land = ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'))
cb = plt.colorbar(cf,shrink=0.5,orientation='horizontal')
cb.ax.tick_params(labelsize=20)
ax.set_title('Winter', fontsize =16)


## SPRING
ax = fig.add_subplot(2, 2, 2, projection=ccrs.Robinson(central_longitude=305.0))
tlon, tlat, phyto = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(zoo_zoo_sum_spring,axis=0))
cf = ax.contourf(tlon, tlat, phyto, extend='both',cmap='Spectral_r',transform=ccrs.PlateCarree());
land = ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'))
cb = plt.colorbar(cf,shrink=0.5,orientation='horizontal')
cb.ax.tick_params(labelsize=20)
ax.set_title('Spring', fontsize =16)

## SUMMER
ax = fig.add_subplot(2, 2, 3, projection=ccrs.Robinson(central_longitude=305.0))
tlon, tlat, phyto = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(zoo_zoo_sum_summer,axis=0))
cf = ax.contourf(tlon, tlat, phyto,  extend='both',cmap='Spectral_r',transform=ccrs.PlateCarree());
land = ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'))
cb = plt.colorbar(cf,shrink=0.5,orientation='horizontal')
cb.ax.tick_params(labelsize=20)
ax.set_title('Summer', fontsize =16)


##FALL
ax = fig.add_subplot(2, 2, 4, projection=ccrs.Robinson(central_longitude=305.0))
tlon, tlat, phyto = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(zoo_zoo_sum_fall,axis=0))
cf = ax.contourf(tlon, tlat, phyto, extend='both',cmap='Spectral_r',transform=ccrs.PlateCarree());
land = ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'))
cb = plt.colorbar(cf,shrink=0.5,orientation='horizontal')
cb.ax.tick_params(labelsize=20)
ax.set_title('Fall', fontsize =16);
fig.tight_layout()

fig.savefig('/glade/u/home/gabyn/case_notes/analysis_figures/GNG595/global_zoo_zoo_grazing_fluxes_quarterly_150m.png',dpi=200, bbox_inches='tight')

# %% [markdown]
# ## Create a Fraction!

# %% [markdown]
# ## Winter, Spring, Summer and Fall.

# %%
fig = plt.figure(figsize=(15, 10))
lat = ds.TLAT
lev = np.arange(0, 50, 5)
norm = colors.DivergingNorm(vmin=lev[0], vmax=lev[-1], vcenter=25)

## WINTER 
ax = fig.add_subplot(2, 2, 1, projection=ccrs.Robinson(central_longitude=305.0))
tlon, tlat, phyto = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_sum_winter,axis=0)/np.nanmean(zoo_zoo_sum_winter,axis=0))
cf = ax.contourf(tlon, tlat, phyto, vmin=0, vmax=50,levels=lev,norm=norm, extend='both',cmap='Spectral_r',transform=ccrs.PlateCarree());
land = ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'))
cb = plt.colorbar(cf,shrink=0.5,orientation='horizontal')
cb.ax.tick_params(labelsize=20)
ax.set_title('Winter', fontsize =16)


## SPRING
ax = fig.add_subplot(2, 2, 2, projection=ccrs.Robinson(central_longitude=305.0))
tlon, tlat, phyto = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_sum_spring,axis=0)/np.nanmean(zoo_zoo_sum_spring,axis=0))
cf = ax.contourf(tlon, tlat, phyto, vmin=0, vmax=50,levels=lev,norm=norm, extend='both',cmap='Spectral_r',transform=ccrs.PlateCarree());
land = ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'))
cb = plt.colorbar(cf,shrink=0.5,orientation='horizontal')
cb.ax.tick_params(labelsize=20)
ax.set_title('Spring', fontsize =16)

## SUMMER
ax = fig.add_subplot(2, 2, 3, projection=ccrs.Robinson(central_longitude=305.0))
tlon, tlat, phyto = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_sum_summer,axis=0)/np.nanmean(zoo_zoo_sum_summer,axis=0))
cf = ax.contourf(tlon, tlat, phyto, vmin=0, vmax=50,levels=lev,norm=norm, extend='both',cmap='Spectral_r',transform=ccrs.PlateCarree());
land = ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'))
cb = plt.colorbar(cf,shrink=0.5,orientation='horizontal')
cb.ax.tick_params(labelsize=20)
ax.set_title('Summer', fontsize =16)


##FALL
ax = fig.add_subplot(2, 2, 4, projection=ccrs.Robinson(central_longitude=305.0))
tlon, tlat, phyto = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_sum_fall,axis=0)/np.nanmean(zoo_zoo_sum_fall,axis=0))
cf = ax.contourf(tlon, tlat, phyto, vmin=0, vmax=50,levels=lev,norm=norm, extend='both',cmap='Spectral_r',transform=ccrs.PlateCarree());
land = ax.add_feature(cartopy.feature.NaturalEarthFeature('physical','land','110m', facecolor='gray'))
cb = plt.colorbar(cf,shrink=0.5,orientation='horizontal')
cb.ax.tick_params(labelsize=20)
ax.set_title('Fall', fontsize =16);
fig.tight_layout()

fig.savefig('/glade/u/home/gabyn/case_notes/analysis_figures/GNG595/global_Z&P_grazing_fraction_quarterly_150m.png',dpi=200, bbox_inches='tight')

# %%
phyto_zoo_frac_winter = phyto_zoo_sum_winter/zoo_zoo_sum_winter
phyto_zoo_frac_spring = phyto_zoo_sum_spring/zoo_zoo_sum_spring
phyto_zoo_frac_fall = phyto_zoo_sum_fall/zoo_zoo_sum_fall
phyto_zoo_frac_summer = phyto_zoo_sum_summer/zoo_zoo_sum_summer

# %% [markdown]
# ## High vs low temperature

# %%
temp_inds = sorted(glob.glob('/glade/scratch/gabyn/SPECTRA/GNG595_monthly_yearly_1948_2009/regrid_SPECTRA_TEMP*.nc', recursive=True))
ds_01= xr.open_mfdataset(temp_inds,concat_dim='time', combine='nested') # Full 62 years of second cycle

# %%
temp_ds_inter = np.empty([63,12,180,360])
temp_ds_inter[:] = np.nan
x = np.array(range(0,756,12)) ## this loops from 0 to 2016, and selects every 12th number. 
for i in range(63):
    temp_ds_inter[i,:,:,:] = ds_01.TEMP[x[i]:x[i]+12,0,:,:]

# %%
temp_arctic = np.nanmean(temp_ds_inter[:,:,149:180,:], axis=(2,3))
temp_arctic_anom = temp_arctic-np.nanmean(temp_arctic,axis=0)
err_ao = np.nanstd(temp_arctic_anom,axis=(0,1))

# Selecting the warm and cold years as less or more than 1/3 of standard deviation 
cold_years_arctic = np.where(np.nanmean(temp_arctic_anom,axis=1) < -(err_ao/2))
warm_years_arctic = np.where(np.nanmean(temp_arctic_anom,axis=1) > (err_ao/2))

# %%
cold_years_winter = phyto_zoo_frac_winter[cold_years_arctic,:,:] # 1/2 standard deviation 
warm_years_winter = phyto_zoo_frac_winter[warm_years_arctic,:,:] # 1/2 standard deviation 

cold_years_spring = phyto_zoo_frac_spring[cold_years_arctic,:,:] # 1/2 standard deviation 
warm_years_spring = phyto_zoo_frac_spring[warm_years_arctic,:,:] # 1/2 standard deviation 

cold_years_fall = phyto_zoo_frac_fall[cold_years_arctic,:,:] # 1/2 standard deviation 
warm_years_fall = phyto_zoo_frac_fall[warm_years_arctic,:,:] # 1/2 standard deviation 

cold_years_summer = phyto_zoo_frac_summer[cold_years_arctic,:,:] # 1/2 standard deviation 
warm_years_summer = phyto_zoo_frac_summer[warm_years_arctic,:,:] # 1/2 standard deviation

# %%
phyto_zoo_frac_summer.shape
# Out:
# (63, 384, 320)

# %% [markdown]
# ## Low vs high ice years

# %%
temp_inds = sorted(glob.glob('/glade/scratch/gabyn/SPECTRA/GNG595_monthly_yearly_1948_2009/regrid_SPECTRA_ECOSYS_IFRAC*.nc', recursive=True))
ds_02= xr.open_mfdataset(temp_inds,concat_dim='time', combine='nested') # Full 62 years of second cycle

# %%
ECOSYS_IFRAC_ds_inter = np.empty([63,12,180,360])
ECOSYS_IFRAC_ds_inter[:] = np.nan
x = np.array(range(0,756,12)) ## this loops from 0 to 2016, and selects every 12th number. 
for i in range(63):
    ECOSYS_IFRAC_ds_inter[i,:,:,:] = ds_02.ECOSYS_IFRAC[x[i]:x[i]+12,:,:]

# %%
ice_arctic = np.nanmean(ECOSYS_IFRAC_ds_inter[:,:,149:180,:], axis=(2,3))
ice_arctic_anom = ice_arctic-np.nanmean(ice_arctic,axis=0)
err_ao = np.nanstd(ice_arctic_anom,axis=(0,1))

# Selecting the warm and cold years as less or more than 1/3 of standard deviation 
low_ice_years_arctic = np.where(np.nanmean(ice_arctic_anom,axis=1) < -(err_ao/2))
high_ice_years_arctic = np.where(np.nanmean(ice_arctic_anom,axis=1) > (err_ao/2))

# %%
low_ice_years_winter = phyto_zoo_frac_winter[low_ice_years_arctic,:,:] # 1/2 standard deviation 
high_ice_years_winter = phyto_zoo_frac_winter[high_ice_years_arctic,:,:] # 1/2 standard deviation 

low_ice_years_spring = phyto_zoo_frac_spring[low_ice_years_arctic,:,:] # 1/2 standard deviation 
high_ice_years_spring = phyto_zoo_frac_spring[high_ice_years_arctic,:,:] # 1/2 standard deviation 

low_ice_years_fall = phyto_zoo_frac_fall[low_ice_years_arctic,:,:] # 1/2 standard deviation 
high_ice_years_fall = phyto_zoo_frac_fall[high_ice_years_arctic,:,:] # 1/2 standard deviation 

low_ice_years_summer = phyto_zoo_frac_summer[low_ice_years_arctic,:,:] # 1/2 standard deviation 
high_ice_years_summer = phyto_zoo_frac_summer[high_ice_years_arctic,:,:] # 1/2 standard deviation

# %% [markdown]
# ## Low vs high nutrient years

# %%
NO3_inds = sorted(glob.glob('/glade/scratch/gabyn/SPECTRA/GNG595_monthly_yearly_1948_2009/regrid_SPECTRA_NO3*.nc', recursive=True))
ds_03= xr.open_mfdataset(NO3_inds,concat_dim='time', combine='nested') # Full 62 years of second cycle

# %%
NO3_ds_inter = np.empty([63,12,180,360])
NO3_ds_inter[:] = np.nan
x = np.array(range(0,756,12)) ## this loops from 0 to 2016, and selects every 12th number. 
for i in range(63):
    NO3_ds_inter[i,:,:,:] = ds_03.NO3[x[i]:x[i]+12,0,:,:]

# %%
no3_arctic = np.nanmean(NO3_ds_inter[:,:,149:180,:], axis=(2,3))
no3_arctic_anom = no3_arctic-np.nanmean(no3_arctic,axis=0)
err_ao = np.nanstd(no3_arctic_anom,axis=(0,1))

# Selecting the warm and cold years as less or more than 1/3 of standard deviation 
low_no3_years_arctic = np.where(np.nanmean(no3_arctic_anom,axis=1) < -(err_ao/2))
high_no3_years_arctic = np.where(np.nanmean(no3_arctic_anom,axis=1) > (err_ao/2))

# %%
low_no3_years_winter = phyto_zoo_frac_winter[low_no3_years_arctic,:,:] # 1/2 standard deviation 
high_no3_years_winter = phyto_zoo_frac_winter[high_no3_years_arctic,:,:] # 1/2 standard deviation 

low_no3_years_spring = phyto_zoo_frac_spring[low_no3_years_arctic,:,:] # 1/2 standard deviation 
high_no3_years_spring = phyto_zoo_frac_spring[high_no3_years_arctic,:,:] # 1/2 standard deviation 

low_no3_years_fall = phyto_zoo_frac_fall[low_no3_years_arctic,:,:] # 1/2 standard deviation 
high_no3_years_fall = phyto_zoo_frac_fall[high_no3_years_arctic,:,:] # 1/2 standard deviation 

low_no3_years_summer = phyto_zoo_frac_summer[low_no3_years_arctic,:,:] # 1/2 standard deviation 
high_no3_years_summer = phyto_zoo_frac_summer[high_no3_years_arctic,:,:] # 1/2 standard deviation

# %%
warm_years_winter.shape
# Out:
# (1, 17, 384, 320)

# %% [markdown]
# ## Publication ready figure

# %%
from mpl_toolkits.basemap import Basemap
lev = np.arange(0, 1, 0.01)
norm = colors.DivergingNorm(vmin=lev[0], vmax=lev[-1], vcenter=0.5)
fig = plt.figure(figsize=(20, 20))

#### 62 year average!!! 

# Winter TLeq = 3 (62yr average)
ax = fig.add_subplot(4, 4, 1)
lon, lat, winter = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_frac_winter,axis=0))
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, winter, cmap='Spectral_r', vmin = 0, vmax = 15);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.set_title('Winter, grazing fraction', fontsize=16)
cb.ax.tick_params(labelsize=16)

# Spring TLeq = 3, (62yr average)
ax = fig.add_subplot(4, 4, 2)
lon, lat, spring = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_frac_spring,axis=0))
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, spring, cmap='Spectral_r', vmin = 0, vmax = 15);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.set_title('Spring, grazing fraction', fontsize=16)
cb.ax.tick_params(labelsize=16)

# Summer TLeq = 3, (62 yr average)
ax = fig.add_subplot(4, 4, 3)
lon, lat, summer = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_frac_summer,axis=0))
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, summer, cmap='Spectral_r', vmin = 0, vmax = 15);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.set_title('Summer, grazing fraction', fontsize=16)
cb.ax.tick_params(labelsize=16)

# Fall TLeq = 3, (62 yr average)
ax = fig.add_subplot(4, 4, 4)
lon, lat, fall = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(phyto_zoo_frac_fall,axis=0))
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, fall, cmap='Spectral_r',vmin = 0, vmax = 15);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.set_title('Fall, grazing fraction', fontsize=16)
cb.ax.tick_params(labelsize=16)

########## Differences!!! 

# Winter, % difference of catch from high and low temperature years. 
ax = fig.add_subplot(4, 4, 5)
winter_temp_diff = (np.nanmean(cold_years_winter,axis=(0,1))-np.nanmean(warm_years_winter,axis=(0,1))/-np.nanmean(warm_years_winter,axis=(0,1)))*100
lon, lat, w_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, winter_temp_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, w_diff, cmap='RdBu_r',vmin=-25,vmax=25);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.set_title(' % difference (l-h/h temp)', fontsize=16)
cb.ax.tick_params(labelsize=16)

# Spring, % difference of catch from high and low temperature years. 
ax = fig.add_subplot(4, 4, 6)
spring_temp_diff = ((np.nanmean(cold_years_spring,axis=(0,1))-np.nanmean(warm_years_spring,axis=(0,1)))/np.nanmean(warm_years_spring,axis=(0,1)))*100
lon, lat, sp_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, spring_temp_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, sp_diff, cmap='RdBu_r',vmin=-25,vmax=25);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.set_title(' % difference (l-h/h temp)', fontsize=16)
cb.ax.tick_params(labelsize=16)

# Summer, % difference of catch from high and low temperature years. 
ax = fig.add_subplot(4, 4, 7)
summer_temp_diff = ((np.nanmean(cold_years_summer,axis=(0,1))-np.nanmean(warm_years_summer,axis=(0,1)))/np.nanmean(warm_years_summer,axis=(0,1)))*100
lon, lat, s_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, summer_temp_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, s_diff, cmap='RdBu_r',vmin=-25,vmax=25);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.set_title(' % difference (l-h/h temp)', fontsize=16)
cb.ax.tick_params(labelsize=16)

# Fall, % difference of catch from high and low temperature years. 
ax = fig.add_subplot(4, 4, 8)
fall_temp_diff = ((np.nanmean(cold_years_fall,axis=(0,1))-np.nanmean(warm_years_fall,axis=(0,1)))/np.nanmean(warm_years_fall,axis=(0,1)))*100
lon, lat, f_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, fall_temp_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, f_diff, cmap='RdBu_r',vmin=-25,vmax=25);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.set_title(' % difference (l-h/h temp)', fontsize=16)
cb.ax.tick_params(labelsize=16)

## Ice Fraction

# Winter, % difference of catch from high and low ice fraction  years. 
ax = fig.add_subplot(4, 4, 9)
winter_ice_diff = ((np.nanmean(high_ice_years_winter, axis=(0,1))-np.nanmean(low_ice_years_winter, axis=(0,1)))/np.nanmean(low_ice_years_winter, axis=(0,1)))*100
lon, lat, w_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, winter_ice_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, w_diff, cmap='RdBu_r',vmin=-25,vmax=25);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.set_title(' % difference (h-l/l ice)', fontsize=16)
cb.ax.tick_params(labelsize=16)

# Spring, % difference of catch from high and low ice fraction years. 
ax = fig.add_subplot(4, 4, 10)
spring_ice_diff = ((np.nanmean(high_ice_years_spring, axis=(0,1))-np.nanmean(low_ice_years_spring, axis=(0,1)))/np.nanmean(low_ice_years_spring, axis=(0,1)))*100
lon, lat, sp_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, spring_ice_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, sp_diff, cmap='RdBu_r',vmin=-25,vmax=25);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.set_title(' % difference (h-l/l ice)', fontsize=16)
cb.ax.tick_params(labelsize=16)

# Summer, % difference of catch from high and low ice fraction  years. 
ax = fig.add_subplot(4, 4, 11)
summer_ice_diff = ((np.nanmean(high_ice_years_summer, axis=(0,1))-np.nanmean(low_ice_years_summer, axis=(0,1)))/np.nanmean(low_ice_years_summer, axis=(0,1)))*100
lon, lat, s_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, summer_ice_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, s_diff, cmap='RdBu_r',vmin=-25,vmax=25);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.set_title(' % difference (h-l/l ice)', fontsize=16)
cb.ax.tick_params(labelsize=16)

# Fall, % difference of catch from high and low ice fraction  years. 
ax = fig.add_subplot(4, 4, 12)
fall_ice_diff = ((np.nanmean(high_ice_years_fall, axis=(0,1))-np.nanmean(low_ice_years_fall, axis=(0,1)))/np.nanmean(low_ice_years_fall, axis=(0,1)))*100
lon, lat, f_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, fall_ice_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, f_diff, cmap='RdBu_r',vmin=-25,vmax=25);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.set_title(' % difference (h-l/l ice)', fontsize=16)
cb.ax.tick_params(labelsize=16)


# Winter, % difference of catch from high and low NO$_3$  years. 
ax = fig.add_subplot(4, 4, 13)
winter_no3_diff = ((np.nanmean(high_no3_years_winter, axis=(0,1))-np.nanmean(low_no3_years_winter, axis=(0,1)))/np.nanmean(low_no3_years_winter, axis=(0,1)))*100
lon, lat, w_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, winter_no3_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, w_diff, cmap='RdBu_r',vmin=-25,vmax=25);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.set_title(' % difference (h-l/l NO$_3$)', fontsize=16)
cb.ax.tick_params(labelsize=16)

# Spring, % difference of catch from high and low NO$_3$ years. 
ax = fig.add_subplot(4, 4, 14)
spring_no3_diff = ((np.nanmean(high_no3_years_spring, axis=(0,1))-np.nanmean(low_no3_years_spring, axis=(0,1)))/np.nanmean(low_no3_years_spring, axis=(0,1)))*100
lon, lat, sp_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, spring_no3_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, sp_diff, cmap='RdBu_r',vmin=-25,vmax=25);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.set_title(' % difference (h-l/l NO$_3$)', fontsize=16)
cb.ax.tick_params(labelsize=16)

# Summer, % difference of catch from high and low NO$_3$  years. 
ax = fig.add_subplot(4, 4, 15)
summer_no3_diff = ((np.nanmean(high_no3_years_summer, axis=(0,1))-np.nanmean(low_no3_years_summer, axis=(0,1)))/np.nanmean(low_no3_years_summer, axis=(0,1)))*100
lon, lat, s_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, summer_no3_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, s_diff, cmap='RdBu_r',vmin=-25,vmax=25);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.set_title(' % difference (h-l/l NO$_3$)', fontsize=16)
cb.ax.tick_params(labelsize=16)

# Fall, % difference of catch from high and low NO$_3$  years. 
ax = fig.add_subplot(4, 4, 16)
fall_no3_diff = ((np.nanmean(high_no3_years_fall, axis=(0,1))-np.nanmean(low_no3_years_fall, axis=(0,1)))/np.nanmean(low_no3_years_fall, axis=(0,1)))*100
lon, lat, f_diff = adjust_pop_grid(ds.TLONG, ds.TLAT, fall_no3_diff)
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
m.fillcontinents(color='gray')
x,y = m(lon, lat)
cf = m.pcolor(x, y, f_diff, cmap='RdBu_r',vmin=-25,vmax=25);
cb = plt.colorbar(cf, shrink=0.5, extend ='both',orientation='horizontal')
cb.ax.tick_params(labelsize=16)
cb.ax.set_title(' % difference (h-l/l NO$_3$)', fontsize=16)

fig.text(0.05, 0.98, 'a',fontsize=24, fontweight='bold')
fig.text(0.3, 0.98, 'b',fontsize=24, fontweight='bold')
fig.text(0.55, 0.98, 'c',fontsize=24, fontweight='bold')
fig.text(0.78, 0.98, 'd',fontsize=24, fontweight='bold')
fig.text(0.05, 0.73, 'e',fontsize=24, fontweight='bold')
fig.text(0.3, 0.73, 'f',fontsize=24, fontweight='bold')
fig.text(0.55, 0.73, 'g',fontsize=24, fontweight='bold')
fig.text(0.78, 0.73, 'h',fontsize=24, fontweight='bold')
fig.text(0.05, 0.49, 'i',fontsize=24, fontweight='bold')
fig.text(0.3, 0.49, 'j',fontsize=24, fontweight='bold')
fig.text(0.55, 0.49, 'k',fontsize=24, fontweight='bold')
fig.text(0.78, 0.49, 'l',fontsize=24, fontweight='bold')
fig.text(0.05, 0.23, 'm',fontsize=24, fontweight='bold')
fig.text(0.3, 0.23, 'n',fontsize=24, fontweight='bold')
fig.text(0.55, 0.23, 'o',fontsize=24, fontweight='bold')
fig.text(0.78, 0.23, 'p',fontsize=24, fontweight='bold')

plt.tight_layout()

fig.savefig('/glade/u/home/gabyn/case_notes/analysis_figures/GNG595/quarterly_grazing_fraction_interannual.png',dpi=200, bbox_inches='tight')
