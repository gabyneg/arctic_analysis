# %% [markdown]
# # Growth Limiation - Create a grid of factor most limiting growth at each year for summer months, for each phytoplankton group... throuhout the whole Arctic Ocean.
# 1. find what areas around the Arctic are limited by what, and
# 2. see how you can plot difference plots or show how these differ between high and low temp, ice and NO$_3$ years.

# %%
import warnings
warnings.simplefilter("ignore") # Silence warnings
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
#import hvplot.xarray
import xarray as xr
import numpy as np
from matplotlib.pyplot import figure
import numpy.ma as ma
from netCDF4 import Dataset as NetCDFFile
import glob
import cartopy
import cartopy.crs as ccrs
import pylab 
from copy import deepcopy

# %%
def adjust_pop_grid(tlon,tlat,field):
    nj = tlon.shape[0]
    ni = tlon.shape[1]
    xL = int(ni/2 - 1)
    xR = int(xL + ni)

    tlon = np.where(np.greater_equal(tlon,np.min(tlon[:,0])),tlon-360.,tlon)
    lon  = np.concatenate((tlon,tlon+360.),1)
    lon = lon[:,xL:xR]

    if ni == 320:
        lon[367:-3,0] = lon[367:-3,0]+360.
    lon = lon - 360.
    lon = np.hstack((lon,lon[:,0:1]+360.))
    if ni == 320:
        lon[367:,-1] = lon[367:,-1] - 360.

    #-- trick cartopy into doing the right thing:
    #   it gets confused when the cyclic coords are identical
    lon[:,0] = lon[:,0]-1e-8

    #-- periodicity
    lat  = np.concatenate((tlat,tlat),1)
    lat = lat[:,xL:xR]
    lat = np.hstack((lat,lat[:,0:1]))

    field = np.ma.concatenate((field,field),1)
    field = field[:,xL:xR]
    field = np.ma.hstack((field,field[:,0:1]))
    return lon,lat,field

# %%
import re
numbers = re.compile(r'(\d+)')
def numericalSort(value):
    parts = numbers.split(value)
    parts[1::2] = map(int, parts[1::2])
    return parts

# %%
path = '/glade/campaign/cesm/development/bgcwg/projects/marbl-spectra/GNG595_2ndcycle_1990-2009_clim'
files = sorted(glob.glob(f'{path}/*.nc', recursive=True),key=numericalSort)
ds= xr.open_mfdataset(files,combine='by_coords')

# %% [markdown]
# ## Check what these files are, because they could save a lot of time...

# %%
diat3_limitation = xr.open_mfdataset('/glade/u/home/gabyn/scratch/SPECTRA/growth_lim/diat3_limitation.nc')
pp_limitation = xr.open_mfdataset('/glade/u/home/gabyn/scratch/SPECTRA/growth_lim/pp_limitation.nc')
# Out:
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		nc_inq_attname: ncid 0xd0000 varid 0 attnum 0
# 		nc_inq_attname: ncid 0xd0000 varid 0 attnum 1
# 		NC4_inq_att: ncid 0xd0000 varid 0 name units
# 			nc4_get_att: ncid 0xd0000 varid 0 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 0 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xd0000 varid 0 name calendar
# 			nc4_get_att: ncid 0xd0000 varid 0 name calendar attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 0 name calendar attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		nc_inq_attname: ncid 0xd0000 varid 2 attnum 0
# 		nc_inq_attname: ncid 0xd0000 varid 2 attnum 1
# 		nc_inq_attname: ncid 0xd0000 varid 2 attnum 2
# 		NC4_inq_att: ncid 0xd0000 varid 2 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 2 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 2 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 2 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 2 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_att: ncid 0xd0000 varid 2 name long_name
# 			nc4_get_att: ncid 0xd0000 varid 2 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 2 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xd0000 varid 2 name units
# 			nc4_get_att: ncid 0xd0000 varid 2 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 2 name units attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		nc_inq_attname: ncid 0xd0000 varid 3 attnum 0
# 		nc_inq_attname: ncid 0xd0000 varid 3 attnum 1
# 		nc_inq_attname: ncid 0xd0000 varid 3 attnum 2
# 		NC4_inq_att: ncid 0xd0000 varid 3 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 3 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 3 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 3 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 3 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_att: ncid 0xd0000 varid 3 name long_name
# 			nc4_get_att: ncid 0xd0000 varid 3 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 3 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xd0000 varid 3 name units
# 			nc4_get_att: ncid 0xd0000 varid 3 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 3 name units attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		nc_inq_attname: ncid 0xd0000 varid 4 attnum 0
# 		nc_inq_attname: ncid 0xd0000 varid 4 attnum 1
# 		nc_inq_attname: ncid 0xd0000 varid 4 attnum 2
# 		NC4_inq_att: ncid 0xd0000 varid 4 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 4 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 4 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 4 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 4 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_att: ncid 0xd0000 varid 4 name long_name
# 			nc4_get_att: ncid 0xd0000 varid 4 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 4 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xd0000 varid 4 name coordinates
# 			nc4_get_att: ncid 0xd0000 varid 4 name coordinates attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 4 name coordinates attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		nc_inq_attname: ncid 0xd0000 varid 5 attnum 0
# 		nc_inq_attname: ncid 0xd0000 varid 5 attnum 1
# 		nc_inq_attname: ncid 0xd0000 varid 5 attnum 2
# 		nc_inq_attname: ncid 0xd0000 varid 5 attnum 3
# 		NC4_inq_att: ncid 0xd0000 varid 5 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 5 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 5 name _FillValue
# 			nc4_get_att: ncid 0xd0000 varid 5 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 5 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_att: ncid 0xd0000 varid 5 name long_name
# 			nc4_get_att: ncid 0xd0000 varid 5 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 5 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xd0000 varid 5 name values
# 			nc4_get_att: ncid 0xd0000 varid 5 name values attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 5 name values attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xd0000 varid 5 name coordinates
# 			nc4_get_att: ncid 0xd0000 varid 5 name coordinates attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid 5 name coordinates attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq: ncid 0xd0000
# 		nc_inq_attname: ncid 0xd0000 varid -1 attnum 0
# 		nc_inq_attname: ncid 0xd0000 varid -1 attnum 1
# 		NC4_inq_att: ncid 0xd0000 varid -1 name NCO
# 			nc4_get_att: ncid 0xd0000 varid -1 name NCO attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid -1 name NCO attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xd0000 varid -1 name history
# 			nc4_get_att: ncid 0xd0000 varid -1 name history attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xd0000 varid -1 name history attnum -1 mem_type 2
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_unlimdims: ncid 0xd0000
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 			NC4_get_vars: var->hdr.name month mem_nc_type 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_att: ncid 0xd0000 varid 0 name scale_factor
# 			nc4_get_att: ncid 0xd0000 varid 0 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 0 name add_offset
# 			nc4_get_att: ncid 0xd0000 varid 0 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 			NC4_get_vars: var->hdr.name month mem_nc_type 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_att: ncid 0xd0000 varid 0 name scale_factor
# 			nc4_get_att: ncid 0xd0000 varid 0 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 0 name add_offset
# 			nc4_get_att: ncid 0xd0000 varid 0 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 			NC4_get_vars: var->hdr.name month mem_nc_type 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_att: ncid 0xd0000 varid 0 name scale_factor
# 			nc4_get_att: ncid 0xd0000 varid 0 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 0 name add_offset
# 			nc4_get_att: ncid 0xd0000 varid 0 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 			NC4_get_vars: var->hdr.name time mem_nc_type 10
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_var_all: ncid 0xd0000 varid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_att: ncid 0xd0000 varid 1 name scale_factor
# 			nc4_get_att: ncid 0xd0000 varid 1 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 1 name add_offset
# 			nc4_get_att: ncid 0xd0000 varid 1 name add_offset attnum -1 mem_type 0
# 	NC4_open: path /glade/u/home/gabyn/scratch/SPECTRA/growth_lim/pp_limitation.nc mode 4096 params 0
# 	HDF5 error messages turned on.
# 			nc4_open_file: path /glade/u/home/gabyn/scratch/SPECTRA/growth_lim/pp_limitation.nc mode 4096
# 			nc4_grp_list_add: name /
# 			nc4_rec_read_metadata: grp->hdr.name /
# 			found dataset month
# 			found dataset nlat
# 			found dataset nlon
# 			found dataset time
# 			found dataset TLAT
# 			found dataset TLONG
# 			found dataset pp_lim_value
# 			found dataset pp_lim_index
# ERROR: Invalid _NCProperties attribute
# 		*** NetCDF-4 Internal Metadata: int_ncid 0xf0000 ext_ncid 0xf0000
# 		FILE - path: /glade/u/home/gabyn/scratch/SPECTRA/growth_lim/pp_limitation.nc cmode: 0x1008 parallel: 0 redef: 0 fill_mode: 0 no_write: 1 next_nc_grpid: 1
# 		 GROUP - / nc_grpid: 0 nvars: 6 natts: 0
# 		 DIMENSION - dimid: 0 name: month len: 12 unlimited: 0
# 		 DIMENSION - dimid: 2 name: nlat len: 384 unlimited: 0
# 		 DIMENSION - dimid: 3 name: nlon len: 320 unlimited: 0
# 		 DIMENSION - dimid: 1 name: time len: 63 unlimited: 0
# 		 VARIABLE - varid: 0 name: month ndims: 1 dimscale: 1 dimids: 0
# 		 VARIABLE - varid: 1 name: time ndims: 1 dimscale: 1 dimids: 1
# 		 VARIABLE - varid: 2 name: TLAT ndims: 2 dimscale: 0 dimids: 2 3
# 		 VARIABLE - varid: 3 name: TLONG ndims: 2 dimscale: 0 dimids: 2 3
# 		 VARIABLE - varid: 4 name: pp_lim_value ndims: 4 dimscale: 0 dimids: 1 0 2 3
# 		 VARIABLE - varid: 5 name: pp_lim_index ndims: 4 dimscale: 0 dimids: 1 0 2 3
# 		nc_inq_format: ncid 0xf0000
# 		NC4_inq_format_extended: ncid 0xf0000
# 		nc_inq_typeids: ncid 0xf0000
# 		NC4_inq: ncid 0xf0000
# 		nc_inq_dimids: ncid 0xf0000 include_parents: 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq: ncid 0xf0000
# 		nc_inq_varids: ncid 0xf0000
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 			nc4_att_list_add: name units
# 			nc4_att_list_add: name calendar
# 		nc_inq_attname: ncid 0xf0000 varid 0 attnum 0
# 		nc_inq_attname: ncid 0xf0000 varid 0 attnum 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 			nc4_att_list_add: name _FillValue
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name units
# 		nc_inq_attname: ncid 0xf0000 varid 2 attnum 0
# 		nc_inq_attname: ncid 0xf0000 varid 2 attnum 1
# 		nc_inq_attname: ncid 0xf0000 varid 2 attnum 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 			nc4_att_list_add: name _FillValue
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name units
# 		nc_inq_attname: ncid 0xf0000 varid 3 attnum 0
# 		nc_inq_attname: ncid 0xf0000 varid 3 attnum 1
# 		nc_inq_attname: ncid 0xf0000 varid 3 attnum 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 			nc4_att_list_add: name _FillValue
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name coordinates
# 		nc_inq_attname: ncid 0xf0000 varid 4 attnum 0
# 		nc_inq_attname: ncid 0xf0000 varid 4 attnum 1
# 		nc_inq_attname: ncid 0xf0000 varid 4 attnum 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 			nc4_att_list_add: name _FillValue
# 			nc4_att_list_add: name long_name
# 			nc4_att_list_add: name values
# 			nc4_att_list_add: name coordinates
# 		nc_inq_attname: ncid 0xf0000 varid 5 attnum 0
# 		nc_inq_attname: ncid 0xf0000 varid 5 attnum 1
# 		nc_inq_attname: ncid 0xf0000 varid 5 attnum 2
# 		nc_inq_attname: ncid 0xf0000 varid 5 attnum 3
# 		nc_inq_grps: ncid 0xf0000
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		nc_inq_attname: ncid 0xf0000 varid 0 attnum 0
# 		nc_inq_attname: ncid 0xf0000 varid 0 attnum 1
# 		NC4_inq_att: ncid 0xf0000 varid 0 name units
# 			nc4_get_att: ncid 0xf0000 varid 0 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid 0 name units attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xf0000 varid 0 name calendar
# 			nc4_get_att: ncid 0xf0000 varid 0 name calendar attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid 0 name calendar attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		nc_inq_attname: ncid 0xf0000 varid 2 attnum 0
# 		nc_inq_attname: ncid 0xf0000 varid 2 attnum 1
# 		nc_inq_attname: ncid 0xf0000 varid 2 attnum 2
# 		NC4_inq_att: ncid 0xf0000 varid 2 name _FillValue
# 			nc4_get_att: ncid 0xf0000 varid 2 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xf0000 varid 2 name _FillValue
# 			nc4_get_att: ncid 0xf0000 varid 2 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid 2 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_att: ncid 0xf0000 varid 2 name long_name
# 			nc4_get_att: ncid 0xf0000 varid 2 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid 2 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xf0000 varid 2 name units
# 			nc4_get_att: ncid 0xf0000 varid 2 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid 2 name units attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		nc_inq_attname: ncid 0xf0000 varid 3 attnum 0
# 		nc_inq_attname: ncid 0xf0000 varid 3 attnum 1
# 		nc_inq_attname: ncid 0xf0000 varid 3 attnum 2
# 		NC4_inq_att: ncid 0xf0000 varid 3 name _FillValue
# 			nc4_get_att: ncid 0xf0000 varid 3 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xf0000 varid 3 name _FillValue
# 			nc4_get_att: ncid 0xf0000 varid 3 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid 3 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_att: ncid 0xf0000 varid 3 name long_name
# 			nc4_get_att: ncid 0xf0000 varid 3 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid 3 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xf0000 varid 3 name units
# 			nc4_get_att: ncid 0xf0000 varid 3 name units attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid 3 name units attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		nc_inq_attname: ncid 0xf0000 varid 4 attnum 0
# 		nc_inq_attname: ncid 0xf0000 varid 4 attnum 1
# 		nc_inq_attname: ncid 0xf0000 varid 4 attnum 2
# 		NC4_inq_att: ncid 0xf0000 varid 4 name _FillValue
# 			nc4_get_att: ncid 0xf0000 varid 4 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xf0000 varid 4 name _FillValue
# 			nc4_get_att: ncid 0xf0000 varid 4 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid 4 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_att: ncid 0xf0000 varid 4 name long_name
# 			nc4_get_att: ncid 0xf0000 varid 4 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid 4 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xf0000 varid 4 name coordinates
# 			nc4_get_att: ncid 0xf0000 varid 4 name coordinates attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid 4 name coordinates attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		nc_inq_attname: ncid 0xf0000 varid 5 attnum 0
# 		nc_inq_attname: ncid 0xf0000 varid 5 attnum 1
# 		nc_inq_attname: ncid 0xf0000 varid 5 attnum 2
# 		nc_inq_attname: ncid 0xf0000 varid 5 attnum 3
# 		NC4_inq_att: ncid 0xf0000 varid 5 name _FillValue
# 			nc4_get_att: ncid 0xf0000 varid 5 name _FillValue attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xf0000 varid 5 name _FillValue
# 			nc4_get_att: ncid 0xf0000 varid 5 name _FillValue attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid 5 name _FillValue attnum -1 mem_type 6
# 		NC4_inq_att: ncid 0xf0000 varid 5 name long_name
# 			nc4_get_att: ncid 0xf0000 varid 5 name long_name attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid 5 name long_name attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xf0000 varid 5 name values
# 			nc4_get_att: ncid 0xf0000 varid 5 name values attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid 5 name values attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xf0000 varid 5 name coordinates
# 			nc4_get_att: ncid 0xf0000 varid 5 name coordinates attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid 5 name coordinates attnum -1 mem_type 2
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq: ncid 0xf0000
# 			nc4_att_list_add: name NCO
# 			nc4_att_list_add: name history
# 		nc_inq_attname: ncid 0xf0000 varid -1 attnum 0
# 		nc_inq_attname: ncid 0xf0000 varid -1 attnum 1
# 		NC4_inq_att: ncid 0xf0000 varid -1 name NCO
# 			nc4_get_att: ncid 0xf0000 varid -1 name NCO attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid -1 name NCO attnum -1 mem_type 2
# 		NC4_inq_att: ncid 0xf0000 varid -1 name history
# 			nc4_get_att: ncid 0xf0000 varid -1 name history attnum -1 mem_type 0
# 			nc4_get_att: ncid 0xf0000 varid -1 name history attnum -1 mem_type 2
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_unlimdims: ncid 0xf0000
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 			NC4_get_vars: var->hdr.name month mem_nc_type 10
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_att: ncid 0xf0000 varid 0 name scale_factor
# 			nc4_get_att: ncid 0xf0000 varid 0 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xf0000 varid 0 name add_offset
# 			nc4_get_att: ncid 0xf0000 varid 0 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 			NC4_get_vars: var->hdr.name month mem_nc_type 10
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_att: ncid 0xf0000 varid 0 name scale_factor
# 			nc4_get_att: ncid 0xf0000 varid 0 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xf0000 varid 0 name add_offset
# 			nc4_get_att: ncid 0xf0000 varid 0 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 			NC4_get_vars: var->hdr.name month mem_nc_type 10
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_att: ncid 0xf0000 varid 0 name scale_factor
# 			nc4_get_att: ncid 0xf0000 varid 0 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xf0000 varid 0 name add_offset
# 			nc4_get_att: ncid 0xf0000 varid 0 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 			NC4_get_vars: var->hdr.name time mem_nc_type 10
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_var_all: ncid 0xf0000 varid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_att: ncid 0xf0000 varid 1 name scale_factor
# 			nc4_get_att: ncid 0xf0000 varid 1 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xf0000 varid 1 name add_offset
# 			nc4_get_att: ncid 0xf0000 varid 1 name add_offset attnum -1 mem_type 0

# %% [markdown]
# ## Set up colorbar

# %%
# colors for each variable 
# temperature (Blue)
temperature3 = ''
temperature2        = '#e0f3f8'
temperature1       = '#abd9e9'
temperature       = '#74add1'
# light (yellow)
light   = '#fdae61'
light1   ='#fee090'
light2   ='#ffffbf'
light3=''
# nutrients (Green)
nitrate2     = '#AFE1AF'
nitrate1     ='#00A36C'
nitrate     ='#097969'

from matplotlib.colors import LinearSegmentedColormap
color_temp = [temperature,temperature1,temperature2]
color_light = [light,light1,light2]
color_nutrients = [nitrate,nitrate1,nitrate2]

cmap_name = 'my_list'
cm_temp = LinearSegmentedColormap.from_list(
        cmap_name, color_temp, N=3)
cm_light = LinearSegmentedColormap.from_list(
        cmap_name, color_light, N=3)
cm_nutrients = LinearSegmentedColormap.from_list(
        cmap_name, color_nutrients, N=3)

# %%
N = 3 # number of colors to extract from each of the base_cmaps below
phyto = [cm_temp,cm_light,cm_nutrients]

n_base = len(phyto)
# we go from 0.2 to 0.8 below to avoid having several whites and blacks in the resulting cmaps
colors_phyto = np.concatenate([plt.get_cmap(name)(np.linspace(0,1,N)) for name in phyto])
cm_phyto = mpl.colors.ListedColormap(colors_phyto)

gradient = np.linspace(0, 1, 256)
gradient = np.vstack((gradient, gradient))

fig, ax = plt.subplots(1,1,figsize=(5,1))
ax.imshow(gradient, aspect='auto', cmap=cm_phyto)

# %% [markdown]
# ## Plot the regional limitaiton during the summer to make sure these are working correctly!

# %%
# %%time
fig = plt.figure(figsize=(5,5))
# ------------------------- Picoplankton ---------------------------
# Summer
ax = fig.add_subplot(121) 
ax.set_title("Summer",fontsize=24)
pp_lims = (pp_limitation.pp_lim_value.where(pp_limitation.pp_lim_value < 0.9) + pp_limitation.pp_lim_index.where(pp_limitation.pp_lim_value < 0.9))
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
tlon, tlat, summer = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(pp_lims[:,5:8,:,:], axis=(0,1)))
x, y = m(tlon,tlat)
cf = m.pcolormesh(x,y,summer,cmap=cm_phyto, vmin=0, vmax=3)
m.drawcoastlines(linewidth=0.5, linestyle='solid', color='gray', antialiased=1, ax=None, zorder=None)
m.fillcontinents(color='0.8', lake_color=None, ax=None, zorder=None, alpha=None)

# Summer
ax = fig.add_subplot(122) 
diat3_lims = (diat3_limitation.diat3_lim_value.where(diat3_limitation.diat3_lim_value < 0.9) + diat3_limitation.diat3_lim_index.where(diat3_limitation.diat3_lim_value < 0.9))
m = Basemap(projection='npstere',round=True, boundinglat=65, lon_0=180+(-100+-30)/2.,resolution='c')
tlon, tlat, summer = adjust_pop_grid(ds.TLONG, ds.TLAT, np.nanmean(diat3_lims[:,5:8,:,:], axis=(0,1)))
x, y = m(tlon,tlat)
cff = m.pcolormesh(x,y,summer,cmap=cm_phyto, vmin=0, vmax=3)
m.drawcoastlines(linewidth=0.5, linestyle='solid', color='gray', antialiased=1, ax=None, zorder=None)
m.fillcontinents(color='0.8', lake_color=None, ax=None, zorder=None, alpha=None)

cbar_ax = fig.add_axes([0.32, 0.01, 0.35, 0.02])
cbar = fig.colorbar(cf, cax=cbar_ax, shrink=0.75, spacing='uniform',ticks=[0.5,1.5,2.5],orientation="horizontal")
cbar.ax.set_xticklabels(['Light','Temp', 'Nutrients'], fontsize = 18)
cbar.ax.set_title('Factor most limiting growth', fontsize = 18)
m.plot
plt.show()
plt.tight_layout()
# Out:
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 			NC4_get_vars: var->hdr.name pp_lim_value mem_nc_type 6
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_att: ncid 0xf0000 varid 4 name scale_factor
# 			nc4_get_att: ncid 0xf0000 varid 4 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xf0000 varid 4 name add_offset
# 			nc4_get_att: ncid 0xf0000 varid 4 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 			NC4_get_vars: var->hdr.name pp_lim_index mem_nc_type 6
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_att: ncid 0xf0000 varid 5 name scale_factor
# 			nc4_get_att: ncid 0xf0000 varid 5 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xf0000 varid 5 name add_offset
# 			nc4_get_att: ncid 0xf0000 varid 5 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 			NC4_get_vars: var->hdr.name diat3_lim_value mem_nc_type 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_att: ncid 0xd0000 varid 4 name scale_factor
# 			nc4_get_att: ncid 0xd0000 varid 4 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 4 name add_offset
# 			nc4_get_att: ncid 0xd0000 varid 4 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 			NC4_get_vars: var->hdr.name diat3_lim_index mem_nc_type 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_att: ncid 0xd0000 varid 5 name scale_factor
# 			nc4_get_att: ncid 0xd0000 varid 5 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 5 name add_offset
# 			nc4_get_att: ncid 0xd0000 varid 5 name add_offset attnum -1 mem_type 0
# CPU times: user 3.69 s, sys: 8.39 s, total: 12.1 s
# Wall time: 15.7 s

# %%
pp_lims = (pp_limitation.pp_lim_value.where(pp_limitation.pp_lim_value < 0.9) + pp_limitation.pp_lim_index.where(pp_limitation.pp_lim_value < 0.9))
diat3_lims = (diat3_limitation.diat3_lim_value.where(diat3_limitation.diat3_lim_value < 0.9) + diat3_limitation.diat3_lim_index.where(diat3_limitation.diat3_lim_value < 0.9))

phyto_lims = np.stack([np.nanmean(pp_lims[:,5:8,:,:],axis=1),np.nanmean(diat3_lims[:,5:8,:,:],axis=1)],axis=0)
# Out:
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 			NC4_get_vars: var->hdr.name pp_lim_value mem_nc_type 6
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_var_all: ncid 0xf0000 varid 4
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_att: ncid 0xf0000 varid 4 name scale_factor
# 			nc4_get_att: ncid 0xf0000 varid 4 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xf0000 varid 4 name add_offset
# 			nc4_get_att: ncid 0xf0000 varid 4 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 			NC4_get_vars: var->hdr.name pp_lim_index mem_nc_type 6
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_var_all: ncid 0xf0000 varid 5
# 		NC4_inq_dim: ncid 0xf0000 dimid 1
# 		NC4_inq_dim: ncid 0xf0000 dimid 0
# 		NC4_inq_dim: ncid 0xf0000 dimid 2
# 		NC4_inq_dim: ncid 0xf0000 dimid 3
# 		NC4_inq_att: ncid 0xf0000 varid 5 name scale_factor
# 			nc4_get_att: ncid 0xf0000 varid 5 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xf0000 varid 5 name add_offset
# 			nc4_get_att: ncid 0xf0000 varid 5 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 			NC4_get_vars: var->hdr.name diat3_lim_value mem_nc_type 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_var_all: ncid 0xd0000 varid 4
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_att: ncid 0xd0000 varid 4 name scale_factor
# 			nc4_get_att: ncid 0xd0000 varid 4 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 4 name add_offset
# 			nc4_get_att: ncid 0xd0000 varid 4 name add_offset attnum -1 mem_type 0
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 			NC4_get_vars: var->hdr.name diat3_lim_index mem_nc_type 6
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_var_all: ncid 0xd0000 varid 5
# 		NC4_inq_dim: ncid 0xd0000 dimid 1
# 		NC4_inq_dim: ncid 0xd0000 dimid 0
# 		NC4_inq_dim: ncid 0xd0000 dimid 2
# 		NC4_inq_dim: ncid 0xd0000 dimid 3
# 		NC4_inq_att: ncid 0xd0000 varid 5 name scale_factor
# 			nc4_get_att: ncid 0xd0000 varid 5 name scale_factor attnum -1 mem_type 0
# 		NC4_inq_att: ncid 0xd0000 varid 5 name add_offset
# 			nc4_get_att: ncid 0xd0000 varid 5 name add_offset attnum -1 mem_type 0

# %%
phyto_lims.shape
# Out:
# (2, 63, 384, 320)

# %% [markdown]
# ## Mask the Region of the Arctic Ocean that you want to average through

# %%
# %%time
# Make the latitude an numpy array 
lat = np.array(ds.TLAT[:,0])

# Select latitudes above 65 degrees 
lat_mask=[(lat>=65)] 
lat_masked=lat[lat_mask] 

# obtain shapes of biomass arrays
b,c,m,n = phyto_lims.shape

# Mask biomass arrays 
phyto_lims_masked = phyto_lims[:,:,np.arange(m)[lat_mask][:, None], :]
# Out:
# CPU times: user 46.7 ms, sys: 311 ms, total: 358 ms
# Wall time: 918 ms

# %% [markdown]
# ## Create colormap with three different colors, representing temperature, light and nutrients.

# %%
from matplotlib.colors import LinearSegmentedColormap
colors = [(0.9994925028835063, 0.9192618223760093, 0.6061361014994233),(0.45066769191336664, 0.7509983339741125, 0.7703857490708702),(0.6825187635707243, 0.810691907283208, 0.6352470180118206)]

cmap_name = 'my_list'
cm = LinearSegmentedColormap.from_list(
        cmap_name, colors, N=3)

# %% [markdown]
# ## Create grid, with phytoplankton types in the y axis, and years in the x axis, that are color coded with the most limiting factor.

# %%
phyto_lims_masked.shape
# Out:
# (2, 63, 18, 1, 320)

# %%
import matplotlib.pyplot as plt
from matplotlib import colors
import numpy as np

data =  np.nanmean(phyto_lims_masked,axis=(2,3,4))# Should be 9 by 63... 
fig, ax = plt.subplots(figsize=(20,5))
ax.imshow(data, cmap=cm)

# draw gridlines
ax.grid(which='major', axis='both', linestyle='-', color='k', linewidth=2)

plt.show()
