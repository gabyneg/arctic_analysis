# %% [markdown]
# ## Bash Remap
# This is after bash_averaging_climatology
#
# Where scrips like these are used:
#
# for n in {104..124}
# do
#    echo "Working on simulation ${n}..."
#    cp g.e21.G1850ECOIAF.t62_g17.marbl0_33.GNG595.pop.h.0${n}-01.nc /glade/scratch/gabyn/GNG595_2ndcycle_20year_clim
# done
#
# nces * GNG595_20year-01.nc
# mv GNG595_20year-01.nc clim_20yr_GNG595_01.nc
# rm -rf g*

# %%
% where the original file is 
cd /glade/scratch/gabyn/GNG595_2ndcycle_20year_clim/

% copy output to my scratch file 
cp * /glade/scratch/gabyn/GNG595_2ndcycle_20year_clim_remap

% go to my scratch directory 
cd /glade/scratch/gabyn/GNG595_2ndcycle_20year_clim_remap

% rename all of the files to make them easier. 
for n in {01..12}
do
    echo "Working on simulation ${n}..."
   mv clim_20yr_GNG595_${n}.nc GNG595.${n}.nc
done

# %% [markdown]
# ['graze_diaz_zoo1',
#  'graze_diaz_zoo2',
#  'graze_diaz_zoo3',
#  'graze_pp_zoo1',
#  'graze_mp1_zoo1',
#  'graze_mp1_zoo2',
#  'graze_mp2_zoo2',
#  'graze_mp2_zoo3',
#  'graze_mp2_zoo4',
#  'graze_mp3_zoo3',
#  'graze_mp3_zoo4',
#  'graze_mp3_zoo5',
#  'graze_mp4_zoo4',
#  'graze_mp4_zoo5',
#  'graze_mp4_zoo6',
#  'graze_diat1_zoo1',
#  'graze_diat1_zoo2',
#  'graze_diat1_zoo3',
#  'graze_diat1_zoo4',
#  'graze_diat2_zoo2',
#  'graze_diat2_zoo3',
#  'graze_diat2_zoo4',
#  'graze_diat2_zoo5',
#  'graze_diat3_zoo3',
#  'graze_diat3_zoo4',
#  'graze_diat3_zoo5',
#  'graze_diat3_zoo6',
#  'graze_zoo1_zoo2',
#  'graze_zoo1_zoo3',
#  'graze_zoo2_zoo3',
#  'graze_zoo2_zoo4',
#  'graze_zoo3_zoo4',
#  'graze_zoo3_zoo5',
#  'graze_zoo4_zoo5',
#  'graze_zoo4_zoo6',
#  'graze_zoo5_zoo6']

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
ncatted -a coordinates,graze_diaz_zoo1,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_diaz_zoo2,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_diaz_zoo3,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_pp_zoo1,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_mp1_zoo1,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_mp1_zoo2,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_mp2_zoo2,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_mp2_zoo3,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_mp2_zoo4,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_mp3_zoo3,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_mp3_zoo4,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_mp3_zoo5,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_mp4_zoo4,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_mp4_zoo5,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_mp4_zoo6,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_diat1_zoo1,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_diat1_zoo2,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_diat1_zoo3,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_diat1_zoo4,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_diat2_zoo2,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_diat2_zoo3,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_diat2_zoo4,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_diat2_zoo5,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_diat3_zoo3,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_diat3_zoo4,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_diat3_zoo5,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_diat3_zoo6,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_zoo1_zoo2,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_zoo1_zoo3,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_zoo2_zoo3,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_zoo2_zoo4,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_zoo3_zoo4,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_zoo3_zoo5,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_zoo4_zoo5,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_zoo4_zoo6,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,graze_zoo5_zoo6,c,c,"TLONG TLAT" GNG595.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
cdo remapbil,r360x180 -selname,graze_diaz_zoo1 GNG595.${n}.nc GNG595_graze_diaz_zoo1.${n}.nc
cdo remapbil,r360x180 -selname,graze_diaz_zoo2 GNG595.${n}.nc GNG595_graze_diaz_zoo2.${n}.nc
cdo remapbil,r360x180 -selname,graze_diaz_zoo3 GNG595.${n}.nc GNG595_graze_diaz_zoo3.${n}.nc
cdo remapbil,r360x180 -selname,graze_pp_zoo1 GNG595.${n}.nc GNG595_graze_pp_zoo1.${n}.nc
cdo remapbil,r360x180 -selname,graze_mp1_zoo1 GNG595.${n}.nc GNG595_graze_mp1_zoo1.${n}.nc
cdo remapbil,r360x180 -selname,graze_mp1_zoo2 GNG595.${n}.nc GNG595_graze_mp1_zoo2.${n}.nc
cdo remapbil,r360x180 -selname,graze_mp2_zoo2 GNG595.${n}.nc GNG595_graze_mp2_zoo2.${n}.nc
cdo remapbil,r360x180 -selname,graze_mp2_zoo3 GNG595.${n}.nc GNG595_graze_mp2_zoo3.${n}.nc
cdo remapbil,r360x180 -selname,graze_mp2_zoo4 GNG595.${n}.nc GNG595_graze_mp2_zoo4.${n}.nc
cdo remapbil,r360x180 -selname,graze_mp3_zoo3 GNG595.${n}.nc GNG595_graze_mp3_zoo3.${n}.nc
cdo remapbil,r360x180 -selname,graze_mp3_zoo4 GNG595.${n}.nc GNG595_graze_mp3_zoo4.${n}.nc
cdo remapbil,r360x180 -selname,graze_mp3_zoo5 GNG595.${n}.nc GNG595_graze_mp3_zoo5.${n}.nc
cdo remapbil,r360x180 -selname,graze_mp4_zoo4 GNG595.${n}.nc GNG595_graze_mp4_zoo4.${n}.nc
cdo remapbil,r360x180 -selname,graze_mp4_zoo5 GNG595.${n}.nc GNG595_graze_mp4_zoo5.${n}.nc
cdo remapbil,r360x180 -selname,graze_mp4_zoo6 GNG595.${n}.nc GNG595_graze_mp4_zoo6.${n}.nc
cdo remapbil,r360x180 -selname,graze_diat1_zoo1 GNG595.${n}.nc GNG595_graze_diat1_zoo1.${n}.nc
cdo remapbil,r360x180 -selname,graze_diat1_zoo2 GNG595.${n}.nc GNG595_graze_diat1_zoo2.${n}.nc
cdo remapbil,r360x180 -selname,graze_diat1_zoo3 GNG595.${n}.nc GNG595_graze_diat1_zoo3.${n}.nc
cdo remapbil,r360x180 -selname,graze_diat1_zoo4 GNG595.${n}.nc GNG595_graze_diat1_zoo4.${n}.nc
cdo remapbil,r360x180 -selname,graze_diat2_zoo2 GNG595.${n}.nc GNG595_graze_diat2_zoo2.${n}.nc
cdo remapbil,r360x180 -selname,graze_diat2_zoo3 GNG595.${n}.nc GNG595_graze_diat2_zoo3.${n}.nc
cdo remapbil,r360x180 -selname,graze_diat2_zoo4 GNG595.${n}.nc GNG595_graze_diat2_zoo4.${n}.nc
cdo remapbil,r360x180 -selname,graze_diat2_zoo5 GNG595.${n}.nc GNG595_graze_diat2_zoo5.${n}.nc
cdo remapbil,r360x180 -selname,graze_diat3_zoo3 GNG595.${n}.nc GNG595_graze_diat3_zoo3.${n}.nc
cdo remapbil,r360x180 -selname,graze_diat3_zoo4 GNG595.${n}.nc GNG595_graze_diat3_zoo4.${n}.nc
cdo remapbil,r360x180 -selname,graze_diat3_zoo5 GNG595.${n}.nc GNG595_graze_diat3_zoo5.${n}.nc
cdo remapbil,r360x180 -selname,graze_diat3_zoo6 GNG595.${n}.nc GNG595_graze_diat3_zoo6.${n}.nc
cdo remapbil,r360x180 -selname,graze_zoo1_zoo2 GNG595.${n}.nc GNG595_graze_zoo1_zoo2.${n}.nc
cdo remapbil,r360x180 -selname,graze_zoo1_zoo3 GNG595.${n}.nc GNG595_graze_zoo1_zoo3.${n}.nc
cdo remapbil,r360x180 -selname,graze_zoo2_zoo3 GNG595.${n}.nc GNG595_graze_zoo2_zoo3.${n}.nc
cdo remapbil,r360x180 -selname,graze_zoo2_zoo4 GNG595.${n}.nc GNG595_graze_zoo2_zoo4.${n}.nc
cdo remapbil,r360x180 -selname,graze_zoo3_zoo4 GNG595.${n}.nc GNG595_graze_zoo3_zoo4.${n}.nc
cdo remapbil,r360x180 -selname,graze_zoo3_zoo5 GNG595.${n}.nc GNG595_graze_zoo3_zoo5.${n}.nc
cdo remapbil,r360x180 -selname,graze_zoo4_zoo5 GNG595.${n}.nc GNG595_graze_zoo4_zoo5.${n}.nc
cdo remapbil,r360x180 -selname,graze_zoo4_zoo6 GNG595.${n}.nc GNG595_graze_zoo4_zoo6.${n}.nc
cdo remapbil,r360x180 -selname,graze_zoo5_zoo6 GNG595.${n}.nc GNG595_graze_zoo5_zoo6.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diaz_zoo1.${n}.nc regrid_GNG595_graze_diaz_zoo1.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diaz_zoo2.${n}.nc regrid_GNG595_graze_diaz_zoo2.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diaz_zoo3.${n}.nc regrid_GNG595_graze_diaz_zoo3.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_pp_zoo1.${n}.nc regrid_GNG595_graze_pp_zoo1.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_mp1_zoo1.${n}.nc regrid_GNG595_graze_mp1_zoo1.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_mp1_zoo2.${n}.nc regrid_GNG595_graze_mp1_zoo2.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_mp2_zoo2.${n}.nc regrid_GNG595_graze_mp2_zoo2.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_mp2_zoo3.${n}.nc regrid_GNG595_graze_mp2_zoo3.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_mp2_zoo4.${n}.nc regrid_GNG595_graze_mp2_zoo4.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_mp3_zoo3.${n}.nc regrid_GNG595_graze_mp3_zoo3.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_mp3_zoo4.${n}.nc regrid_GNG595_graze_mp3_zoo4.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_mp3_zoo5.${n}.nc regrid_GNG595_graze_mp3_zoo5.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_mp4_zoo4.${n}.nc regrid_GNG595_graze_mp4_zoo4.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_mp4_zoo5.${n}.nc regrid_GNG595_graze_mp4_zoo5.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_mp4_zoo6.${n}.nc regrid_GNG595_graze_mp4_zoo6.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diat1_zoo1.${n}.nc regrid_GNG595_graze_diat1_zoo1.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diat1_zoo2.${n}.nc regrid_GNG595_graze_diat1_zoo2.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diat1_zoo3.${n}.nc regrid_GNG595_graze_diat1_zoo3.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diat1_zoo4.${n}.nc regrid_GNG595_graze_diat1_zoo4.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diat2_zoo2.${n}.nc regrid_GNG595_graze_diat2_zoo2.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diat2_zoo3.${n}.nc regrid_GNG595_graze_diat2_zoo3.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diat2_zoo4.${n}.nc regrid_GNG595_graze_diat2_zoo4.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diat2_zoo5.${n}.nc regrid_GNG595_graze_diat2_zoo5.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diat3_zoo3.${n}.nc regrid_GNG595_graze_diat3_zoo3.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diat3_zoo4.${n}.nc regrid_GNG595_graze_diat3_zoo4.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diat3_zoo5.${n}.nc regrid_GNG595_graze_diat3_zoo5.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diat3_zoo6.${n}.nc regrid_GNG595_graze_diat3_zoo6.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_zoo1_zoo2.${n}.nc regrid_GNG595_graze_zoo1_zoo2.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_zoo1_zoo3.${n}.nc regrid_GNG595_graze_zoo1_zoo3.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_zoo2_zoo3.${n}.nc regrid_GNG595_graze_zoo2_zoo3.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_zoo2_zoo4.${n}.nc regrid_GNG595_graze_zoo2_zoo4.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_zoo3_zoo4.${n}.nc regrid_GNG595_graze_zoo3_zoo4.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_zoo3_zoo5.${n}.nc regrid_GNG595_graze_zoo3_zoo5.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_zoo4_zoo5.${n}.nc regrid_GNG595_graze_zoo4_zoo5.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_zoo4_zoo6.${n}.nc regrid_GNG595_graze_zoo4_zoo6.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_zoo5_zoo6.${n}.nc regrid_GNG595_graze_zoo5_zoo6.${n}.nc
done

# %%
## 20 year clim 
under --- cd /glade/u/home/gabyn/scratch/SPECTRA/GNG595_2ndcycle_1990-2009_clim/

# %%
## 20 year clim 
under --- cd /glade/u/home/gabyn/scratch/SPECTRA/GNG595_2ndcycle_1990-2009_clim/

for n in {01..12}
do
echo "Working on simulation ${n}..."
ncatted -a coordinates,TAREA,c,c,"TLONG TLAT" GNG595_clim_1990-2009_${n}.nc
done

for n in {01..12}
do
echo "Working on simulation ${n}..."
cdo remapbil,r360x180 -selname,TAREA GNG595_clim_1990-2009_${n}.nc SPECTRA_TAREA.${n}.nc
done

for n in {01..12}
do
echo "Working on simulation ${n}..."
cdo sellonlatbox,-180,180,-89.5,89.5 SPECTRA_TAREA.${n}.nc regrid_SPECTRA_TAREA.${n}.nc
done

mv regrid* regrid

# %%
for n in {104..124};
do
echo "Working on simulation ${n}..."
cdo remapbil,r360x180 -selname,diat1Chl SPECTRA_${n}.nc SPECTRA_diat1Chl.${n}.nc
cdo remapbil,r360x180 -selname,diat2Chl SPECTRA_${n}.nc SPECTRA_diat2Chl.${n}.nc
cdo remapbil,r360x180 -selname,diat3Chl SPECTRA_${n}.nc SPECTRA_diat3Chl.${n}.nc
cdo remapbil,r360x180 -selname,diazChl SPECTRA_${n}.nc SPECTRA_diazChl.${n}.nc
cdo remapbil,r360x180 -selname,mp1Chl SPECTRA_${n}.nc SPECTRA_mp1Chl.${n}.nc
cdo remapbil,r360x180 -selname,mp2Chl SPECTRA_${n}.nc SPECTRA_mp2Chl.${n}.nc
cdo remapbil,r360x180 -selname,mp3Chl SPECTRA_${n}.nc SPECTRA_mp3Chl.${n}.nc
cdo remapbil,r360x180 -selname,mp4Chl SPECTRA_${n}.nc SPECTRA_mp4Chl.${n}.nc
cdo remapbil,r360x180 -selname,ppChl SPECTRA_${n}.nc SPECTRA_ppChl.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
ncatted -a coordinates,pp_loss_doc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,diat1_loss_doc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,diat2_loss_doc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,diat3_loss_doc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp1_loss_doc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp2_loss_doc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp3_loss_doc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp4_loss_doc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,diaz_loss_doc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,pp_agg_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,diat1_agg_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,diat2_agg_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,diat3_agg_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp1_agg_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp2_agg_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp3_agg_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp4_agg_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,diaz_agg_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,pp_loss_poc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,diat1_loss_poc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,diat2_loss_poc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,diat3_loss_poc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp1_loss_poc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp2_loss_poc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp3_loss_poc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp4_loss_poc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,diaz_loss_poc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
cdo remapbil,r360x180 -selname,pp_loss_doc_zint_100m GNG595.${n}.nc GNG595_pp_loss_doc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,diat1_loss_doc_zint_100m GNG595.${n}.nc GNG595_diat1_loss_doc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,diat2_loss_doc_zint_100m GNG595.${n}.nc GNG595_diat2_loss_doc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,diat3_loss_doc_zint_100m GNG595.${n}.nc GNG595_diat3_loss_doc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,mp1_loss_doc_zint_100m GNG595.${n}.nc GNG595_mp1_loss_doc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,mp2_loss_doc_zint_100m GNG595.${n}.nc GNG595_mp2_loss_doc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,mp3_loss_doc_zint_100m GNG595.${n}.nc GNG595_mp3_loss_doc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,mp4_loss_doc_zint_100m GNG595.${n}.nc GNG595_mp4_loss_doc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,diaz_loss_doc_zint_100m GNG595.${n}.nc GNG595_diaz_loss_doc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,pp_agg_zint_100m GNG595.${n}.nc GNG595_pp_agg_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,diat1_agg_zint_100m GNG595.${n}.nc GNG595_diat1_agg_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,diat2_agg_zint_100m GNG595.${n}.nc GNG595_diat2_agg_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,diat3_agg_zint_100m GNG595.${n}.nc GNG595_diat3_agg_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,mp1_agg_zint_100m GNG595.${n}.nc GNG595_mp1_agg_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,mp2_agg_zint_100m GNG595.${n}.nc GNG595_mp2_agg_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,mp3_agg_zint_100m GNG595.${n}.nc GNG595_mp3_agg_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,mp4_agg_zint_100m GNG595.${n}.nc GNG595_mp4_agg_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,diaz_agg_zint_100m GNG595.${n}.nc GNG595_diaz_agg_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,pp_loss_poc_zint_100m GNG595.${n}.nc GNG595_pp_loss_poc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,diat1_loss_poc_zint_100m GNG595.${n}.nc GNG595_diat1_loss_poc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,diat2_loss_poc_zint_100m GNG595.${n}.nc GNG595_diat2_loss_poc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,diat3_loss_poc_zint_100m GNG595.${n}.nc GNG595_diat3_loss_poc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,mp1_loss_poc_zint_100m GNG595.${n}.nc GNG595_mp1_loss_poc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,mp2_loss_poc_zint_100m GNG595.${n}.nc GNG595_mp2_loss_poc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,mp3_loss_poc_zint_100m GNG595.${n}.nc GNG595_mp3_loss_poc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,mp4_loss_poc_zint_100m GNG595.${n}.nc GNG595_mp4_loss_poc_zint_100m.${n}.nc
cdo remapbil,r360x180 -selname,diaz_loss_poc_zint_100m GNG595.${n}.nc GNG595_diaz_loss_poc_zint_100m.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_pp_loss_doc_zint_100m.${n}.nc regrid_GNG595_pp_loss_doc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diat1_loss_doc_zint_100m.${n}.nc regrid_GNG595_diat1_loss_doc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diat2_loss_doc_zint_100m.${n}.nc regrid_GNG595_diat2_loss_doc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diat3_loss_doc_zint_100m.${n}.nc regrid_GNG595_diat3_loss_doc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp1_loss_doc_zint_100m.${n}.nc regrid_GNG595_mp1_loss_doc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp2_loss_doc_zint_100m.${n}.nc regrid_GNG595_mp2_loss_doc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp3_loss_doc_zint_100m.${n}.nc regrid_GNG595_mp3_loss_doc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp4_loss_doc_zint_100m.${n}.nc regrid_GNG595_mp4_loss_doc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diaz_loss_doc_zint_100m.${n}.nc regrid_GNG595_diaz_loss_doc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_pp_agg_zint_100m.${n}.nc regrid_GNG595_pp_agg_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diat1_agg_zint_100m.${n}.nc regrid_GNG595_diat1_agg_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diat2_agg_zint_100m.${n}.nc regrid_GNG595_diat2_agg_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diat3_agg_zint_100m.${n}.nc regrid_GNG595_diat3_agg_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp1_agg_zint_100m.${n}.nc regrid_GNG595_mp1_agg_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp2_agg_zint_100m.${n}.nc regrid_GNG595_mp2_agg_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp3_agg_zint_100m.${n}.nc regrid_GNG595_mp3_agg_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp4_agg_zint_100m.${n}.nc regrid_GNG595_mp4_agg_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diaz_agg_zint_100m.${n}.nc regrid_GNG595_diaz_agg_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_pp_loss_poc_zint_100m.${n}.nc regrid_GNG595_pp_loss_poc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diat1_loss_poc_zint_100m.${n}.nc regrid_GNG595_diat1_loss_poc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diat2_loss_poc_zint_100m.${n}.nc regrid_GNG595_diat2_loss_poc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diat3_loss_poc_zint_100m.${n}.nc regrid_GNG595_diat3_loss_poc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp1_loss_poc_zint_100m.${n}.nc regrid_GNG595_mp1_loss_poc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp2_loss_poc_zint_100m.${n}.nc regrid_GNG595_mp2_loss_poc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp3_loss_poc_zint_100m.${n}.nc regrid_GNG595_mp3_loss_poc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp4_loss_poc_zint_100m.${n}.nc regrid_GNG595_mp4_loss_poc_zint_100m.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diaz_loss_poc_zint_100m.${n}.nc regrid_GNG595_diaz_loss_poc_zint_100m.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
ncatted -a coordinates,pp_loss_doc_zint_100m,c,c,"TLONG TLAT" GNG595.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
cdo remapbil,r360x180 -selname,pp_loss_doc_zint_100m GNG595.${n}.nc GNG595_pp_loss_doc_zint_100m.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_pp_loss_doc_zint_100m.${n}.nc regrid_GNG595_pp_loss_doc_zint_100m.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_graze_diaz_zoo1.${n}.nc regrid_GNG595_graze_diaz_zoo1.${n}.nc
done

# %% [markdown]
# ### Remap chlorophyll dataset OCCCI

# %%
% where the original file is 
cd /glade/scratch/gabyn/OCCCI/

% rename all of the files to make them easier. 
for n in {01..12}
do
    echo "Working on simulation ${n}..."
   mv ESACCI-OC-L3S-CHLOR_A-MERGED-1M_MONTHLY_4km_GEO_PML_OCx-1999${n}-fv5.0.nc OCCCI_Chla_1999.${n}.nc
   mv ESACCI-OC-L3S-CHLOR_A-MERGED-1M_MONTHLY_4km_GEO_PML_OCx-2000${n}-fv5.0.nc OCCCI_Chla_2000.${n}.nc
   mv ESACCI-OC-L3S-CHLOR_A-MERGED-1M_MONTHLY_4km_GEO_PML_OCx-2001${n}-fv5.0.nc OCCCI_Chla_2001.${n}.nc
   mv ESACCI-OC-L3S-CHLOR_A-MERGED-1M_MONTHLY_4km_GEO_PML_OCx-2002${n}-fv5.0.nc OCCCI_Chla_2002.${n}.nc
   mv ESACCI-OC-L3S-CHLOR_A-MERGED-1M_MONTHLY_4km_GEO_PML_OCx-2003${n}-fv5.0.nc OCCCI_Chla_2003.${n}.nc
   mv ESACCI-OC-L3S-CHLOR_A-MERGED-1M_MONTHLY_4km_GEO_PML_OCx-2004${n}-fv5.0.nc OCCCI_Chla_2004.${n}.nc
   mv ESACCI-OC-L3S-CHLOR_A-MERGED-1M_MONTHLY_4km_GEO_PML_OCx-2005${n}-fv5.0.nc OCCCI_Chla_2005.${n}.nc
   mv ESACCI-OC-L3S-CHLOR_A-MERGED-1M_MONTHLY_4km_GEO_PML_OCx-2006${n}-fv5.0.nc OCCCI_Chla_2006.${n}.nc
   mv ESACCI-OC-L3S-CHLOR_A-MERGED-1M_MONTHLY_4km_GEO_PML_OCx-2007${n}-fv5.0.nc OCCCI_Chla_2007.${n}.nc
   mv ESACCI-OC-L3S-CHLOR_A-MERGED-1M_MONTHLY_4km_GEO_PML_OCx-2008${n}-fv5.0.nc OCCCI_Chla_2008.${n}.nc
   mv ESACCI-OC-L3S-CHLOR_A-MERGED-1M_MONTHLY_4km_GEO_PML_OCx-2009${n}-fv5.0.nc OCCCI_Chla_2009.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
ncatted -a coordinates,chlor_a,c,c,"lon lat" OCCCI_Chla_1998.${n}.nc
ncatted -a coordinates,chlor_a,c,c,"lon lat" OCCCI_Chla_1999.${n}.nc
ncatted -a coordinates,chlor_a,c,c,"lon lat" OCCCI_Chla_2000.${n}.nc
ncatted -a coordinates,chlor_a,c,c,"lon lat" OCCCI_Chla_2001.${n}.nc
ncatted -a coordinates,chlor_a,c,c,"lon lat" OCCCI_Chla_2002.${n}.nc
ncatted -a coordinates,chlor_a,c,c,"lon lat" OCCCI_Chla_2003.${n}.nc
ncatted -a coordinates,chlor_a,c,c,"lon lat" OCCCI_Chla_2004.${n}.nc
ncatted -a coordinates,chlor_a,c,c,"lon lat" OCCCI_Chla_2005.${n}.nc
ncatted -a coordinates,chlor_a,c,c,"lon lat" OCCCI_Chla_2006.${n}.nc
ncatted -a coordinates,chlor_a,c,c,"lon lat" OCCCI_Chla_2007.${n}.nc
ncatted -a coordinates,chlor_a,c,c,"lon lat" OCCCI_Chla_2008.${n}.nc
ncatted -a coordinates,chlor_a,c,c,"lon lat" OCCCI_Chla_2009.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
cdo remapbil,r360x180 -selname,chlor_a OCCCI_Chla_1998.${n}.nc OCCCI_Chla_1998_rmap.${n}.nc
cdo remapbil,r360x180 -selname,chlor_a OCCCI_Chla_1999.${n}.nc OCCCI_Chla_1999_rmap.${n}.nc
cdo remapbil,r360x180 -selname,chlor_a OCCCI_Chla_2000.${n}.nc OCCCI_Chla_2000_rmap.${n}.nc
cdo remapbil,r360x180 -selname,chlor_a OCCCI_Chla_2001.${n}.nc OCCCI_Chla_2001_rmap.${n}.nc
cdo remapbil,r360x180 -selname,chlor_a OCCCI_Chla_2002.${n}.nc OCCCI_Chla_2002_rmap.${n}.nc
cdo remapbil,r360x180 -selname,chlor_a OCCCI_Chla_2003.${n}.nc OCCCI_Chla_2003_rmap.${n}.nc
cdo remapbil,r360x180 -selname,chlor_a OCCCI_Chla_2004.${n}.nc OCCCI_Chla_2004_rmap.${n}.nc
cdo remapbil,r360x180 -selname,chlor_a OCCCI_Chla_2005.${n}.nc OCCCI_Chla_2005_rmap.${n}.nc
cdo remapbil,r360x180 -selname,chlor_a OCCCI_Chla_2006.${n}.nc OCCCI_Chla_2006_rmap.${n}.nc
cdo remapbil,r360x180 -selname,chlor_a OCCCI_Chla_2007.${n}.nc OCCCI_Chla_2007_rmap.${n}.nc
cdo remapbil,r360x180 -selname,chlor_a OCCCI_Chla_2008.${n}.nc OCCCI_Chla_2008_rmap.${n}.nc
cdo remapbil,r360x180 -selname,chlor_a OCCCI_Chla_2009.${n}.nc OCCCI_Chla_2009_rmap.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
cdo sellonlatbox,-180,180,-89.5,89.5 OCCCI_Chla_1998_rmap.${n}.nc regrid_OCCCI_Chla_1998.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 OCCCI_Chla_1999_rmap.${n}.nc regrid_OCCCI_Chla_1999.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 OCCCI_Chla_2000_rmap.${n}.nc regrid_OCCCI_Chla_2000.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 OCCCI_Chla_2001_rmap.${n}.nc regrid_OCCCI_Chla_2001.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 OCCCI_Chla_2002_rmap.${n}.nc regrid_OCCCI_Chla_2002.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 OCCCI_Chla_2003_rmap.${n}.nc regrid_OCCCI_Chla_2003.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 OCCCI_Chla_2004_rmap.${n}.nc regrid_OCCCI_Chla_2004.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 OCCCI_Chla_2005_rmap.${n}.nc regrid_OCCCI_Chla_2005.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 OCCCI_Chla_2006_rmap.${n}.nc regrid_OCCCI_Chla_2006.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 OCCCI_Chla_2007_rmap.${n}.nc regrid_OCCCI_Chla_2007.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 OCCCI_Chla_2008_rmap.${n}.nc regrid_OCCCI_Chla_2008.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 OCCCI_Chla_2009_rmap.${n}.nc regrid_OCCCI_Chla_2009.${n}.nc
done

# %%
for n in {1998..2009};
do
    echo "Working on simulation ${n}..."
    ncrcat regrid_OCCCI_Chla_${n}.01.nc regrid_OCCCI_Chla_${n}.02.nc regrid_OCCCI_Chla_${n}.03.nc regrid_OCCCI_Chla_${n}.04.nc regrid_OCCCI_Chla_${n}.05.nc regrid_OCCCI_Chla_${n}.06.nc regrid_OCCCI_Chla_${n}.07.nc regrid_OCCCI_Chla_${n}.08.nc regrid_OCCCI_Chla_${n}.09.nc regrid_OCCCI_Chla_${n}.10.nc regrid_OCCCI_Chla_${n}.11.nc regrid_OCCCI_Chla_${n}.12.nc regrid_OCCCI_Chla_${n}.nc
done;

# %% [markdown]
# ## Try to remap the chlorohyll dataset

# %%
% where the original file is 
cd /glade/work/jluo/obs/SeaWiFS/climatology_regridded/

% copy output to my scratch file 
cp *.L3m_MC_CHL_chl_ocx_gx1v6.nc /glade/scratch/gabyn/SeaWiFS/

% go to my scratch directory 
cd /glade/scratch/gabyn/SeaWiFS/

% rename all of the files to make them easier. 
for n in {01..12}
do
    echo "Working on simulation ${n}..."
   mv ${n}*.L3m_MC_CHL_chl_ocx_gx1v6.nc Chl.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
ncatted -a coordinates,chl_ocx,c,c,"TLONG TLAT" Chl.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
cdo remapbil,r360x180 -selname,chl_ocx Chl.${n}.nc chl_ocx_SeaWiFS.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
cdo sellonlatbox,-180,180,-89.5,89.5 chl_ocx_SeaWiFS.${n}.nc regrid_chl_ocx_SeaWiFS.${n}.nc
done

# %% [markdown]
# ## For Monthly Chlorophyll

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
ncatted -a coordinates,diat1Chl,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,diat2Chl,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,diat3Chl,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,diazChl,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp1Chl,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp2Chl,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp3Chl,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,mp4Chl,c,c,"TLONG TLAT" GNG595.${n}.nc
ncatted -a coordinates,ppChl,c,c,"TLONG TLAT" GNG595.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
cdo remapbil,r360x180 -selname,diat1Chl GNG595.${n}.nc GNG595_diat1Chl.${n}.nc
cdo remapbil,r360x180 -selname,diat2Chl GNG595.${n}.nc GNG595_diat2Chl.${n}.nc
cdo remapbil,r360x180 -selname,diat3Chl GNG595.${n}.nc GNG595_diat3Chl.${n}.nc
cdo remapbil,r360x180 -selname,diazChl GNG595.${n}.nc GNG595_diazChl.${n}.nc
cdo remapbil,r360x180 -selname,mp1Chl GNG595.${n}.nc GNG595_mp1Chl.${n}.nc
cdo remapbil,r360x180 -selname,mp2Chl GNG595.${n}.nc GNG595_mp2Chl.${n}.nc
cdo remapbil,r360x180 -selname,mp3Chl GNG595.${n}.nc GNG595_mp3Chl.${n}.nc
cdo remapbil,r360x180 -selname,mp4Chl GNG595.${n}.nc GNG595_mp4Chl.${n}.nc
cdo remapbil,r360x180 -selname,ppChl GNG595.${n}.nc GNG595_ppChl.${n}.nc
done

# %%
for n in {01..12}
do
echo "Working on simulation ${n}..."
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diat1Chl.${n}.nc regrid_GNG595_diat1Chl.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diat2Chl.${n}.nc regrid_GNG595_diat2Chl.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diat3Chl.${n}.nc regrid_GNG595_diat3Chl.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_diazChl.${n}.nc regrid_GNG595_diazChl.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp1Chl.${n}.nc regrid_GNG595_mp1Chl.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp2Chl.${n}.nc regrid_GNG595_mp2Chl.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp3Chl.${n}.nc regrid_GNG595_mp3Chl.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_mp4Chl.${n}.nc regrid_GNG595_mp4Chl.${n}.nc
cdo sellonlatbox,-180,180,-89.5,89.5 GNG595_ppChl.${n}.nc regrid_GNG595_ppChl.${n}.nc
done

# %%
## For the Sfm dataset

# %%
cd /glade/scratch/gabyn/Smf_data_remap

# %%
ncatted -a coordinates,Sfm,c,c,"Y X" Sfm_199709_MO_4km.nc

# %%
cdo remapbil,r360x180 -selname,Sfm Sfm_199709_MO_4km.nc Sfm_199709_MO_4km_r.nc

# %%
cdo sellonlatbox,-180,180,-89.5,89.5 Sfm_199709_MO_4km.nc regrid_Sfm_199709_MO_4km.nc
